# %% [markdown]
# # Ethereum Price Prediction

# %% [markdown]
# download historical data from Yahoo Finance

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv("/content/ETH-USD.csv")
print(data.head())
# Out:
#          Date         Open         High          Low        Close  \
# 0  2022-12-20  1167.882690  1224.092651  1165.599487  1217.703613
# 1  2022-12-21  1217.586426  1218.192261  1206.440063  1213.599976
# 2  2022-12-22  1213.672607  1221.986816  1187.127808  1218.182129
# 3  2022-12-23  1218.079346  1226.998779  1215.994873  1220.159424
# 4  2022-12-24  1220.117920  1224.911621  1216.338745  1221.148560
#
#      Adj Close      Volume
# 0  1217.703613  6684951715
# 1  1213.599976  4217182733
# 2  1218.182129  5297471739
# 3  1220.159424  4835831923
# 4  1221.148560  2626153345
# <ipython-input-4-6aaad84c804e>:7: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
data.dropna()
plt.figure(figsize=(10, 4))
plt.title("Ethereum Price INR")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !pip install autots
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 817.9/817.9 kB 5.1 MB/s eta 0:00:00
# ...

# %%
from autots import AutoTS
model = AutoTS(forecast_length=10, frequency='infer', ensemble='simple', drop_data_older_than_periods=200)
model = model.fit(data, date_col='Date', value_col='Close', id_col=None)

prediction = model.predict()
forecast = prediction.forecast
print("Ethereum Price Prediction")
print(forecast)
# Out:
# Data frequency is: D, used frequency is: D
# Old data dropped by `drop_data_older_than_periods`.
# Model Number: 1 with model ARIMA in generation 0 of 10
# Model Number: 2 with model AverageValueNaive in generation 0 of 10
# Model Number: 3 with model AverageValueNaive in generation 0 of 10
# Model Number: 4 with model AverageValueNaive in generation 0 of 10
# Model Number: 5 with model DatepartRegression in generation 0 of 10
# Model Number: 6 with model DatepartRegression in generation 0 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Model Number: 7 with model DatepartRegression in generation 0 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# ...

# %% [markdown]
# ## Output
# Data frequency is: D, used frequency is: D
# Old data dropped by `drop_data_older_than_periods`.
# Model Number: 1 with model ARIMA in generation 0 of 10
# Model Number: 2 with model AverageValueNaive in generation 0 of 10
# Model Number: 3 with model AverageValueNaive in generation 0 of 10
# Model Number: 4 with model AverageValueNaive in generation 0 of 10
# Model Number: 5 with model DatepartRegression in generation 0 of 10
# Model Number: 6 with model DatepartRegression in generation 0 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Model Number: 7 with model DatepartRegression in generation 0 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Model Number: 8 with model DatepartRegression in generation 0 of 10
# Epoch 1/50
# 6/6 [==============================] - 15s 11ms/step - loss: 0.3924
# Epoch 2/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3894
# Epoch 3/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3897
# Epoch 4/50
# 6/6 [==============================] - 0s 17ms/step - loss: 0.3872
# Epoch 5/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.3887
# Epoch 6/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3885
# Epoch 7/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3877
# Epoch 8/50
# 6/6 [==============================] - 0s 13ms/step - loss: 0.3863
# Epoch 9/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3856
# Epoch 10/50
# 6/6 [==============================] - 0s 17ms/step - loss: 0.3877
# Epoch 11/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3862
# Epoch 12/50
# 6/6 [==============================] - 0s 15ms/step - loss: 0.3844
# Epoch 13/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3883
# Epoch 14/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.3855
# Epoch 15/50
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3852
# Epoch 16/50
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3858
# Epoch 17/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3842
# Epoch 18/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3845
# Epoch 19/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3870
# Epoch 20/50
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3832
# Epoch 21/50
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3845
# Epoch 22/50
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3834
# Epoch 23/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3850
# Epoch 24/50
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3823
# Epoch 25/50
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3846
# Epoch 26/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3826
# Epoch 27/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3802
# Epoch 28/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3844
# Epoch 29/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3799
# Epoch 30/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3810
# Epoch 31/50
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3820
# Epoch 32/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.3824
# Epoch 33/50
# 6/6 [==============================] - 0s 15ms/step - loss: 0.3798
# Epoch 34/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3783
# Epoch 35/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3755
# Epoch 36/50
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3782
# Epoch 37/50
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3792
# Epoch 38/50
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3797
# Epoch 39/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3780
# Epoch 40/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3748
# Epoch 41/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3793
# Epoch 42/50
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3779
# Epoch 43/50
# 6/6 [==============================] - 0s 13ms/step - loss: 0.3701
# Epoch 44/50
# 6/6 [==============================] - 0s 15ms/step - loss: 0.3711
# Epoch 45/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3763
# Epoch 46/50
# 6/6 [==============================] - 0s 19ms/step - loss: 0.3683
# Epoch 47/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.3735
# Epoch 48/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3678
# Epoch 49/50
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3691
# Epoch 50/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3716
# 1/1 [==============================] - 3s 3s/step
# Model Number: 9 with model ETS in generation 0 of 10
# Model Number: 10 with model ETS in generation 0 of 10
# Model Number: 11 with model GLM in generation 0 of 10
# Model Number: 12 with model GLM in generation 0 of 10
# Model Number: 13 with model GLS in generation 0 of 10
# Model Number: 14 with model GLS in generation 0 of 10
# Model Number: 15 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue, try 1.23.1 {as of 06-2023}') in model 15 in generation 0: GluonTS
# Model Number: 16 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue, try 1.23.1 {as of 06-2023}') in model 16 in generation 0: GluonTS
# Model Number: 17 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue, try 1.23.1 {as of 06-2023}') in model 17 in generation 0: GluonTS
# Model Number: 18 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue, try 1.23.1 {as of 06-2023}') in model 18 in generation 0: GluonTS
# Model Number: 19 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue, try 1.23.1 {as of 06-2023}') in model 19 in generation 0: GluonTS
# Model Number: 20 with model LastValueNaive in generation 0 of 10
# Model Number: 21 with model LastValueNaive in generation 0 of 10
# Model Number: 22 with model LastValueNaive in generation 0 of 10
# Model Number: 23 with model LastValueNaive in generation 0 of 10
# Model Number: 24 with model SeasonalNaive in generation 0 of 10
# Model Number: 25 with model SeasonalNaive in generation 0 of 10
# Model Number: 26 with model SeasonalNaive in generation 0 of 10
# Model Number: 27 with model UnobservedComponents in generation 0 of 10
# Model Number: 28 with model UnobservedComponents in generation 0 of 10
# Model Number: 29 with model UnobservedComponents in generation 0 of 10
# Model Number: 30 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 30 in generation 0: VAR
# Model Number: 31 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 31 in generation 0: VAR
# Model Number: 32 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 32 in generation 0: VECM
# Model Number: 33 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 33 in generation 0: VECM
# Model Number: 34 with model WindowRegression in generation 0 of 10
# Model Number: 35 with model ConstantNaive in generation 0 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Model Number: 36 with model FBProphet in generation 0 of 10
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyjx7m51j/cq8zl1mr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpyjx7m51j/twlzrhsp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=50548', 'data', 'file=/tmp/tmpyjx7m51j/cq8zl1mr.json', 'init=/tmp/tmpyjx7m51j/twlzrhsp.json', 'output', 'file=/tmp/tmpyjx7m51j/prophet_modelw9j4iqrh/prophet_model-20231220190326.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 19:03:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:03:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Model Number: 37 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue, try 1.23.1 {as of 06-2023}') in model 37 in generation 0: GluonTS
# Model Number: 38 with model MultivariateRegression in generation 0 of 10
# Model Number: 39 with model MultivariateRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but not future_regressor supplied.") in model 39 in generation 0: MultivariateRegression
# Model Number: 40 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 40 in generation 0: DatepartRegression
# Model Number: 41 with model SeasonalNaive in generation 0 of 10
# Model Number: 42 with model DatepartRegression in generation 0 of 10
# Model Number: 43 with model UnobservedComponents in generation 0 of 10
# Model Number: 44 with model UnobservedComponents in generation 0 of 10
# Model Number: 45 with model ETS in generation 0 of 10
# Model Number: 46 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 46 in generation 0: VECM
# Model Number: 47 with model ARDL in generation 0 of 10
# Model Number: 48 with model MultivariateMotif in generation 0 of 10
# Model Number: 49 with model MultivariateMotif in generation 0 of 10
# Model Number: 50 with model UnivariateMotif in generation 0 of 10
# Model Number: 51 with model UnivariateMotif in generation 0 of 10
# Model Number: 52 with model SectionalMotif in generation 0 of 10
# Model Number: 53 with model SectionalMotif in generation 0 of 10
# Model Number: 54 with model MultivariateRegression in generation 0 of 10
# Model Number: 55 with model FBProphet in generation 0 of 10
# Model Number: 56 with model SeasonalNaive in generation 0 of 10
# Model Number: 57 with model DatepartRegression in generation 0 of 10
# Model Number: 58 with model NVAR in generation 0 of 10
# Model Number: 59 with model Theta in generation 0 of 10
# Model Number: 60 with model UnivariateRegression in generation 0 of 10
# Template Eval Error: ValueError('Input X contains NaN.\nDecisionTreeRegressor does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values') in model 60 in generation 0: UnivariateRegression
# Model Number: 61 with model ARCH in generation 0 of 10
# Template Eval Error: ImportError('`arch` package must be installed from pip') in model 61 in generation 0: ARCH
# Model Number: 62 with model ConstantNaive in generation 0 of 10
# Model Number: 63 with model LastValueNaive in generation 0 of 10
# /usr/local/lib/python3.10/dist-packages/autots/tools/seasonal.py:629: RuntimeWarning: invalid value encountered in divide
#   scores = np.mean(np.abs(a - b) / divisor, axis=2)
# Model Number: 64 with model AverageValueNaive in generation 0 of 10
# Model Number: 65 with model GLS in generation 0 of 10
# Model Number: 66 with model SeasonalNaive in generation 0 of 10
# Model Number: 67 with model GLM in generation 0 of 10
# Model Number: 68 with model ETS in generation 0 of 10
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/links.py:198: RuntimeWarning: overflow encountered in exp
#   t = np.exp(-z)
# Model Number: 69 with model FBProphet in generation 0 of 10
# Model Number: 70 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue, try 1.23.1 {as of 06-2023}') in model 70 in generation 0: GluonTS
# Model Number: 71 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: Exception('Transformer HolidayTransformer failed on fit') in model 71 in generation 0: UnobservedComponents
# Model Number: 72 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 72 in generation 0: VAR
# Model Number: 73 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 73 in generation 0: VECM
# Model Number: 74 with model ARIMA in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 74 in generation 0: ARIMA
# Model Number: 75 with model WindowRegression in generation 0 of 10
# /usr/local/lib/python3.10/dist-packages/autots/tools/percentile.py:47: RuntimeWarning: All-NaN slice encountered
#   max_val = np.nanmax(arr)
# Model Number: 76 with model DatepartRegression in generation 0 of 10
# Model Number: 77 with model UnivariateRegression in generation 0 of 10
# Template Eval Error: ValueError('Input X contains NaN.\nLinearRegression does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values') in model 77 in generation 0: UnivariateRegression
# Model Number: 78 with model MultivariateRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but not future_regressor supplied.") in model 78 in generation 0: MultivariateRegression
# Model Number: 79 with model UnivariateMotif in generation 0 of 10
# Model Number: 80 with model MultivariateMotif in generation 0 of 10
# Model Number: 81 with model SectionalMotif in generation 0 of 10
# Model Number: 82 with model NVAR in generation 0 of 10
# Model Number: 83 with model Theta in generation 0 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.380e+06, tolerance: 6.091e+02
#   model = cd_fast.enet_coordinate_descent(
# Model Number: 84 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 84 in generation 0: ARDL
# Model Number: 85 with model ARCH in generation 0 of 10
# Template Eval Error: ImportError('`arch` package must be installed from pip') in model 85 in generation 0: ARCH
# Model Number: 86 with model MetricMotif in generation 0 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 86 in generation 0: MetricMotif
# Model Number: 87 with model ETS in generation 0 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.5498e-25): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# Model Number: 88 with model LastValueNaive in generation 0 of 10
# Model Number: 89 with model ConstantNaive in generation 0 of 10
# Model Number: 90 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 90 in generation 0: VAR
# Model Number: 91 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 91 in generation 0: VAR
# Model Number: 92 with model MultivariateMotif in generation 0 of 10
# Model Number: 93 with model MetricMotif in generation 0 of 10
# Model Number: 94 with model UnobservedComponents in generation 0 of 10
# Model Number: 95 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: ValueError('Model UnobservedComponents returned NaN for one or more series. fail_on_forecast_nan=True') in model 95 in generation 0: UnobservedComponents
# Model Number: 96 with model GLS in generation 0 of 10
# Template Eval Error: Exception('Transformer KalmanSmoothing failed on fit') in model 96 in generation 0: GLS
# Model Number: 97 with model AverageValueNaive in generation 0 of 10
# Model Number: 98 with model ARDL in generation 0 of 10
# Template Eval Error: Exception('Transformer HolidayTransformer failed on fit') in model 98 in generation 0: ARDL
# Model Number: 99 with model SectionalMotif in generation 0 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 99 in generation 0: SectionalMotif
# Model Number: 100 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue, try 1.23.1 {as of 06-2023}') in model 100 in generation 0: GluonTS
# Model Number: 101 with model ConstantNaive in generation 0 of 10
# Template Eval Error: Exception('Transformer MinMaxScaler failed on fit') in model 101 in generation 0: ConstantNaive
# Model Number: 102 with model UnivariateMotif in generation 0 of 10
# Model Number: 103 with model UnobservedComponents in generation 0 of 10
# Model Number: 104 with model GLS in generation 0 of 10
# Model Number: 105 with model WindowRegression in generation 0 of 10
# Model Number: 106 with model MultivariateMotif in generation 0 of 10
# Model Number: 107 with model UnobservedComponents in generation 0 of 10
# Model Number: 108 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue, try 1.23.1 {as of 06-2023}') in model 108 in generation 0: GluonTS
# Model Number: 109 with model GLS in generation 0 of 10
# Model Number: 110 with model LastValueNaive in generation 0 of 10
# Model Number: 111 with model ETS in generation 0 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 111 in generation 0: ETS
# Model Number: 112 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ValueError('Model DatepartRegression returned NaN for one or more series. fail_on_forecast_nan=True') in model 112 in generation 0: DatepartRegression
# Model Number: 113 with model UnobservedComponents in generation 0 of 10
# Model Number: 114 with model SeasonalNaive in generation 0 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_regression.py:494: UserWarning: One or more samples have no neighbors within specified radius; predicting NaN.
#   warnings.warn(empty_warning_msg)
# Model Number: 115 with model MultivariateMotif in generation 0 of 10
# Model Number: 116 with model UnivariateMotif in generation 0 of 10
# Model Number: 117 with model LastValueNaive in generation 0 of 10
# Model Number: 118 with model ConstantNaive in generation 0 of 10
# Model Number: 119 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 119 in generation 0: VAR
# Model Number: 120 with model ETS in generation 0 of 10
# Model Number: 121 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 121 in generation 0: VAR
# Model Number: 122 with model UnobservedComponents in generation 0 of 10
# Model Number: 123 with model Theta in generation 0 of 10
# Model Number: 124 with model Theta in generation 0 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 124 in generation 0: Theta
# Model Number: 125 with model ConstantNaive in generation 0 of 10
# Template Eval Error: Exception('Transformer KalmanSmoothing failed on fit') in model 125 in generation 0: ConstantNaive
# Model Number: 126 with model GLS in generation 0 of 10
# Template Eval Error: Exception('Transformer HolidayTransformer failed on fit') in model 126 in generation 0: GLS
# Model Number: 127 with model SeasonalNaive in generation 0 of 10
# Model Number: 128 with model MetricMotif in generation 0 of 10
# Model Number: 129 with model Theta in generation 0 of 10
# Model Number: 130 with model VECM in generation 0 of 10
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 130 in generation 0: VECM
# Model Number: 131 with model ARDL in generation 0 of 10
# Model Number: 132 with model Theta in generation 0 of 10
# Model Number: 133 with model MultivariateRegression in generation 0 of 10
# Template Eval Error: Exception('Transformer RegressionFilter failed on fit') in model 133 in generation 0: MultivariateRegression
# Model Number: 134 with model UnobservedComponents in generation 0 of 10
# Model Number: 135 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('Unknown Distance Metric: kulsinski') in model 135 in generation 0: SectionalMotif
# Model Number: 136 with model LastValueNaive in generation 0 of 10
# Model Number: 137 with model FBProphet in generation 0 of 10
# 19:03:45 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 137 in generation 0: FBProphet
# Model Number: 138 with model ETS in generation 0 of 10
# Model Number: 139 with model UnivariateMotif in generation 0 of 10
# Model Number: 140 with model ConstantNaive in generation 0 of 10
# Model Number: 141 with model UnivariateMotif in generation 0 of 10
# Model Number: 142 with model NVAR in generation 0 of 10
# Model Number: 143 with model MultivariateMotif in generation 0 of 10
# Model Number: 144 with model UnivariateMotif in generation 0 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 144 in generation 0: UnivariateMotif
# Model Number: 145 with model ETS in generation 0 of 10
# Model Number: 146 with model NVAR in generation 0 of 10
# Model Number: 147 with model ARDL in generation 0 of 10
# Model Number: 148 with model ETS in generation 0 of 10
# Model Number: 149 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue, try 1.23.1 {as of 06-2023}') in model 149 in generation 0: GluonTS
# Model Number: 150 with model UnivariateMotif in generation 0 of 10
# Model Number: 151 with model ARCH in generation 0 of 10
# Template Eval Error: ImportError('`arch` package must be installed from pip') in model 151 in generation 0: ARCH
# Model Number: 152 with model GLM in generation 0 of 10
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:445: RuntimeWarning: divide by zero encountered in divide
#   endog_mu = self._clean(endog / mu)
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:143: RuntimeWarning: divide by zero encountered in divide
#   return 1. / (self.link.deriv(mu)**2 * self.variance(mu))
# Template Eval Error: ValueError('NaN, inf or invalid value detected in weights, estimation infeasible.') in model 152 in generation 0: GLM
# Model Number: 153 with model UnivariateMotif in generation 0 of 10
# Template Eval Error: ValueError('kth(=5) out of bounds (1)') in model 153 in generation 0: UnivariateMotif
# Model Number: 154 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 154 in generation 0: VAR
# Model Number: 155 with model GLS in generation 0 of 10
# Model Number: 156 with model AverageValueNaive in generation 0 of 10
# Model Number: 157 with model MultivariateMotif in generation 0 of 10
# Model Number: 158 with model ARIMA in generation 0 of 10
# Model Number: 159 with model ETS in generation 0 of 10
# Model Number: 160 with model SectionalMotif in generation 0 of 10
# Model Number: 161 with model GLM in generation 0 of 10
# Model Number: 162 with model LastValueNaive in generation 0 of 10
# Model Number: 163 with model NVAR in generation 0 of 10
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# Model Number: 164 with model SectionalMotif in generation 0 of 10
# Model Number: 165 with model ConstantNaive in generation 0 of 10
# Model Number: 166 with model GLM in generation 0 of 10
# Model Number: 167 with model NVAR in generation 0 of 10
# Model Number: 168 with model GLM in generation 0 of 10
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/generalized_linear_model.py:308: DomainWarning: The InversePower link function does not respect the domain of the Gamma family.
#   warnings.warn((f"The {type(family.link).__name__} link function "
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.5498e-25): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# Model Number: 169 with model VECM in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 169 in generation 0: VECM
# Model Number: 170 with model UnivariateMotif in generation 0 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 170 in generation 0: UnivariateMotif
# Model Number: 171 with model Theta in generation 0 of 10
# Model Number: 172 with model MultivariateMotif in generation 0 of 10
# Model Number: 173 with model UnobservedComponents in generation 0 of 10
# Model Number: 174 with model GLM in generation 0 of 10
# Template Eval Error: ValueError('NaN, inf or invalid value detected in weights, estimation infeasible.') in model 174 in generation 0: GLM
# Model Number: 175 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 175 in generation 0: ARDL
# Model Number: 176 with model ConstantNaive in generation 0 of 10
# Model Number: 177 with model ConstantNaive in generation 0 of 10
# Model Number: 178 with model UnivariateMotif in generation 0 of 10
# Model Number: 179 with model SeasonalNaive in generation 0 of 10
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/links.py:527: RuntimeWarning: overflow encountered in exp
#   return np.exp(z)
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1402: RuntimeWarning: divide by zero encountered in divide
#   endog_mu = self._clean(endog / mu)
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1406: RuntimeWarning: divide by zero encountered in log
#   resid_dev -= endog_alpha * np.log(endog_alpha / mu_alpha)
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1406: RuntimeWarning: invalid value encountered in log
#   resid_dev -= endog_alpha * np.log(endog_alpha / mu_alpha)
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/varfuncs.py:265: RuntimeWarning: overflow encountered in square
#   return p + self.alpha*p**2
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:143: RuntimeWarning: invalid value encountered in multiply
#   return 1. / (self.link.deriv(mu)**2 * self.variance(mu))
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/generalized_linear_model.py:1328: RuntimeWarning: invalid value encountered in multiply
#   wlsendog = (lin_pred + self.family.link.deriv(mu) * (self.endog-mu)
# Model Number: 180 with model UnobservedComponents in generation 0 of 10
# Model Number: 181 with model SectionalMotif in generation 0 of 10
# Model Number: 182 with model ConstantNaive in generation 0 of 10
# Model Number: 183 with model MultivariateMotif in generation 0 of 10
# Model Number: 184 with model MultivariateRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but not future_regressor supplied.") in model 184 in generation 0: MultivariateRegression
# Model Number: 185 with model UnobservedComponents in generation 0 of 10
# Model Number: 186 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 186 in generation 0: VECM
# New Generation: 1 of 10
# Model Number: 187 with model ETS in generation 1 of 10
# Model Number: 188 with model FBProphet in generation 1 of 10
# Template Eval Error: Exception('Transformer HolidayTransformer failed on fit') in model 188 in generation 1: FBProphet
# Model Number: 189 with model MetricMotif in generation 1 of 10
# Model Number: 190 with model LastValueNaive in generation 1 of 10
# Model Number: 191 with model WindowRegression in generation 1 of 10
# Model Number: 192 with model LastValueNaive in generation 1 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 192 in generation 1: LastValueNaive
# Model Number: 193 with model SeasonalNaive in generation 1 of 10
# Model Number: 194 with model ARIMA in generation 1 of 10
# Template Eval Error: Exception('Transformer HolidayTransformer failed on fit') in model 194 in generation 1: ARIMA
# Model Number: 195 with model FBProphet in generation 1 of 10
# Model Number: 196 with model UnobservedComponents in generation 1 of 10
# Model Number: 197 with model MultivariateMotif in generation 1 of 10
# Model Number: 198 with model ETS in generation 1 of 10
# Model Number: 199 with model GLM in generation 1 of 10
# Template Eval Error: ValueError('regression_type=user and no future_regressor passed') in model 199 in generation 1: GLM
# Model Number: 200 with model Theta in generation 1 of 10
# Model Number: 201 with model NVAR in generation 1 of 10
# Model Number: 202 with model GLS in generation 1 of 10
# Model Number: 203 with model DatepartRegression in generation 1 of 10
# Model Number: 204 with model DatepartRegression in generation 1 of 10
# Model Number: 205 with model ETS in generation 1 of 10
# Model Number: 206 with model UnobservedComponents in generation 1 of 10
# Model Number: 207 with model MultivariateMotif in generation 1 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Model Number: 208 with model LastValueNaive in generation 1 of 10
# Model Number: 209 with model UnivariateMotif in generation 1 of 10
# Model Number: 210 with model DatepartRegression in generation 1 of 10
# Template Eval Error: Exception('Transformer BTCD failed on fit') in model 210 in generation 1: DatepartRegression
# Model Number: 211 with model LastValueNaive in generation 1 of 10
# Model Number: 212 with model UnivariateMotif in generation 1 of 10
# Model Number: 213 with model SeasonalNaive in generation 1 of 10
# Model Number: 214 with model SectionalMotif in generation 1 of 10
# Model Number: 215 with model SeasonalNaive in generation 1 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 215 in generation 1: SeasonalNaive
# Model Number: 216 with model GLS in generation 1 of 10
# Model Number: 217 with model LastValueNaive in generation 1 of 10
# Model Number: 218 with model ETS in generation 1 of 10
# Model Number: 219 with model ETS in generation 1 of 10
# Model Number: 220 with model FBProphet in generation 1 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 220 in generation 1: FBProphet
# Model Number: 221 with model WindowRegression in generation 1 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/experimental/enable_hist_gradient_boosting.py:16: UserWarning: Since version 1.0, it is not needed to import enable_hist_gradient_boosting anymore. HistGradientBoostingClassifier and HistGradientBoostingRegressor are now stable and can be normally imported from sklearn.ensemble.
#   warnings.warn(
# Model Number: 222 with model ETS in generation 1 of 10
# Model Number: 223 with model GLM in generation 1 of 10
# Template Eval Error: ValueError('The first guess on the deviance function returned a nan.  This could be a boundary  problem and should be reported.') in model 223 in generation 1: GLM
# Model Number: 224 with model WindowRegression in generation 1 of 10
# Template Eval Error: Exception('Transformer KalmanSmoothing failed on fit') in model 224 in generation 1: WindowRegression
# Model Number: 225 with model MultivariateMotif in generation 1 of 10
# Model Number: 226 with model SectionalMotif in generation 1 of 10
# Template Eval Error: Exception('Transformer HolidayTransformer failed on fit') in model 226 in generation 1: SectionalMotif
# Model Number: 227 with model GLS in generation 1 of 10
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1406: RuntimeWarning: invalid value encountered in log
#   resid_dev -= endog_alpha * np.log(endog_alpha / mu_alpha)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Model Number: 228 with model ARIMA in generation 1 of 10
# Model Number: 229 with model MultivariateMotif in generation 1 of 10
# Model Number: 230 with model UnobservedComponents in generation 1 of 10
# Model Number: 231 with model AverageValueNaive in generation 1 of 10
# Model Number: 232 with model ConstantNaive in generation 1 of 10
# Model Number: 233 with model UnobservedComponents in generation 1 of 10
# Template Eval Error: Exception('Transformer HolidayTransformer failed on fit') in model 233 in generation 1: UnobservedComponents
# Model Number: 234 with model SectionalMotif in generation 1 of 10
# Model Number: 235 with model ETS in generation 1 of 10
# Model Number: 236 with model UnobservedComponents in generation 1 of 10
# Model Number: 237 with model ETS in generation 1 of 10
# Model Number: 238 with model Theta in generation 1 of 10
# Model Number: 239 with model UnobservedComponents in generation 1 of 10
# Model Number: 240 with model UnivariateMotif in generation 1 of 10
# Model Number: 241 with model LastValueNaive in generation 1 of 10
# Template Eval Error: Exception('Transformer BTCD failed on fit') in model 241 in generation 1: LastValueNaive
# Model Number: 242 with model WindowRegression in generation 1 of 10
# Model Number: 243 with model GLS in generation 1 of 10
# Model Number: 244 with model LastValueNaive in generation 1 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Model Number: 245 with model MultivariateRegression in generation 1 of 10
# Model Number: 246 with model GLS in generation 1 of 10
# Model Number: 247 with model ConstantNaive in generation 1 of 10
# Model Number: 248 with model SeasonalNaive in generation 1 of 10
# Model Number: 249 with model SeasonalNaive in generation 1 of 10
# Model Number: 250 with model Theta in generation 1 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.376e+06, tolerance: 6.108e+02
#   model = cd_fast.enet_coordinate_descent(
# Model Number: 251 with model ARIMA in generation 1 of 10
# Model Number: 252 with model SeasonalNaive in generation 1 of 10
# Model Number: 253 with model MultivariateRegression in generation 1 of 10
# Model Number: 254 with model GLS in generation 1 of 10
# Model Number: 255 with model DatepartRegression in generation 1 of 10
# Template Eval Error: Exception('Transformer BTCD failed on fit') in model 255 in generation 1: DatepartRegression
# Model Number: 256 with model AverageValueNaive in generation 1 of 10
# Model Number: 257 with model MultivariateMotif in generation 1 of 10
# Model Number: 258 with model WindowRegression in generation 1 of 10
# Model Number: 259 with model MultivariateMotif in generation 1 of 10
# Model Number: 260 with model LastValueNaive in generation 1 of 10
# Model Number: 261 with model WindowRegression in generation 1 of 10
# Model Number: 262 with model SeasonalNaive in generation 1 of 10
# Model Number: 263 with model ConstantNaive in generation 1 of 10
# Model Number: 264 with model DatepartRegression in generation 1 of 10
# Model Number: 265 with model Theta in generation 1 of 10
# Model Number: 266 with model UnobservedComponents in generation 1 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.376e+06, tolerance: 6.108e+02
#   model = cd_fast.enet_coordinate_descent(
# Model Number: 267 with model WindowRegression in generation 1 of 10
# Model Number: 268 with model GLM in generation 1 of 10
# Model Number: 269 with model MultivariateMotif in generation 1 of 10
# Model Number: 270 with model MetricMotif in generation 1 of 10
# Template Eval Error: ValueError('cannot reshape array of size 10 into shape (10,1,5)') in model 270 in generation 1: MetricMotif
# Model Number: 271 with model Theta in generation 1 of 10
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 271 in generation 1: Theta
# Model Number: 272 with model SeasonalNaive in generation 1 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 272 in generation 1: SeasonalNaive
# Model Number: 273 with model AverageValueNaive in generation 1 of 10
# Model Number: 274 with model SeasonalNaive in generation 1 of 10
# Template Eval Error: Exception('Transformer KalmanSmoothing failed on fit') in model 274 in generation 1: SeasonalNaive
# Model Number: 275 with model MultivariateRegression in generation 1 of 10
# /usr/local/lib/python3.10/dist-packages/autots/tools/percentile.py:47: RuntimeWarning: All-NaN slice encountered
#   max_val = np.nanmax(arr)
# Model Number: 276 with model ConstantNaive in generation 1 of 10
# Model Number: 277 with model LastValueNaive in generation 1 of 10
# Model Number: 278 with model GLS in generation 1 of 10
# Model Number: 279 with model MetricMotif in generation 1 of 10
# Model Number: 280 with model NVAR in generation 1 of 10
# Model Number: 281 with model MultivariateRegression in generation 1 of 10
# Template Eval Error: Exception('Transformer KalmanSmoothing failed on fit') in model 281 in generation 1: MultivariateRegression
# Model Number: 282 with model GLM in generation 1 of 10
# Template Eval Error: ValueError('regression_type=user and no future_regressor passed') in model 282 in generation 1: GLM
# Model Number: 283 with model GLS in generation 1 of 10
# Model Number: 284 with model UnivariateMotif in generation 1 of 10
# Model Number: 285 with model DatepartRegression in generation 1 of 10
# Model Number: 286 with model ETS in generation 1 of 10
# Model Number: 287 with model ETS in generation 1 of 10
# Model Number: 288 with model UnobservedComponents in generation 1 of 10
# Template Eval Error: Exception('Transformer RegressionFilter failed on fit') in model 288 in generation 1: UnobservedComponents
# Model Number: 289 with model UnobservedComponents in generation 1 of 10
# Model Number: 290 with model Theta in generation 1 of 10
# Model Number: 291 with model SectionalMotif in generation 1 of 10
# Template Eval Error: Exception('Transformer BTCD failed on fit') in model 291 in generation 1: SectionalMotif
# Model Number: 292 with model SeasonalNaive in generation 1 of 10
# Model Number: 293 with model Theta in generation 1 of 10
# Model Number: 294 with model DatepartRegression in generation 1 of 10
# Model Number: 295 with model LastValueNaive in generation 1 of 10
# Model Number: 296 with model ConstantNaive in generation 1 of 10
# Model Number: 297 with model LastValueNaive in generation 1 of 10
# Model Number: 298 with model MultivariateMotif in generation 1 of 10
# Model Number: 299 with model DatepartRegression in generation 1 of 10
# Model Number: 300 with model SeasonalNaive in generation 1 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 300 in generation 1: SeasonalNaive
# Model Number: 301 with model ETS in generation 1 of 10
# Model Number: 302 with model ETS in generation 1 of 10
# Model Number: 303 with model UnobservedComponents in generation 1 of 10
# Model Number: 304 with model ConstantNaive in generation 1 of 10
# Model Number: 305 with model AverageValueNaive in generation 1 of 10
# Model Number: 306 with model MultivariateMotif in generation 1 of 10
# Model Number: 307 with model DatepartRegression in generation 1 of 10
# Model Number: 308 with model UnivariateMotif in generation 1 of 10
# Model Number: 309 with model ARDL in generation 1 of 10
# Template Eval Error: Exception('Transformer MinMaxScaler failed on fit') in model 309 in generation 1: ARDL
# Model Number: 310 with model DatepartRegression in generation 1 of 10
# Template Eval Error: ValueError('Model DatepartRegression returned NaN for one or more series. fail_on_forecast_nan=True') in model 310 in generation 1: DatepartRegression
# Model Number: 311 with model Theta in generation 1 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_regression.py:494: UserWarning: One or more samples have no neighbors within specified radius; predicting NaN.
#   warnings.warn(empty_warning_msg)
# New Generation: 2 of 10
# Model Number: 312 with model SeasonalNaive in generation 2 of 10
# Model Number: 313 with model SeasonalNaive in generation 2 of 10
# Model Number: 314 with model GLS in generation 2 of 10
# Model Number: 315 with model ETS in generation 2 of 10
# Model Number: 316 with model DatepartRegression in generation 2 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 316 in generation 2: DatepartRegression
# Model Number: 317 with model SeasonalNaive in generation 2 of 10
# Template Eval Error: Exception('Transformer KalmanSmoothing failed on fit') in model 317 in generation 2: SeasonalNaive
# Model Number: 318 with model MultivariateMotif in generation 2 of 10
# Model Number: 319 with model MultivariateMotif in generation 2 of 10
# Model Number: 320 with model LastValueNaive in generation 2 of 10
# Model Number: 321 with model ETS in generation 2 of 10
# Model Number: 322 with model UnobservedComponents in generation 2 of 10
# Model Number: 323 with model LastValueNaive in generation 2 of 10
# Model Number: 324 with model MultivariateRegression in generation 2 of 10
# Epoch 1/50
# 6/6 [==============================] - 6s 10ms/step - loss: 0.0591
# Epoch 2/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0507
# Epoch 3/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0495
# Epoch 4/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0509
# Epoch 5/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0493
# Epoch 6/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0503
# Epoch 7/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0499
# Epoch 8/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0494
# Epoch 9/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0498
# Epoch 10/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0495
# Epoch 11/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0492
# Epoch 12/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0505
# Epoch 13/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0496
# Epoch 14/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0492
# Epoch 15/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0502
# Epoch 16/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0495
# Epoch 17/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0490
# Epoch 18/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0491
# Epoch 19/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0509
# Epoch 20/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0502
# Epoch 21/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0492
# Epoch 22/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0495
# Epoch 23/50
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0499
# Epoch 24/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0496
# Epoch 25/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0492
# Epoch 26/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0485
# Epoch 27/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0507
# Epoch 28/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0497
# Epoch 29/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0490
# Epoch 30/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0502
# Epoch 31/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0501
# Epoch 32/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0497
# Epoch 33/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0509
# Epoch 34/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0506
# Epoch 35/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0497
# Epoch 36/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0492
# Epoch 37/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0491
# Epoch 38/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0500
# Epoch 39/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0503
# Epoch 40/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0500
# Epoch 41/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0492
# Epoch 42/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0500
# Epoch 43/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0495
# Epoch 44/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0492
# Epoch 45/50
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0497
# Epoch 46/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0486
# Epoch 47/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0485
# Epoch 48/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0496
# Epoch 49/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0496
# Epoch 50/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0501
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# Model Number: 325 with model AverageValueNaive in generation 2 of 10
# Model Number: 326 with model GLS in generation 2 of 10
# Template Eval Error: Exception('Transformer BTCD failed on fit') in model 326 in generation 2: GLS
# Model Number: 327 with model MultivariateMotif in generation 2 of 10
# Model Number: 328 with model ConstantNaive in generation 2 of 10
# Model Number: 329 with model LastValueNaive in generation 2 of 10
# Model Number: 330 with model ConstantNaive in generation 2 of 10
# Model Number: 331 with model DatepartRegression in generation 2 of 10
# Model Number: 332 with model DatepartRegression in generation 2 of 10
# Model Number: 333 with model GLM in generation 2 of 10
# Model Number: 334 with model DatepartRegression in generation 2 of 10
# Template Eval Error: Exception('Transformer ReplaceConstant failed on fit') in model 334 in generation 2: DatepartRegression
# Model Number: 335 with model LastValueNaive in generation 2 of 10
# Model Number: 336 with model GLM in generation 2 of 10
# Template Eval Error: ValueError('regression_type=user and no future_regressor passed') in model 336 in generation 2: GLM
# Model Number: 337 with model AverageValueNaive in generation 2 of 10
# Model Number: 338 with model GLM in generation 2 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Model Number: 339 with model SeasonalNaive in generation 2 of 10
# Model Number: 340 with model GLS in generation 2 of 10
# Model Number: 341 with model ConstantNaive in generation 2 of 10
# Model Number: 342 with model MultivariateRegression in generation 2 of 10
# Model Number: 343 with model ConstantNaive in generation 2 of 10
# Model Number: 344 with model ETS in generation 2 of 10
# Model Number: 345 with model SeasonalNaive in generation 2 of 10
# Model Number: 346 with model GLS in generation 2 of 10
# Model Number: 347 with model MetricMotif in generation 2 of 10
# Model Number: 348 with model DatepartRegression in generation 2 of 10
# Template Eval Error: Exception('Transformer RegressionFilter failed on fit') in model 348 in generation 2: DatepartRegression
# Model Number: 349 with model UnivariateMotif in generation 2 of 10
# Model Number: 350 with model SeasonalNaive in generation 2 of 10
# Model Number: 351 with model SeasonalNaive in generation 2 of 10
# Model Number: 352 with model MultivariateRegression in generation 2 of 10
# Template Eval Error: Exception('Transformer BTCD failed on fit') in model 352 in generation 2: MultivariateRegression
# Model Number: 353 with model Theta in generation 2 of 10
# Model Number: 354 with model AverageValueNaive in generation 2 of 10
# Model Number: 355 with model GLS in generation 2 of 10
# Model Number: 356 with model ARIMA in generation 2 of 10
# Template Eval Error: Exception('Transformer Cointegration failed on fit') in model 356 in generation 2: ARIMA
# Model Number: 357 with model DatepartRegression in generation 2 of 10
# Model Number: 358 with model Theta in generation 2 of 10
# Model Number: 359 with model SectionalMotif in generation 2 of 10
# Model Number: 360 with model NVAR in generation 2 of 10
# Model Number: 361 with model MetricMotif in generation 2 of 10
# Model Number: 362 with model DatepartRegression in generation 2 of 10
# Template Eval Error: ValueError('Model DatepartRegression returned NaN for one or more series. fail_on_forecast_nan=True') in model 362 in generation 2: DatepartRegression
# Model Number: 363 with model LastValueNaive in generation 2 of 10
# Model Number: 364 with model GLS in generation 2 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_regression.py:494: UserWarning: One or more samples have no neighbors within specified radius; predicting NaN.
#   warnings.warn(empty_warning_msg)
# Model Number: 365 with model UnobservedComponents in generation 2 of 10
# Model Number: 366 with model SectionalMotif in generation 2 of 10
# Model Number: 367 with model SectionalMotif in generation 2 of 10
# Model Number: 368 with model SectionalMotif in generation 2 of 10
# Model Number: 369 with model MultivariateRegression in generation 2 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_linear_loss.py:289: RuntimeWarning: invalid value encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# Model Number: 370 with model SeasonalNaive in generation 2 of 10
# Model Number: 371 with model AverageValueNaive in generation 2 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 371 in generation 2: AverageValueNaive
# Model Number: 372 with model ETS in generation 2 of 10
# Model Number: 373 with model GLM in generation 2 of 10
# Model Number: 374 with model AverageValueNaive in generation 2 of 10
# Model Number: 375 with model SectionalMotif in generation 2 of 10
# Model Number: 376 with model FBProphet in generation 2 of 10
# Template Eval Error: Exception('Transformer Cointegration failed on fit') in model 376 in generation 2: FBProphet
# Model Number: 377 with model ConstantNaive in generation 2 of 10
# Model Number: 378 with model NVAR in generation 2 of 10
# Model Number: 379 with model LastValueNaive in generation 2 of 10
# Model Number: 380 with model WindowRegression in generation 2 of 10
# Model Number: 381 with model WindowRegression in generation 2 of 10
# Model Number: 382 with model MultivariateMotif in generation 2 of 10
# Model Number: 383 with model ConstantNaive in generation 2 of 10
# Model Number: 384 with model LastValueNaive in generation 2 of 10
# Model Number: 385 with model DatepartRegression in generation 2 of 10
# Template Eval Error: ValueError('Model DatepartRegression returned NaN for one or more series. fail_on_forecast_nan=True') in model 385 in generation 2: DatepartRegression
# Model Number: 386 with model UnivariateMotif in generation 2 of 10
# Model Number: 387 with model MultivariateRegression in generation 2 of 10
# Template Eval Error: Exception('Transformer Cointegration failed on fit') in model 387 in generation 2: MultivariateRegression
# Model Number: 388 with model UnivariateMotif in generation 2 of 10
# Model Number: 389 with model ARIMA in generation 2 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_regression.py:494: UserWarning: One or more samples have no neighbors within specified radius; predicting NaN.
#   warnings.warn(empty_warning_msg)
# Model Number: 390 with model LastValueNaive in generation 2 of 10
# Model Number: 391 with model DatepartRegression in generation 2 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 391 in generation 2: DatepartRegression
# Model Number: 392 with model WindowRegression in generation 2 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 392 in generation 2: WindowRegression
# Model Number: 393 with model MetricMotif in generation 2 of 10
# Model Number: 394 with model SectionalMotif in generation 2 of 10
# Model Number: 395 with model ETS in generation 2 of 10
# Model Number: 396 with model Theta in generation 2 of 10
# Model Number: 397 with model FBProphet in generation 2 of 10
# Model Number: 398 with model Theta in generation 2 of 10
# Model Number: 399 with model UnobservedComponents in generation 2 of 10
# Model Number: 400 with model WindowRegression in generation 2 of 10
# Model Number: 401 with model MultivariateMotif in generation 2 of 10
# Model Number: 402 with model Theta in generation 2 of 10
# Model Number: 403 with model ETS in generation 2 of 10
# Model Number: 404 with model LastValueNaive in generation 2 of 10
# Model Number: 405 with model GLM in generation 2 of 10
# Model Number: 406 with model Theta in generation 2 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.376e+06, tolerance: 6.108e+02
#   model = cd_fast.enet_coordinate_descent(
# Model Number: 407 with model ETS in generation 2 of 10
# Model Number: 408 with model DatepartRegression in generation 2 of 10
# Model Number: 409 with model UnobservedComponents in generation 2 of 10
# Model Number: 410 with model MultivariateMotif in generation 2 of 10
# Model Number: 411 with model LastValueNaive in generation 2 of 10
# Model Number: 412 with model MetricMotif in generation 2 of 10
# Model Number: 413 with model GLM in generation 2 of 10
# Model Number: 414 with model WindowRegression in generation 2 of 10
# Template Eval Error: Exception('Transformer Cointegration failed on fit') in model 414 in generation 2: WindowRegression
# Model Number: 415 with model WindowRegression in generation 2 of 10
# Model Number: 416 with model AverageValueNaive in generation 2 of 10
# Model Number: 417 with model Theta in generation 2 of 10
# Model Number: 418 with model UnobservedComponents in generation 2 of 10
# Model Number: 419 with model ARIMA in generation 2 of 10
# Model Number: 420 with model SectionalMotif in generation 2 of 10
# Model Number: 421 with model UnobservedComponents in generation 2 of 10
# Model Number: 422 with model Theta in generation 2 of 10
# Model Number: 423 with model SectionalMotif in generation 2 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 423 in generation 2: SectionalMotif
# Model Number: 424 with model SeasonalNaive in generation 2 of 10
# Model Number: 425 with model ARIMA in generation 2 of 10
# Model Number: 426 with model UnobservedComponents in generation 2 of 10
# Model Number: 427 with model WindowRegression in generation 2 of 10
# Model Number: 428 with model MetricMotif in generation 2 of 10
# Model Number: 429 with model GLS in generation 2 of 10
# Model Number: 430 with model UnobservedComponents in generation 2 of 10
# Model Number: 431 with model DatepartRegression in generation 2 of 10
# Model Number: 432 with model MultivariateMotif in generation 2 of 10
# Model Number: 433 with model DatepartRegression in generation 2 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 433 in generation 2: DatepartRegression
# Model Number: 434 with model UnobservedComponents in generation 2 of 10
# Model Number: 435 with model MultivariateRegression in generation 2 of 10
# Model Number: 436 with model MultivariateRegression in generation 2 of 10
# New Generation: 3 of 10
# Model Number: 437 with model MetricMotif in generation 3 of 10
# Model Number: 438 with model Theta in generation 3 of 10
# Model Number: 439 with model ConstantNaive in generation 3 of 10
# Model Number: 440 with model SeasonalNaive in generation 3 of 10
# Model Number: 441 with model SectionalMotif in generation 3 of 10
# Model Number: 442 with model WindowRegression in generation 3 of 10
# Model Number: 443 with model ARIMA in generation 3 of 10
# Model Number: 444 with model WindowRegression in generation 3 of 10
# Model Number: 445 with model SectionalMotif in generation 3 of 10
# Model Number: 446 with model ARIMA in generation 3 of 10
# Model Number: 447 with model ETS in generation 3 of 10
# Model Number: 448 with model ConstantNaive in generation 3 of 10
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 448 in generation 3: ConstantNaive
# Model Number: 449 with model DatepartRegression in generation 3 of 10
# Template Eval Error: ValueError('Model DatepartRegression returned NaN for one or more series. fail_on_forecast_nan=True') in model 449 in generation 3: DatepartRegression
# Model Number: 450 with model LastValueNaive in generation 3 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_regression.py:494: UserWarning: One or more samples have no neighbors within specified radius; predicting NaN.
#   warnings.warn(empty_warning_msg)
# Model Number: 451 with model MetricMotif in generation 3 of 10
# Model Number: 452 with model LastValueNaive in generation 3 of 10
# Model Number: 453 with model SectionalMotif in generation 3 of 10
# Model Number: 454 with model NVAR in generation 3 of 10
# Model Number: 455 with model ETS in generation 3 of 10
# Model Number: 456 with model WindowRegression in generation 3 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 456 in generation 3: WindowRegression
# Model Number: 457 with model SeasonalNaive in generation 3 of 10
# Model Number: 458 with model MultivariateMotif in generation 3 of 10
# Template Eval Error: Exception('Transformer ReplaceConstant failed on fit') in model 458 in generation 3: MultivariateMotif
# Model Number: 459 with model DatepartRegression in generation 3 of 10
# Model Number: 460 with model ConstantNaive in generation 3 of 10
# Model Number: 461 with model GLS in generation 3 of 10
# Model Number: 462 with model Theta in generation 3 of 10
# Model Number: 463 with model UnobservedComponents in generation 3 of 10
# Model Number: 464 with model WindowRegression in generation 3 of 10
# Model Number: 465 with model ConstantNaive in generation 3 of 10
# Model Number: 466 with model MultivariateMotif in generation 3 of 10
# Model Number: 467 with model FBProphet in generation 3 of 10
# Model Number: 468 with model ConstantNaive in generation 3 of 10
# Model Number: 469 with model UnivariateMotif in generation 3 of 10
# Model Number: 470 with model UnivariateMotif in generation 3 of 10
# Model Number: 471 with model LastValueNaive in generation 3 of 10
# Model Number: 472 with model GLS in generation 3 of 10
# Model Number: 473 with model DatepartRegression in generation 3 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 473 in generation 3: DatepartRegression
# Model Number: 474 with model LastValueNaive in generation 3 of 10
# Model Number: 475 with model SeasonalNaive in generation 3 of 10
# Model Number: 476 with model UnivariateMotif in generation 3 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Model Number: 477 with model GLM in generation 3 of 10
# Model Number: 478 with model DatepartRegression in generation 3 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 478 in generation 3: DatepartRegression
# Model Number: 479 with model GLM in generation 3 of 10
# Template Eval Error: ValueError('The first guess on the deviance function returned a nan.  This could be a boundary  problem and should be reported.') in model 479 in generation 3: GLM
# Model Number: 480 with model FBProphet in generation 3 of 10
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/generalized_linear_model.py:1342: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1406: RuntimeWarning: divide by zero encountered in log
#   resid_dev -= endog_alpha * np.log(endog_alpha / mu_alpha)
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1406: RuntimeWarning: invalid value encountered in log
#   resid_dev -= endog_alpha * np.log(endog_alpha / mu_alpha)
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1406: RuntimeWarning: invalid value encountered in multiply
#   resid_dev -= endog_alpha * np.log(endog_alpha / mu_alpha)
# Model Number: 481 with model UnivariateMotif in generation 3 of 10
# Template Eval Error: Exception('Transformer StandardScaler failed on inverse') in model 481 in generation 3: UnivariateMotif
# Model Number: 482 with model ETS in generation 3 of 10
# Model Number: 483 with model UnobservedComponents in generation 3 of 10
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py:351: RuntimeWarning: overflow encountered in exp
#   result = func(self.values, **kwargs)
# /usr/local/lib/python3.10/dist-packages/sklearn/decomposition/_fastica.py:583: UserWarning: Ignoring n_components with whiten=False.
#   warnings.warn("Ignoring n_components with whiten=False.")
# Model Number: 484 with model UnobservedComponents in generation 3 of 10
# Model Number: 485 with model SectionalMotif in generation 3 of 10
# Model Number: 486 with model LastValueNaive in generation 3 of 10
# Model Number: 487 with model DatepartRegression in generation 3 of 10
# Model Number: 488 with model GLM in generation 3 of 10
# Model Number: 489 with model FBProphet in generation 3 of 10
# Model Number: 490 with model LastValueNaive in generation 3 of 10
# Model Number: 491 with model ETS in generation 3 of 10
# Model Number: 492 with model GLS in generation 3 of 10
# Model Number: 493 with model ARDL in generation 3 of 10
# Model Number: 494 with model SeasonalNaive in generation 3 of 10
# Model Number: 495 with model MultivariateMotif in generation 3 of 10
# Model Number: 496 with model DatepartRegression in generation 3 of 10
# Template Eval Error: XGBoostError('[19:06:26] /workspace/include/xgboost/objective.h:104: multioutput is not supported by current objective function\nStack trace:\n  [bt] (0) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(+0x48c70a) [0x7b36fba6670a]\n  [bt] (1) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(+0x4bfee7) [0x7b36fba99ee7]\n  [bt] (2) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(+0x4ccd7d) [0x7b36fbaa6d7d]\n  [bt] (3) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(+0x4c5268) [0x7b36fba9f268]\n  [bt] (4) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(XGBoosterUpdateOneIter+0x70) [0x7b36fb73bef0]\n  [bt] (5) /lib/x86_64-linux-gnu/libffi.so.8(+0x7e2e) [0x7b37d4d0ce2e]\n  [bt] (6) /lib/x86_64-linux-gnu/libffi.so.8(+0x4493) [0x7b37d4d09493]\n  [bt] (7) /usr/lib/python3.10/lib-dynload/_ctypes.cpython-310-x86_64-linux-gnu.so(+0xa3e9) [0x7b37d4d323e9]\n  [bt] (8) /usr/lib/python3.10/lib-dynload/_ctypes.cpython-310-x86_64-linux-gnu.so(+0x9a00) [0x7b37d4d31a00]\n\n') in model 496 in generation 3: DatepartRegression
# Model Number: 497 with model ETS in generation 3 of 10
# Model Number: 498 with model SectionalMotif in generation 3 of 10
# Model Number: 499 with model UnobservedComponents in generation 3 of 10
# Model Number: 500 with model MultivariateRegression in generation 3 of 10
# Model Number: 501 with model UnobservedComponents in generation 3 of 10
# Model Number: 502 with model SectionalMotif in generation 3 of 10
# Model Number: 503 with model AverageValueNaive in generation 3 of 10
# Model Number: 504 with model ARIMA in generation 3 of 10
# Model Number: 505 with model UnivariateMotif in generation 3 of 10
# Model Number: 506 with model SeasonalNaive in generation 3 of 10
# Model Number: 507 with model WindowRegression in generation 3 of 10
# Model Number: 508 with model GLS in generation 3 of 10
# Model Number: 509 with model Theta in generation 3 of 10
# Model Number: 510 with model DatepartRegression in generation 3 of 10
# Epoch 1/50
# 24/24 [==============================] - 8s 58ms/step - loss: 1813.4758
# Epoch 2/50
# 24/24 [==============================] - 1s 57ms/step - loss: 1813.4009
# Epoch 3/50
# 24/24 [==============================] - 1s 57ms/step - loss: 1813.3409
# Epoch 4/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1813.2847
# Epoch 5/50
# 24/24 [==============================] - 2s 88ms/step - loss: 1813.2224
# Epoch 6/50
# 24/24 [==============================] - 2s 67ms/step - loss: 1813.1520
# Epoch 7/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1813.0625
# Epoch 8/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1812.9457
# Epoch 9/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1812.7765
# Epoch 10/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1812.5162
# Epoch 11/50
# 24/24 [==============================] - 1s 59ms/step - loss: 1812.1273
# Epoch 12/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1811.5842
# Epoch 13/50
# 24/24 [==============================] - 2s 76ms/step - loss: 1811.0006
# Epoch 14/50
# 24/24 [==============================] - 2s 74ms/step - loss: 1810.4972
# Epoch 15/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1810.0815
# Epoch 16/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1809.7161
# Epoch 17/50
# 24/24 [==============================] - 1s 60ms/step - loss: 1809.3995
# Epoch 18/50
# 24/24 [==============================] - 1s 57ms/step - loss: 1809.1067
# Epoch 19/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1808.8276
# Epoch 20/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1808.5742
# Epoch 21/50
# 24/24 [==============================] - 2s 68ms/step - loss: 1808.3339
# Epoch 22/50
# 24/24 [==============================] - 2s 84ms/step - loss: 1808.1117
# Epoch 23/50
# 24/24 [==============================] - 1s 60ms/step - loss: 1807.8977
# Epoch 24/50
# 24/24 [==============================] - 1s 57ms/step - loss: 1807.6819
# Epoch 25/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1807.5115
# Epoch 26/50
# 24/24 [==============================] - 1s 57ms/step - loss: 1807.3011
# Epoch 27/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1807.1434
# Epoch 28/50
# 24/24 [==============================] - 1s 59ms/step - loss: 1806.9911
# Epoch 29/50
# 24/24 [==============================] - 1s 60ms/step - loss: 1806.8356
# Epoch 30/50
# 24/24 [==============================] - 2s 88ms/step - loss: 1806.6870
# Epoch 31/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1806.5696
# Epoch 32/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1806.4351
# Epoch 33/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1806.3173
# Epoch 34/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1806.2020
# Epoch 35/50
# 24/24 [==============================] - 1s 59ms/step - loss: 1806.0895
# Epoch 36/50
# 24/24 [==============================] - 1s 59ms/step - loss: 1805.9951
# Epoch 37/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1805.8864
# Epoch 38/50
# 24/24 [==============================] - 2s 85ms/step - loss: 1805.7845
# Epoch 39/50
# 24/24 [==============================] - 2s 68ms/step - loss: 1805.7201
# Epoch 40/50
# 24/24 [==============================] - 1s 57ms/step - loss: 1805.6310
# Epoch 41/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1805.5510
# Epoch 42/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1805.4951
# Epoch 43/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1805.4138
# Epoch 44/50
# 24/24 [==============================] - 1s 59ms/step - loss: 1805.3333
# Epoch 45/50
# 24/24 [==============================] - 1s 60ms/step - loss: 1805.2743
# Epoch 46/50
# 24/24 [==============================] - 2s 76ms/step - loss: 1805.2117
# Epoch 47/50
# 24/24 [==============================] - 2s 77ms/step - loss: 1805.1558
# Epoch 48/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1805.0768
# Epoch 49/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1805.0402
# Epoch 50/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1804.9867
# 1/1 [==============================] - 1s 1s/step
# Model Number: 511 with model UnobservedComponents in generation 3 of 10
# Model Number: 512 with model MetricMotif in generation 3 of 10
# Model Number: 513 with model FBProphet in generation 3 of 10
# Model Number: 514 with model SectionalMotif in generation 3 of 10
# Model Number: 515 with model GLS in generation 3 of 10
# Model Number: 516 with model Theta in generation 3 of 10
# Model Number: 517 with model AverageValueNaive in generation 3 of 10
# Model Number: 518 with model LastValueNaive in generation 3 of 10
# Model Number: 519 with model MultivariateRegression in generation 3 of 10
# Template Eval Error: ValueError("regression_type='User' but not future_regressor supplied.") in model 519 in generation 3: MultivariateRegression
# Model Number: 520 with model SeasonalNaive in generation 3 of 10
# Template Eval Error: Exception('Transformer Cointegration failed on fit') in model 520 in generation 3: SeasonalNaive
# Model Number: 521 with model UnobservedComponents in generation 3 of 10
# Model Number: 522 with model MultivariateRegression in generation 3 of 10
# Template Eval Error: Exception('Transformer HolidayTransformer failed on fit') in model 522 in generation 3: MultivariateRegression
# Model Number: 523 with model LastValueNaive in generation 3 of 10
# Model Number: 524 with model WindowRegression in generation 3 of 10
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 524 in generation 3: WindowRegression
# Model Number: 525 with model ETS in generation 3 of 10
# Model Number: 526 with model FBProphet in generation 3 of 10
# 19:08:13 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# Model Number: 527 with model GLM in generation 3 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 527 in generation 3: GLM
# Model Number: 528 with model MultivariateMotif in generation 3 of 10
# Model Number: 529 with model WindowRegression in generation 3 of 10
# Model Number: 530 with model DatepartRegression in generation 3 of 10
# Model Number: 531 with model ARIMA in generation 3 of 10
# Model Number: 532 with model MultivariateRegression in generation 3 of 10
# Model Number: 533 with model MetricMotif in generation 3 of 10
# Model Number: 534 with model ConstantNaive in generation 3 of 10
# Model Number: 535 with model Theta in generation 3 of 10
# Model Number: 536 with model NVAR in generation 3 of 10
# Model Number: 537 with model DatepartRegression in generation 3 of 10
# Model Number: 538 with model UnivariateMotif in generation 3 of 10
# Model Number: 539 with model GLM in generation 3 of 10
# Model Number: 540 with model MultivariateRegression in generation 3 of 10
# Template Eval Error: Exception('Transformer QuantileTransformer failed on inverse') in model 540 in generation 3: MultivariateRegression
# Model Number: 541 with model MultivariateRegression in generation 3 of 10
# Model Number: 542 with model FBProphet in generation 3 of 10
# Template Eval Error: ValueError('more than 1 year of data is required for holiday detection.') in model 542 in generation 3: FBProphet
# Model Number: 543 with model ETS in generation 3 of 10
# Model Number: 544 with model MultivariateRegression in generation 3 of 10
# Model Number: 545 with model Theta in generation 3 of 10
# Model Number: 546 with model UnivariateMotif in generation 3 of 10
# Template Eval Error: ValueError('Model UnivariateMotif returned NaN for one or more series. fail_on_forecast_nan=True') in model 546 in generation 3: UnivariateMotif
# Model Number: 547 with model SeasonalNaive in generation 3 of 10
# Model Number: 548 with model AverageValueNaive in generation 3 of 10
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:48: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# Model Number: 549 with model SectionalMotif in generation 3 of 10
# Model Number: 550 with model AverageValueNaive in generation 3 of 10
# Model Number: 551 with model Theta in generation 3 of 10
# Model Number: 552 with model SectionalMotif in generation 3 of 10
# Model Number: 553 with model MultivariateRegression in generation 3 of 10
# Template Eval Error: ValueError("Some value(s) of y are out of the valid range of the loss 'HalfPoissonLoss'.") in model 553 in generation 3: MultivariateRegression
# Model Number: 554 with model SectionalMotif in generation 3 of 10
# Model Number: 555 with model LastValueNaive in generation 3 of 10
# Model Number: 556 with model ARDL in generation 3 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 556 in generation 3: ARDL
# Model Number: 557 with model GLM in generation 3 of 10
# Model Number: 558 with model UnivariateMotif in generation 3 of 10
# Model Number: 559 with model Theta in generation 3 of 10
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# Model Number: 560 with model NVAR in generation 3 of 10
# Model Number: 561 with model MultivariateMotif in generation 3 of 10
# New Generation: 4 of 10
# Model Number: 562 with model DatepartRegression in generation 4 of 10
# Model Number: 563 with model MetricMotif in generation 4 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Model Number: 564 with model DatepartRegression in generation 4 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 564 in generation 4: DatepartRegression
# Model Number: 565 with model MultivariateMotif in generation 4 of 10
# Model Number: 566 with model SectionalMotif in generation 4 of 10
# Model Number: 567 with model ConstantNaive in generation 4 of 10
# Model Number: 568 with model ETS in generation 4 of 10
# Model Number: 569 with model Theta in generation 4 of 10
# Model Number: 570 with model ARIMA in generation 4 of 10
# Model Number: 571 with model GLS in generation 4 of 10
# Model Number: 572 with model LastValueNaive in generation 4 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 572 in generation 4: LastValueNaive
# Model Number: 573 with model ETS in generation 4 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Model Number: 574 with model SeasonalNaive in generation 4 of 10
# Model Number: 575 with model UnobservedComponents in generation 4 of 10
# Template Eval Error: Exception('Transformer RegressionFilter failed on fit') in model 575 in generation 4: UnobservedComponents
# Model Number: 576 with model MetricMotif in generation 4 of 10
# Model Number: 577 with model WindowRegression in generation 4 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 577 in generation 4: WindowRegression
# Model Number: 578 with model ARIMA in generation 4 of 10
# Model Number: 579 with model SectionalMotif in generation 4 of 10
# Model Number: 580 with model UnobservedComponents in generation 4 of 10
# Model Number: 581 with model SectionalMotif in generation 4 of 10
# Model Number: 582 with model MultivariateMotif in generation 4 of 10
# Model Number: 583 with model ARIMA in generation 4 of 10
# Model Number: 584 with model WindowRegression in generation 4 of 10
# Model Number: 585 with model FBProphet in generation 4 of 10
# Model Number: 586 with model SectionalMotif in generation 4 of 10
# Model Number: 587 with model ETS in generation 4 of 10
# Model Number: 588 with model MultivariateRegression in generation 4 of 10
# Model Number: 589 with model MetricMotif in generation 4 of 10
# Model Number: 590 with model ConstantNaive in generation 4 of 10
# Model Number: 591 with model ConstantNaive in generation 4 of 10
# Model Number: 592 with model WindowRegression in generation 4 of 10
# Model Number: 593 with model LastValueNaive in generation 4 of 10
# Model Number: 594 with model MultivariateRegression in generation 4 of 10
# Model Number: 595 with model UnobservedComponents in generation 4 of 10
# Model Number: 596 with model MetricMotif in generation 4 of 10
# Model Number: 597 with model SectionalMotif in generation 4 of 10
# Model Number: 598 with model ConstantNaive in generation 4 of 10
# Model Number: 599 with model ETS in generation 4 of 10
# Model Number: 600 with model ARIMA in generation 4 of 10
# Model Number: 601 with model SeasonalNaive in generation 4 of 10
# Model Number: 602 with model MultivariateMotif in generation 4 of 10
# Model Number: 603 with model MetricMotif in generation 4 of 10
# Model Number: 604 with model ETS in generation 4 of 10
# Model Number: 605 with model UnivariateMotif in generation 4 of 10
# Template Eval Error: ValueError('Model UnivariateMotif returned NaN for one or more series. fail_on_forecast_nan=True') in model 605 in generation 4: UnivariateMotif
# Model Number: 606 with model LastValueNaive in generation 4 of 10
# Model Number: 607 with model DatepartRegression in generation 4 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/decomposition/_fastica.py:708: FutureWarning: Starting in v1.3, whiten=True should be specified as whiten='arbitrary-variance' (its current behaviour). This behavior is deprecated in 1.1 and will raise ValueError in 1.3.
#   return self._fit_transform(X, compute_sources=True)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:550: RuntimeWarning: invalid value encountered in divide
#   avg = np.multiply(a, wgt,
# Model Number: 608 with model ETS in generation 4 of 10
# Model Number: 609 with model LastValueNaive in generation 4 of 10
# Model Number: 610 with model ETS in generation 4 of 10
# Model Number: 611 with model AverageValueNaive in generation 4 of 10
# Model Number: 612 with model MultivariateRegression in generation 4 of 10
# Model Number: 613 with model DatepartRegression in generation 4 of 10
# Model Number: 614 with model MetricMotif in generation 4 of 10
# Model Number: 615 with model FBProphet in generation 4 of 10
# 19:08:35 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# Model Number: 616 with model ETS in generation 4 of 10
# Model Number: 617 with model GLM in generation 4 of 10
# Model Number: 618 with model UnivariateMotif in generation 4 of 10
# Model Number: 619 with model LastValueNaive in generation 4 of 10
# Model Number: 620 with model MultivariateRegression in generation 4 of 10
# Model Number: 621 with model MultivariateMotif in generation 4 of 10
# Model Number: 622 with model SectionalMotif in generation 4 of 10
# Model Number: 623 with model GLM in generation 4 of 10
# Model Number: 624 with model ARIMA in generation 4 of 10
# Model Number: 625 with model GLM in generation 4 of 10
# Model Number: 626 with model DatepartRegression in generation 4 of 10
# Model Number: 627 with model UnivariateMotif in generation 4 of 10
# Model Number: 628 with model SectionalMotif in generation 4 of 10
# Model Number: 629 with model AverageValueNaive in generation 4 of 10
# Model Number: 630 with model FBProphet in generation 4 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/decomposition/_fastica.py:708: FutureWarning: Starting in v1.3, whiten=True should be specified as whiten='arbitrary-variance' (its current behaviour). This behavior is deprecated in 1.1 and will raise ValueError in 1.3.
#   return self._fit_transform(X, compute_sources=True)
# Model Number: 631 with model WindowRegression in generation 4 of 10
# Model Number: 632 with model SectionalMotif in generation 4 of 10
# Model Number: 633 with model AverageValueNaive in generation 4 of 10
# Model Number: 634 with model MultivariateMotif in generation 4 of 10
# Model Number: 635 with model UnobservedComponents in generation 4 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/decomposition/_fastica.py:708: FutureWarning: Starting in v1.3, whiten=True should be specified as whiten='arbitrary-variance' (its current behaviour). This behavior is deprecated in 1.1 and will raise ValueError in 1.3.
#   return self._fit_transform(X, compute_sources=True)
# Model Number: 636 with model SeasonalNaive in generation 4 of 10
# Model Number: 637 with model MetricMotif in generation 4 of 10
# Model Number: 638 with model WindowRegression in generation 4 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 638 in generation 4: WindowRegression
# Model Number: 639 with model LastValueNaive in generation 4 of 10
# Model Number: 640 with model ConstantNaive in generation 4 of 10
# Model Number: 641 with model LastValueNaive in generation 4 of 10
# Model Number: 642 with model DatepartRegression in generation 4 of 10
# Model Number: 643 with model GLM in generation 4 of 10
# Model Number: 644 with model MultivariateMotif in generation 4 of 10
# Model Number: 645 with model SectionalMotif in generation 4 of 10
# Model Number: 646 with model LastValueNaive in generation 4 of 10
# Model Number: 647 with model MetricMotif in generation 4 of 10
# Model Number: 648 with model UnivariateMotif in generation 4 of 10
# Model Number: 649 with model SeasonalNaive in generation 4 of 10
# Template Eval Error: Exception('Transformer Cointegration failed on fit') in model 649 in generation 4: SeasonalNaive
# Model Number: 650 with model SectionalMotif in generation 4 of 10
# Model Number: 651 with model SeasonalNaive in generation 4 of 10
# Model Number: 652 with model AverageValueNaive in generation 4 of 10
# Model Number: 653 with model ConstantNaive in generation 4 of 10
# Template Eval Error: Exception('Transformer RobustScaler failed on fit') in model 653 in generation 4: ConstantNaive
# Model Number: 654 with model Theta in generation 4 of 10
# Model Number: 655 with model FBProphet in generation 4 of 10
# No anomalies detected.
# Template Eval Error: ValueError('more than 1 year of data is required for holiday detection.') in model 655 in generation 4: FBProphet
# Model Number: 656 with model GLS in generation 4 of 10
# Model Number: 657 with model Theta in generation 4 of 10
# Template Eval Error: Exception('Transformer BTCD failed on fit') in model 657 in generation 4: Theta
# Model Number: 658 with model GLM in generation 4 of 10
# Template Eval Error: ValueError('NaN, inf or invalid value detected in weights, estimation infeasible.') in model 658 in generation 4: GLM
# Model Number: 659 with model SectionalMotif in generation 4 of 10
# Model Number: 660 with model GLM in generation 4 of 10
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/links.py:527: RuntimeWarning: overflow encountered in exp
#   return np.exp(z)
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:143: RuntimeWarning: invalid value encountered in multiply
#   return 1. / (self.link.deriv(mu)**2 * self.variance(mu))
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/generalized_linear_model.py:1328: RuntimeWarning: invalid value encountered in multiply
#   wlsendog = (lin_pred + self.family.link.deriv(mu) * (self.endog-mu)
# Model Number: 661 with model GLM in generation 4 of 10
# Model Number: 662 with model UnivariateMotif in generation 4 of 10
# Model Number: 663 with model ETS in generation 4 of 10
# Model Number: 664 with model ConstantNaive in generation 4 of 10
# Model Number: 665 with model MultivariateMotif in generation 4 of 10
# Model Number: 666 with model ETS in generation 4 of 10
# Model Number: 667 with model Theta in generation 4 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Model Number: 668 with model MultivariateMotif in generation 4 of 10
# Model Number: 669 with model Theta in generation 4 of 10
# Model Number: 670 with model ARIMA in generation 4 of 10
# Template Eval Error: Exception('Transformer StandardScaler failed on inverse') in model 670 in generation 4: ARIMA
# Model Number: 671 with model WindowRegression in generation 4 of 10
# Model Number: 672 with model SeasonalNaive in generation 4 of 10
# Model Number: 673 with model UnobservedComponents in generation 4 of 10
# Model Number: 674 with model DatepartRegression in generation 4 of 10
# Model Number: 675 with model UnivariateMotif in generation 4 of 10
# Model Number: 676 with model Theta in generation 4 of 10
# Model Number: 677 with model DatepartRegression in generation 4 of 10
# Model Number: 678 with model MetricMotif in generation 4 of 10
# Model Number: 679 with model SeasonalNaive in generation 4 of 10
# Model Number: 680 with model ARIMA in generation 4 of 10
# Model Number: 681 with model DatepartRegression in generation 4 of 10
# Model Number: 682 with model SectionalMotif in generation 4 of 10
# Model Number: 683 with model ETS in generation 4 of 10
# Model Number: 684 with model DatepartRegression in generation 4 of 10
# Template Eval Error: Exception('Transformer Cointegration failed on fit') in model 684 in generation 4: DatepartRegression
# Model Number: 685 with model NVAR in generation 4 of 10
# Template Eval Error: Exception('Transformer ReplaceConstant failed on fit') in model 685 in generation 4: NVAR
# Model Number: 686 with model DatepartRegression in generation 4 of 10
# Epoch 1/50
# 24/24 [==============================] - 7s 81ms/step - loss: 1.5213e-04
# Epoch 2/50
# 24/24 [==============================] - 2s 71ms/step - loss: 1.5158e-04
# Epoch 3/50
# 24/24 [==============================] - 1s 61ms/step - loss: 1.5051e-04
# Epoch 4/50
# 24/24 [==============================] - 1s 57ms/step - loss: 1.5007e-04
# Epoch 5/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1.5085e-04
# Epoch 6/50
# 24/24 [==============================] - 1s 57ms/step - loss: 1.4963e-04
# Epoch 7/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1.5035e-04
# Epoch 8/50
# 24/24 [==============================] - 1s 59ms/step - loss: 1.5053e-04
# Epoch 9/50
# 24/24 [==============================] - 2s 70ms/step - loss: 1.5031e-04
# Epoch 10/50
# 24/24 [==============================] - 2s 82ms/step - loss: 1.5026e-04
# Epoch 11/50
# 24/24 [==============================] - 1s 57ms/step - loss: 1.5089e-04
# Epoch 12/50
# 24/24 [==============================] - 1s 56ms/step - loss: 1.5075e-04
# Epoch 13/50
# 24/24 [==============================] - 1s 57ms/step - loss: 1.5087e-04
# Epoch 14/50
# 24/24 [==============================] - 1s 57ms/step - loss: 1.5058e-04
# Epoch 15/50
# 24/24 [==============================] - 1s 57ms/step - loss: 1.5069e-04
# Epoch 16/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1.5069e-04
# Epoch 17/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1.4979e-04
# Epoch 18/50
# 24/24 [==============================] - 2s 88ms/step - loss: 1.5080e-04
# Epoch 19/50
# 24/24 [==============================] - 2s 63ms/step - loss: 1.5028e-04
# Epoch 20/50
# 24/24 [==============================] - 1s 57ms/step - loss: 1.5000e-04
# Epoch 21/50
# 24/24 [==============================] - 1s 57ms/step - loss: 1.5031e-04
# Epoch 22/50
# 24/24 [==============================] - 1s 57ms/step - loss: 1.5040e-04
# Epoch 23/50
# 24/24 [==============================] - 1s 57ms/step - loss: 1.4999e-04
# Epoch 24/50
# 24/24 [==============================] - 1s 57ms/step - loss: 1.4999e-04
# Epoch 25/50
# 24/24 [==============================] - 1s 57ms/step - loss: 1.5079e-04
# Epoch 26/50
# 24/24 [==============================] - 2s 78ms/step - loss: 1.4986e-04
# Epoch 27/50
# 24/24 [==============================] - 2s 73ms/step - loss: 1.5043e-04
# Epoch 28/50
# 24/24 [==============================] - 1s 56ms/step - loss: 1.5037e-04
# Epoch 29/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1.5062e-04
# Epoch 30/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1.5050e-04
# Epoch 31/50
# 24/24 [==============================] - 1s 57ms/step - loss: 1.5022e-04
# Epoch 32/50
# 24/24 [==============================] - 1s 57ms/step - loss: 1.5058e-04
# Epoch 33/50
# 24/24 [==============================] - 1s 57ms/step - loss: 1.5072e-04
# Epoch 34/50
# 24/24 [==============================] - 2s 64ms/step - loss: 1.4974e-04
# Epoch 35/50
# 24/24 [==============================] - 2s 86ms/step - loss: 1.5091e-04
# Epoch 36/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1.4968e-04
# Epoch 37/50
# 24/24 [==============================] - 1s 57ms/step - loss: 1.5046e-04
# Epoch 38/50
# 24/24 [==============================] - 1s 57ms/step - loss: 1.5102e-04
# Epoch 39/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1.4994e-04
# Epoch 40/50
# 24/24 [==============================] - 1s 57ms/step - loss: 1.4989e-04
# Epoch 41/50
# 24/24 [==============================] - 1s 57ms/step - loss: 1.5037e-04
# Epoch 42/50
# 24/24 [==============================] - 1s 59ms/step - loss: 1.5001e-04
# Epoch 43/50
# 24/24 [==============================] - 2s 88ms/step - loss: 1.5105e-04
# Epoch 44/50
# 24/24 [==============================] - 2s 65ms/step - loss: 1.4960e-04
# Epoch 45/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1.5045e-04
# Epoch 46/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1.5088e-04
# Epoch 47/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1.5034e-04
# Epoch 48/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1.5044e-04
# Epoch 49/50
# 24/24 [==============================] - 1s 57ms/step - loss: 1.5042e-04
# Epoch 50/50
# 24/24 [==============================] - 1s 58ms/step - loss: 1.5107e-04
# 1/1 [==============================] - 2s 2s/step
# New Generation: 5 of 10
# Model Number: 687 with model DatepartRegression in generation 5 of 10
# Template Eval Error: Exception('Transformer Cointegration failed on fit') in model 687 in generation 5: DatepartRegression
# Model Number: 688 with model SectionalMotif in generation 5 of 10
# Template Eval Error: LinAlgError('Singular matrix') in model 688 in generation 5: SectionalMotif
# Model Number: 689 with model DatepartRegression in generation 5 of 10
# Model Number: 690 with model GLM in generation 5 of 10
# Model Number: 691 with model SectionalMotif in generation 5 of 10
# Model Number: 692 with model GLM in generation 5 of 10
# Template Eval Error: ValueError('The first guess on the deviance function returned a nan.  This could be a boundary  problem and should be reported.') in model 692 in generation 5: GLM
# Model Number: 693 with model GLM in generation 5 of 10
# Template Eval Error: ValueError('NaN, inf or invalid value detected in weights, estimation infeasible.') in model 693 in generation 5: GLM
# Model Number: 694 with model ETS in generation 5 of 10
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1650: RuntimeWarning: invalid value encountered in log
#   endog * np.log(endog / mu) + (mu - endog))
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1650: RuntimeWarning: invalid value encountered in log
#   endog * np.log(endog / mu) + (mu - endog))
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1650: RuntimeWarning: divide by zero encountered in divide
#   endog * np.log(endog / mu) + (mu - endog))
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/generalized_linear_model.py:898: RuntimeWarning: divide by zero encountered in divide
#   return np.sum(resid / self.family.variance(mu)) / self.df_resid
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:143: RuntimeWarning: divide by zero encountered in divide
#   return 1. / (self.link.deriv(mu)**2 * self.variance(mu))
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 694 in generation 5: ETS
# Model Number: 695 with model SectionalMotif in generation 5 of 10
# Model Number: 696 with model MultivariateRegression in generation 5 of 10
# Model Number: 697 with model GLM in generation 5 of 10
# Model Number: 698 with model WindowRegression in generation 5 of 10
# Model Number: 699 with model GLS in generation 5 of 10
# Model Number: 700 with model SectionalMotif in generation 5 of 10
# Template Eval Error: Exception('Transformer Cointegration failed on fit') in model 700 in generation 5: SectionalMotif
# Model Number: 701 with model MetricMotif in generation 5 of 10
# Model Number: 702 with model SeasonalNaive in generation 5 of 10
# Model Number: 703 with model GLS in generation 5 of 10
# Model Number: 704 with model UnobservedComponents in generation 5 of 10
# Template Eval Error: Exception('Transformer BTCD failed on fit') in model 704 in generation 5: UnobservedComponents
# Model Number: 705 with model ConstantNaive in generation 5 of 10
# Model Number: 706 with model ARIMA in generation 5 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 706 in generation 5: ARIMA
# Model Number: 707 with model WindowRegression in generation 5 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.5498e-25): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /usr/local/lib/python3.10/dist-packages/sklearn/decomposition/_fastica.py:708: FutureWarning: Starting in v1.3, whiten=True should be specified as whiten='arbitrary-variance' (its current behaviour). This behavior is deprecated in 1.1 and will raise ValueError in 1.3.
#   return self._fit_transform(X, compute_sources=True)
# Model Number: 708 with model ETS in generation 5 of 10
# Model Number: 709 with model UnobservedComponents in generation 5 of 10
# Model Number: 710 with model LastValueNaive in generation 5 of 10
# Model Number: 711 with model AverageValueNaive in generation 5 of 10
# Model Number: 712 with model ETS in generation 5 of 10
# Model Number: 713 with model FBProphet in generation 5 of 10
# Model Number: 714 with model ARDL in generation 5 of 10
# Template Eval Error: ValueError("ARDL series Close failed with error IndexError('tuple index out of range') exog train None and predict None") in model 714 in generation 5: ARDL
# Model Number: 715 with model UnivariateMotif in generation 5 of 10
# Model Number: 716 with model Theta in generation 5 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Model Number: 717 with model MultivariateRegression in generation 5 of 10
# Template Eval Error: ValueError("Some value(s) of y are out of the valid range of the loss 'HalfPoissonLoss'.") in model 717 in generation 5: MultivariateRegression
# Model Number: 718 with model GLS in generation 5 of 10
# Model Number: 719 with model MetricMotif in generation 5 of 10
# Model Number: 720 with model ConstantNaive in generation 5 of 10
# Model Number: 721 with model MetricMotif in generation 5 of 10
# Model Number: 722 with model ARIMA in generation 5 of 10
# Template Eval Error: Exception('Transformer QuantileTransformer failed on inverse') in model 722 in generation 5: ARIMA
# Model Number: 723 with model LastValueNaive in generation 5 of 10
# Model Number: 724 with model SeasonalNaive in generation 5 of 10
# Model Number: 725 with model SectionalMotif in generation 5 of 10
# Model Number: 726 with model SectionalMotif in generation 5 of 10
# Template Eval Error: ValueError('The number of observations (28) is too small; the covariance matrix is singular. For observations with 50 dimensions, at least 51 observations are required.') in model 726 in generation 5: SectionalMotif
# Model Number: 727 with model MetricMotif in generation 5 of 10
# Model Number: 728 with model DatepartRegression in generation 5 of 10
# Model Number: 729 with model MultivariateMotif in generation 5 of 10
# Model Number: 730 with model UnivariateMotif in generation 5 of 10
# Model Number: 731 with model GLM in generation 5 of 10
# Model Number: 732 with model UnivariateMotif in generation 5 of 10
# Model Number: 733 with model AverageValueNaive in generation 5 of 10
# Model Number: 734 with model SeasonalNaive in generation 5 of 10
# Model Number: 735 with model FBProphet in generation 5 of 10
# Template Eval Error: Exception('Transformer HolidayTransformer failed on fit') in model 735 in generation 5: FBProphet
# Model Number: 736 with model LastValueNaive in generation 5 of 10
# Model Number: 737 with model ARIMA in generation 5 of 10
# Model Number: 738 with model GLM in generation 5 of 10
# Model Number: 739 with model MultivariateMotif in generation 5 of 10
# Model Number: 740 with model UnivariateMotif in generation 5 of 10
# Model Number: 741 with model WindowRegression in generation 5 of 10
# Model Number: 742 with model GLM in generation 5 of 10
# Model Number: 743 with model FBProphet in generation 5 of 10
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1402: RuntimeWarning: divide by zero encountered in divide
#   endog_mu = self._clean(endog / mu)
# Model Number: 744 with model ETS in generation 5 of 10
# Model Number: 745 with model GLS in generation 5 of 10
# Model Number: 746 with model SeasonalNaive in generation 5 of 10
# Model Number: 747 with model Theta in generation 5 of 10
# Model Number: 748 with model ETS in generation 5 of 10
# Model Number: 749 with model NVAR in generation 5 of 10
# Model Number: 750 with model UnivariateMotif in generation 5 of 10
# Model Number: 751 with model ConstantNaive in generation 5 of 10
# Model Number: 752 with model Theta in generation 5 of 10
# Model Number: 753 with model SeasonalNaive in generation 5 of 10
# Model Number: 754 with model GLS in generation 5 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/decomposition/_fastica.py:708: FutureWarning: Starting in v1.3, whiten=True should be specified as whiten='arbitrary-variance' (its current behaviour). This behavior is deprecated in 1.1 and will raise ValueError in 1.3.
#   return self._fit_transform(X, compute_sources=True)
# Model Number: 755 with model ETS in generation 5 of 10
# Model Number: 756 with model LastValueNaive in generation 5 of 10
# Model Number: 757 with model LastValueNaive in generation 5 of 10
# Model Number: 758 with model ARIMA in generation 5 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 758 in generation 5: ARIMA
# Model Number: 759 with model ARIMA in generation 5 of 10
# Model Number: 760 with model NVAR in generation 5 of 10
# Model Number: 761 with model MultivariateMotif in generation 5 of 10
# Model Number: 762 with model LastValueNaive in generation 5 of 10
# Model Number: 763 with model DatepartRegression in generation 5 of 10
# Template Eval Error: ValueError('Model DatepartRegression returned NaN for one or more series. fail_on_forecast_nan=True') in model 763 in generation 5: DatepartRegression
# Model Number: 764 with model ETS in generation 5 of 10
# Model Number: 765 with model SeasonalNaive in generation 5 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_regression.py:494: UserWarning: One or more samples have no neighbors within specified radius; predicting NaN.
#   warnings.warn(empty_warning_msg)
# Model Number: 766 with model ETS in generation 5 of 10
# Model Number: 767 with model MultivariateMotif in generation 5 of 10
# Model Number: 768 with model ARIMA in generation 5 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.5498e-25): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# Model Number: 769 with model ConstantNaive in generation 5 of 10
# Model Number: 770 with model ConstantNaive in generation 5 of 10
# Model Number: 771 with model DatepartRegression in generation 5 of 10
# Model Number: 772 with model MultivariateRegression in generation 5 of 10
# Model Number: 773 with model MultivariateMotif in generation 5 of 10
# Model Number: 774 with model Theta in generation 5 of 10
# Model Number: 775 with model MultivariateMotif in generation 5 of 10
# Model Number: 776 with model MultivariateRegression in generation 5 of 10
# Template Eval Error: ValueError("regression_type='User' but not future_regressor supplied.") in model 776 in generation 5: MultivariateRegression
# Model Number: 777 with model ConstantNaive in generation 5 of 10
# Model Number: 778 with model ConstantNaive in generation 5 of 10
# Model Number: 779 with model UnobservedComponents in generation 5 of 10
# Model Number: 780 with model LastValueNaive in generation 5 of 10
# Model Number: 781 with model MultivariateRegression in generation 5 of 10
# Model Number: 782 with model ETS in generation 5 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_linear_loss.py:289: RuntimeWarning: invalid value encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# Model Number: 783 with model WindowRegression in generation 5 of 10
# Model Number: 784 with model ARIMA in generation 5 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 784 in generation 5: ARIMA
# Model Number: 785 with model DatepartRegression in generation 5 of 10
# Model Number: 786 with model MultivariateMotif in generation 5 of 10
# New Generation: 6 of 10
# Model Number: 787 with model ConstantNaive in generation 6 of 10
# Model Number: 788 with model MultivariateMotif in generation 6 of 10
# Template Eval Error: Exception('Transformer RegressionFilter failed on fit') in model 788 in generation 6: MultivariateMotif
# Model Number: 789 with model GLM in generation 6 of 10
# Model Number: 790 with model ETS in generation 6 of 10
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/links.py:198: RuntimeWarning: overflow encountered in exp
#   t = np.exp(-z)
# Model Number: 791 with model MultivariateMotif in generation 6 of 10
# Model Number: 792 with model MetricMotif in generation 6 of 10
# Model Number: 793 with model FBProphet in generation 6 of 10
# Model Number: 794 with model UnivariateMotif in generation 6 of 10
# Model Number: 795 with model ETS in generation 6 of 10
# Model Number: 796 with model SectionalMotif in generation 6 of 10
# Model Number: 797 with model UnivariateMotif in generation 6 of 10
# Model Number: 798 with model AverageValueNaive in generation 6 of 10
# Template Eval Error: Exception('Transformer ReplaceConstant failed on fit') in model 798 in generation 6: AverageValueNaive
# Model Number: 799 with model GLM in generation 6 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Model Number: 800 with model UnivariateMotif in generation 6 of 10
# Model Number: 801 with model WindowRegression in generation 6 of 10
# Model Number: 802 with model DatepartRegression in generation 6 of 10
# Model Number: 803 with model SeasonalNaive in generation 6 of 10
# Model Number: 804 with model AverageValueNaive in generation 6 of 10
# Template Eval Error: Exception('Transformer ReplaceConstant failed on fit') in model 804 in generation 6: AverageValueNaive
# Model Number: 805 with model SectionalMotif in generation 6 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Template Eval Error: Exception('Transformer RegressionFilter failed on fit') in model 805 in generation 6: SectionalMotif
# Model Number: 806 with model DatepartRegression in generation 6 of 10
# Epoch 1/100
# 3/3 [==============================] - 6s 22ms/step - loss: 140.4330
# Epoch 2/100
# 3/3 [==============================] - 0s 19ms/step - loss: 140.4263
# Epoch 3/100
# 3/3 [==============================] - 0s 19ms/step - loss: 140.4225
# Epoch 4/100
# 3/3 [==============================] - 0s 21ms/step - loss: 140.4180
# Epoch 5/100
# 3/3 [==============================] - 0s 20ms/step - loss: 140.4059
# Epoch 6/100
# 3/3 [==============================] - 0s 21ms/step - loss: 140.3969
# Epoch 7/100
# 3/3 [==============================] - 0s 20ms/step - loss: 140.4072
# Epoch 8/100
# 3/3 [==============================] - 0s 20ms/step - loss: 140.3898
# Epoch 9/100
# 3/3 [==============================] - 0s 20ms/step - loss: 140.3896
# Epoch 10/100
# 3/3 [==============================] - 0s 22ms/step - loss: 140.3496
# Epoch 11/100
# 3/3 [==============================] - 0s 20ms/step - loss: 140.3470
# Epoch 12/100
# 3/3 [==============================] - 0s 22ms/step - loss: 140.3318
# Epoch 13/100
# 3/3 [==============================] - 0s 20ms/step - loss: 140.3797
# Epoch 14/100
# 3/3 [==============================] - 0s 19ms/step - loss: 140.2874
# Epoch 15/100
# 3/3 [==============================] - 0s 20ms/step - loss: 140.2930
# Epoch 16/100
# 3/3 [==============================] - 0s 20ms/step - loss: 140.2459
# Epoch 17/100
# 3/3 [==============================] - 0s 20ms/step - loss: 140.2339
# Epoch 18/100
# 3/3 [==============================] - 0s 24ms/step - loss: 140.1944
# Epoch 19/100
# 3/3 [==============================] - 0s 20ms/step - loss: 140.1715
# Epoch 20/100
# 3/3 [==============================] - 0s 19ms/step - loss: 140.1223
# Epoch 21/100
# 3/3 [==============================] - 0s 21ms/step - loss: 140.1014
# Epoch 22/100
# 3/3 [==============================] - 0s 20ms/step - loss: 140.0818
# Epoch 23/100
# 3/3 [==============================] - 0s 20ms/step - loss: 140.0252
# Epoch 24/100
# 3/3 [==============================] - 0s 20ms/step - loss: 140.0040
# Epoch 25/100
# 3/3 [==============================] - 0s 21ms/step - loss: 139.9724
# Epoch 26/100
# 3/3 [==============================] - 0s 21ms/step - loss: 139.9590
# Epoch 27/100
# 3/3 [==============================] - 0s 20ms/step - loss: 139.9229
# Epoch 28/100
# 3/3 [==============================] - 0s 21ms/step - loss: 139.9367
# Epoch 29/100
# 3/3 [==============================] - 0s 23ms/step - loss: 139.8865
# Epoch 30/100
# 3/3 [==============================] - 0s 19ms/step - loss: 139.8926
# Epoch 31/100
# 3/3 [==============================] - 0s 21ms/step - loss: 139.8714
# Epoch 32/100
# 3/3 [==============================] - 0s 20ms/step - loss: 139.8790
# Epoch 33/100
# 3/3 [==============================] - 0s 20ms/step - loss: 139.8677
# Epoch 34/100
# 3/3 [==============================] - 0s 20ms/step - loss: 139.8653
# Epoch 35/100
# 3/3 [==============================] - 0s 21ms/step - loss: 139.8363
# Epoch 36/100
# 3/3 [==============================] - 0s 20ms/step - loss: 139.8360
# Epoch 37/100
# 3/3 [==============================] - 0s 20ms/step - loss: 139.8362
# Epoch 38/100
# 3/3 [==============================] - 0s 19ms/step - loss: 139.8241
# Epoch 39/100
# 3/3 [==============================] - 0s 20ms/step - loss: 139.8334
# Epoch 40/100
# 3/3 [==============================] - 0s 20ms/step - loss: 139.8206
# Epoch 41/100
# 3/3 [==============================] - 0s 20ms/step - loss: 139.8141
# Epoch 42/100
# 3/3 [==============================] - 0s 19ms/step - loss: 139.8105
# Epoch 43/100
# 3/3 [==============================] - 0s 22ms/step - loss: 139.8162
# Epoch 44/100
# 3/3 [==============================] - 0s 20ms/step - loss: 139.8157
# Epoch 45/100
# 3/3 [==============================] - 0s 20ms/step - loss: 139.8191
# Epoch 46/100
# 3/3 [==============================] - 0s 19ms/step - loss: 139.8104
# Epoch 47/100
# 3/3 [==============================] - 0s 19ms/step - loss: 139.8063
# Epoch 48/100
# 3/3 [==============================] - 0s 20ms/step - loss: 139.7975
# Epoch 49/100
# 3/3 [==============================] - 0s 20ms/step - loss: 139.7977
# Epoch 50/100
# 3/3 [==============================] - 0s 20ms/step - loss: 139.8022
# Epoch 51/100
# 3/3 [==============================] - 0s 21ms/step - loss: 139.7960
# Epoch 52/100
# 3/3 [==============================] - 0s 20ms/step - loss: 139.7991
# Epoch 53/100
# 3/3 [==============================] - 0s 22ms/step - loss: 139.7939
# Epoch 54/100
# 3/3 [==============================] - 0s 21ms/step - loss: 139.7837
# Epoch 55/100
# 3/3 [==============================] - 0s 21ms/step - loss: 139.7910
# Epoch 56/100
# 3/3 [==============================] - 0s 20ms/step - loss: 139.7878
# Epoch 57/100
# 3/3 [==============================] - 0s 20ms/step - loss: 139.7822
# Epoch 58/100
# 3/3 [==============================] - 0s 26ms/step - loss: 139.7781
# Epoch 59/100
# 3/3 [==============================] - 0s 20ms/step - loss: 139.7876
# Epoch 60/100
# 3/3 [==============================] - 0s 23ms/step - loss: 139.7785
# Epoch 61/100
# 3/3 [==============================] - 0s 20ms/step - loss: 139.7778
# Epoch 62/100
# 3/3 [==============================] - 0s 21ms/step - loss: 139.7744
# Epoch 63/100
# 3/3 [==============================] - 0s 21ms/step - loss: 139.7684
# Epoch 64/100
# 3/3 [==============================] - 0s 20ms/step - loss: 139.7667
# Epoch 65/100
# 3/3 [==============================] - 0s 21ms/step - loss: 139.7753
# Epoch 66/100
# 3/3 [==============================] - 0s 19ms/step - loss: 139.7651
# Epoch 67/100
# 3/3 [==============================] - 0s 20ms/step - loss: 139.7610
# Epoch 68/100
# 3/3 [==============================] - 0s 21ms/step - loss: 139.7617
# Epoch 69/100
# 3/3 [==============================] - 0s 20ms/step - loss: 139.7620
# Epoch 70/100
# 3/3 [==============================] - 0s 19ms/step - loss: 139.7608
# Epoch 71/100
# 3/3 [==============================] - 0s 19ms/step - loss: 139.7585
# Epoch 72/100
# 3/3 [==============================] - 0s 26ms/step - loss: 139.7631
# Epoch 73/100
# 3/3 [==============================] - 0s 23ms/step - loss: 139.7561
# Epoch 74/100
# 3/3 [==============================] - 0s 21ms/step - loss: 139.7581
# Epoch 75/100
# 3/3 [==============================] - 0s 30ms/step - loss: 139.7684
# Epoch 76/100
# 3/3 [==============================] - 0s 31ms/step - loss: 139.7626
# Epoch 77/100
# 3/3 [==============================] - 0s 31ms/step - loss: 139.7538
# Epoch 78/100
# 3/3 [==============================] - 0s 35ms/step - loss: 139.7538
# Epoch 79/100
# 3/3 [==============================] - 0s 30ms/step - loss: 139.7547
# Epoch 80/100
# 3/3 [==============================] - 0s 31ms/step - loss: 139.7568
# Epoch 81/100
# 3/3 [==============================] - 0s 31ms/step - loss: 139.7518
# Epoch 82/100
# 3/3 [==============================] - 0s 33ms/step - loss: 139.7495
# Epoch 83/100
# 3/3 [==============================] - 0s 30ms/step - loss: 139.7491
# Epoch 84/100
# 3/3 [==============================] - 0s 31ms/step - loss: 139.7538
# Epoch 85/100
# 3/3 [==============================] - 0s 29ms/step - loss: 139.7494
# Epoch 86/100
# 3/3 [==============================] - 0s 30ms/step - loss: 139.7517
# Epoch 87/100
# 3/3 [==============================] - 0s 33ms/step - loss: 139.7500
# Epoch 88/100
# 3/3 [==============================] - 0s 29ms/step - loss: 139.7530
# Epoch 89/100
# 3/3 [==============================] - 0s 35ms/step - loss: 139.7489
# Epoch 90/100
# 3/3 [==============================] - 0s 29ms/step - loss: 139.7450
# Epoch 91/100
# 3/3 [==============================] - 0s 29ms/step - loss: 139.7468
# Epoch 92/100
# 3/3 [==============================] - 0s 31ms/step - loss: 139.7461
# Epoch 93/100
# 3/3 [==============================] - 0s 30ms/step - loss: 139.7453
# Epoch 94/100
# 3/3 [==============================] - 0s 30ms/step - loss: 139.7495
# Epoch 95/100
# 3/3 [==============================] - 0s 30ms/step - loss: 139.7443
# Epoch 96/100
# 3/3 [==============================] - 0s 31ms/step - loss: 139.7514
# Epoch 97/100
# 3/3 [==============================] - 0s 32ms/step - loss: 139.7466
# Epoch 98/100
# 3/3 [==============================] - 0s 31ms/step - loss: 139.7446
# Epoch 99/100
# 3/3 [==============================] - 0s 33ms/step - loss: 139.7471
# Epoch 100/100
# 3/3 [==============================] - 0s 31ms/step - loss: 139.7466
# 1/1 [==============================] - 2s 2s/step
# Model Number: 807 with model MetricMotif in generation 6 of 10
# Model Number: 808 with model MetricMotif in generation 6 of 10
# Model Number: 809 with model MetricMotif in generation 6 of 10
# Model Number: 810 with model DatepartRegression in generation 6 of 10
# Model Number: 811 with model LastValueNaive in generation 6 of 10
# Model Number: 812 with model AverageValueNaive in generation 6 of 10
# Model Number: 813 with model SectionalMotif in generation 6 of 10
# Model Number: 814 with model AverageValueNaive in generation 6 of 10
# Model Number: 815 with model SectionalMotif in generation 6 of 10
# Model Number: 816 with model MultivariateMotif in generation 6 of 10
# Model Number: 817 with model Theta in generation 6 of 10
# Model Number: 818 with model SeasonalNaive in generation 6 of 10
# Model Number: 819 with model LastValueNaive in generation 6 of 10
# Model Number: 820 with model LastValueNaive in generation 6 of 10
# Model Number: 821 with model MetricMotif in generation 6 of 10
# Model Number: 822 with model NVAR in generation 6 of 10
# Template Eval Error: Exception('Transformer HolidayTransformer failed on fit') in model 822 in generation 6: NVAR
# Model Number: 823 with model UnivariateMotif in generation 6 of 10
# Model Number: 824 with model ARIMA in generation 6 of 10
# Model Number: 825 with model UnivariateMotif in generation 6 of 10
# Model Number: 826 with model MetricMotif in generation 6 of 10
# Model Number: 827 with model DatepartRegression in generation 6 of 10
# Model Number: 828 with model MultivariateMotif in generation 6 of 10
# Model Number: 829 with model SectionalMotif in generation 6 of 10
# Model Number: 830 with model LastValueNaive in generation 6 of 10
# Model Number: 831 with model NVAR in generation 6 of 10
# Model Number: 832 with model AverageValueNaive in generation 6 of 10
# Template Eval Error: Exception('Transformer MinMaxScaler failed on fit') in model 832 in generation 6: AverageValueNaive
# Model Number: 833 with model GLM in generation 6 of 10
# Model Number: 834 with model ConstantNaive in generation 6 of 10
# Model Number: 835 with model LastValueNaive in generation 6 of 10
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/links.py:198: RuntimeWarning: overflow encountered in exp
#   t = np.exp(-z)
# Model Number: 836 with model MetricMotif in generation 6 of 10
# Model Number: 837 with model MetricMotif in generation 6 of 10
# Model Number: 838 with model UnivariateMotif in generation 6 of 10
# Model Number: 839 with model ETS in generation 6 of 10
# Template Eval Error: ValueError("Model returned NaN due to a preprocessing transformer {'fillna': 'ffill_mean_biased', 'transformations': {'0': 'LocalLinearTrend', '1': 'KalmanSmoothing', '2': 'SeasonalDifference', '3': 'AlignLastValue', '4': 'AlignLastValue'}, 'transformation_params': {'0': {'rolling_window': 0.1, 'n_tails': 0.1, 'n_future': 90, 'method': 'mean', 'macro_micro': True}, '1': {'model_name': 'ucm_deterministic_trend', 'state_transition': [[1, 1], [0, 1]], 'process_noise': [[0.01, 0], [0, 0.01]], 'observation_model': [[1, 0]], 'observation_noise': 0.1, 'em_iter': None}, '2': {'lag_1': 12, 'method': 'Mean'}, '3': {'rows': 1, 'lag': 7, 'method': 'additive', 'strength': 1.0, 'first_value_only': False}, '4': {'rows': 1, 'lag': 1, 'method': 'multiplicative', 'strength': 1.0, 'first_value_only': False}}}. fail_on_forecast_nan=True") in model 839 in generation 6: ETS
# Model Number: 840 with model LastValueNaive in generation 6 of 10
# Model Number: 841 with model ConstantNaive in generation 6 of 10
# Model Number: 842 with model DatepartRegression in generation 6 of 10
# Model Number: 843 with model ConstantNaive in generation 6 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 843 in generation 6: ConstantNaive
# Model Number: 844 with model UnobservedComponents in generation 6 of 10
# Model Number: 845 with model MultivariateRegression in generation 6 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 845 in generation 6: MultivariateRegression
# Model Number: 846 with model GLS in generation 6 of 10
# Model Number: 847 with model Theta in generation 6 of 10
# Model Number: 848 with model SectionalMotif in generation 6 of 10
# Model Number: 849 with model ARIMA in generation 6 of 10
# 19:11:11 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# Model Number: 850 with model FBProphet in generation 6 of 10
# Model Number: 851 with model GLM in generation 6 of 10
# Model Number: 852 with model ARIMA in generation 6 of 10
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# Model Number: 853 with model ARIMA in generation 6 of 10
# Model Number: 854 with model SectionalMotif in generation 6 of 10
# Model Number: 855 with model MultivariateRegression in generation 6 of 10
# Model Number: 856 with model MetricMotif in generation 6 of 10
# Template Eval Error: ZeroDivisionError("Weights sum to zero, can't be normalized") in model 856 in generation 6: MetricMotif
# Model Number: 857 with model Theta in generation 6 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/decomposition/_fastica.py:708: FutureWarning: Starting in v1.3, whiten=True should be specified as whiten='arbitrary-variance' (its current behaviour). This behavior is deprecated in 1.1 and will raise ValueError in 1.3.
#   return self._fit_transform(X, compute_sources=True)
# Model Number: 858 with model GLS in generation 6 of 10
# Model Number: 859 with model FBProphet in generation 6 of 10
# 19:11:37 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# Model Number: 860 with model WindowRegression in generation 6 of 10
# Template Eval Error: Exception('Transformer BTCD failed on fit') in model 860 in generation 6: WindowRegression
# Model Number: 861 with model ConstantNaive in generation 6 of 10
# Model Number: 862 with model Theta in generation 6 of 10
# Model Number: 863 with model WindowRegression in generation 6 of 10
# Model Number: 864 with model WindowRegression in generation 6 of 10
# Model Number: 865 with model GLM in generation 6 of 10
# Model Number: 866 with model Theta in generation 6 of 10
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# Model Number: 867 with model UnivariateMotif in generation 6 of 10
# Model Number: 868 with model FBProphet in generation 6 of 10
# Model Number: 869 with model Theta in generation 6 of 10
# Model Number: 870 with model ETS in generation 6 of 10
# Model Number: 871 with model SeasonalNaive in generation 6 of 10
# Model Number: 872 with model AverageValueNaive in generation 6 of 10
# Model Number: 873 with model DatepartRegression in generation 6 of 10
# Model Number: 874 with model AverageValueNaive in generation 6 of 10
# Model Number: 875 with model WindowRegression in generation 6 of 10
# Model Number: 876 with model ConstantNaive in generation 6 of 10
# Model Number: 877 with model Theta in generation 6 of 10
# Model Number: 878 with model UnobservedComponents in generation 6 of 10
# Model Number: 879 with model ConstantNaive in generation 6 of 10
# Model Number: 880 with model LastValueNaive in generation 6 of 10
# Model Number: 881 with model ARIMA in generation 6 of 10
# Model Number: 882 with model LastValueNaive in generation 6 of 10
# Model Number: 883 with model GLS in generation 6 of 10
# Model Number: 884 with model DatepartRegression in generation 6 of 10
# Template Eval Error: Exception('Transformer HolidayTransformer failed on fit') in model 884 in generation 6: DatepartRegression
# Model Number: 885 with model Theta in generation 6 of 10
# Model Number: 886 with model MultivariateMotif in generation 6 of 10
# New Generation: 7 of 10
# Model Number: 887 with model Theta in generation 7 of 10
# Model Number: 888 with model SectionalMotif in generation 7 of 10
# Model Number: 889 with model DatepartRegression in generation 7 of 10
# Model Number: 890 with model FBProphet in generation 7 of 10
# Model Number: 891 with model UnivariateMotif in generation 7 of 10
# Template Eval Error: Exception('Transformer HolidayTransformer failed on fit') in model 891 in generation 7: UnivariateMotif
# Model Number: 892 with model NVAR in generation 7 of 10
# Model Number: 893 with model DatepartRegression in generation 7 of 10
# Template Eval Error: ValueError('Model DatepartRegression returned NaN for one or more series. fail_on_forecast_nan=True') in model 893 in generation 7: DatepartRegression
# Model Number: 894 with model MultivariateRegression in generation 7 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_regression.py:494: UserWarning: One or more samples have no neighbors within specified radius; predicting NaN.
#   warnings.warn(empty_warning_msg)
# Model Number: 895 with model GLS in generation 7 of 10
# Model Number: 896 with model Theta in generation 7 of 10
# Model Number: 897 with model ARIMA in generation 7 of 10
# Model Number: 898 with model Theta in generation 7 of 10
# Model Number: 899 with model SectionalMotif in generation 7 of 10
# Model Number: 900 with model ConstantNaive in generation 7 of 10
# Model Number: 901 with model Theta in generation 7 of 10
# Model Number: 902 with model UnivariateMotif in generation 7 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 902 in generation 7: UnivariateMotif
# Model Number: 903 with model MetricMotif in generation 7 of 10
# Model Number: 904 with model ConstantNaive in generation 7 of 10
# Model Number: 905 with model ARIMA in generation 7 of 10
# Model Number: 906 with model MetricMotif in generation 7 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 906 in generation 7: MetricMotif
# Model Number: 907 with model ARIMA in generation 7 of 10
# Model Number: 908 with model ConstantNaive in generation 7 of 10
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 908 in generation 7: ConstantNaive
# Model Number: 909 with model ARIMA in generation 7 of 10
# Model Number: 910 with model SeasonalNaive in generation 7 of 10
# Model Number: 911 with model SeasonalNaive in generation 7 of 10
# Model Number: 912 with model DatepartRegression in generation 7 of 10
# Model Number: 913 with model WindowRegression in generation 7 of 10
# Model Number: 914 with model DatepartRegression in generation 7 of 10
# Model Number: 915 with model MetricMotif in generation 7 of 10
# Model Number: 916 with model WindowRegression in generation 7 of 10
# Template Eval Error: Exception('Transformer RegressionFilter failed on fit') in model 916 in generation 7: WindowRegression
# Model Number: 917 with model GLS in generation 7 of 10
# Model Number: 918 with model SectionalMotif in generation 7 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 918 in generation 7: SectionalMotif
# Model Number: 919 with model MetricMotif in generation 7 of 10
# Model Number: 920 with model ETS in generation 7 of 10
# Model Number: 921 with model ARIMA in generation 7 of 10
# Model Number: 922 with model AverageValueNaive in generation 7 of 10
# Model Number: 923 with model LastValueNaive in generation 7 of 10
# Model Number: 924 with model ConstantNaive in generation 7 of 10
# Model Number: 925 with model GLM in generation 7 of 10
# Template Eval Error: Exception('Transformer Cointegration failed on fit') in model 925 in generation 7: GLM
# Model Number: 926 with model GLM in generation 7 of 10
# Model Number: 927 with model ConstantNaive in generation 7 of 10
# Model Number: 928 with model SectionalMotif in generation 7 of 10
# Model Number: 929 with model MultivariateMotif in generation 7 of 10
# Model Number: 930 with model UnivariateMotif in generation 7 of 10
# Model Number: 931 with model SeasonalNaive in generation 7 of 10
# Model Number: 932 with model MetricMotif in generation 7 of 10
# Model Number: 933 with model FBProphet in generation 7 of 10
# No anomalies detected.
# Template Eval Error: ValueError('more than 1 year of data is required for holiday detection.') in model 933 in generation 7: FBProphet
# Model Number: 934 with model MetricMotif in generation 7 of 10
# Model Number: 935 with model SeasonalNaive in generation 7 of 10
# Model Number: 936 with model MultivariateMotif in generation 7 of 10
# Model Number: 937 with model GLM in generation 7 of 10
# Template Eval Error: ValueError('regression_type=user and no future_regressor passed') in model 937 in generation 7: GLM
# Model Number: 938 with model WindowRegression in generation 7 of 10
# Model Number: 939 with model LastValueNaive in generation 7 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/decomposition/_fastica.py:708: FutureWarning: Starting in v1.3, whiten=True should be specified as whiten='arbitrary-variance' (its current behaviour). This behavior is deprecated in 1.1 and will raise ValueError in 1.3.
#   return self._fit_transform(X, compute_sources=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/decomposition/_fastica.py:708: FutureWarning: Starting in v1.3, whiten=True should be specified as whiten='arbitrary-variance' (its current behaviour). This behavior is deprecated in 1.1 and will raise ValueError in 1.3.
#   return self._fit_transform(X, compute_sources=True)
# Model Number: 940 with model DatepartRegression in generation 7 of 10
# Model Number: 941 with model WindowRegression in generation 7 of 10
# Model Number: 942 with model SeasonalNaive in generation 7 of 10
# Model Number: 943 with model ETS in generation 7 of 10
# Model Number: 944 with model AverageValueNaive in generation 7 of 10
# Model Number: 945 with model UnivariateMotif in generation 7 of 10
# Model Number: 946 with model DatepartRegression in generation 7 of 10
# Model Number: 947 with model ARIMA in generation 7 of 10
# Model Number: 948 with model LastValueNaive in generation 7 of 10
# Model Number: 949 with model GLS in generation 7 of 10
# Model Number: 950 with model SectionalMotif in generation 7 of 10
# Template Eval Error: LinAlgError('Singular matrix') in model 950 in generation 7: SectionalMotif
# Model Number: 951 with model ARDL in generation 7 of 10
# Model Number: 952 with model MetricMotif in generation 7 of 10
# Model Number: 953 with model ETS in generation 7 of 10
# Model Number: 954 with model ETS in generation 7 of 10
# Model Number: 955 with model Theta in generation 7 of 10
# Model Number: 956 with model FBProphet in generation 7 of 10
# Model Number: 957 with model UnobservedComponents in generation 7 of 10
# Model Number: 958 with model MetricMotif in generation 7 of 10
# Model Number: 959 with model ARIMA in generation 7 of 10
# Model Number: 960 with model ARIMA in generation 7 of 10
# Template Eval Error: Exception('Transformer ReplaceConstant failed on fit') in model 960 in generation 7: ARIMA
# Model Number: 961 with model ETS in generation 7 of 10
# Model Number: 962 with model Theta in generation 7 of 10
# Template Eval Error: Exception('Transformer Cointegration failed on fit') in model 962 in generation 7: Theta
# Model Number: 963 with model UnobservedComponents in generation 7 of 10
# Model Number: 964 with model ConstantNaive in generation 7 of 10
# Model Number: 965 with model Theta in generation 7 of 10
# Model Number: 966 with model UnivariateMotif in generation 7 of 10
# Model Number: 967 with model UnobservedComponents in generation 7 of 10
# Model Number: 968 with model WindowRegression in generation 7 of 10
# Model Number: 969 with model LastValueNaive in generation 7 of 10
# Model Number: 970 with model DatepartRegression in generation 7 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Model Number: 971 with model MultivariateMotif in generation 7 of 10
# Model Number: 972 with model ARIMA in generation 7 of 10
# Template Eval Error: Exception('Transformer BTCD failed on fit') in model 972 in generation 7: ARIMA
# Model Number: 973 with model SeasonalNaive in generation 7 of 10
# Model Number: 974 with model ConstantNaive in generation 7 of 10
# Model Number: 975 with model ETS in generation 7 of 10
# Model Number: 976 with model UnivariateMotif in generation 7 of 10
# Model Number: 977 with model NVAR in generation 7 of 10
# Model Number: 978 with model MultivariateMotif in generation 7 of 10
# Model Number: 979 with model ETS in generation 7 of 10
# Model Number: 980 with model SectionalMotif in generation 7 of 10
# Model Number: 981 with model LastValueNaive in generation 7 of 10
# Model Number: 982 with model GLM in generation 7 of 10
# Model Number: 983 with model ARIMA in generation 7 of 10
# Template Eval Error: Exception('Transformer ReplaceConstant failed on fit') in model 983 in generation 7: ARIMA
# Model Number: 984 with model Theta in generation 7 of 10
# Template Eval Error: Exception('Transformer PCA failed on inverse') in model 984 in generation 7: Theta
# Model Number: 985 with model MetricMotif in generation 7 of 10
# Model Number: 986 with model WindowRegression in generation 7 of 10
# New Generation: 8 of 10
# Model Number: 987 with model Theta in generation 8 of 10
# Model Number: 988 with model ETS in generation 8 of 10
# Model Number: 989 with model MultivariateMotif in generation 8 of 10
# Model Number: 990 with model AverageValueNaive in generation 8 of 10
# Model Number: 991 with model ARIMA in generation 8 of 10
# Model Number: 992 with model SeasonalNaive in generation 8 of 10
# Model Number: 993 with model ConstantNaive in generation 8 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.256e+06, tolerance: 5.869e+02
#   model = cd_fast.enet_coordinate_descent(
# Model Number: 994 with model SeasonalNaive in generation 8 of 10
# Model Number: 995 with model MultivariateMotif in generation 8 of 10
# Model Number: 996 with model Theta in generation 8 of 10
# Model Number: 997 with model SectionalMotif in generation 8 of 10
# Model Number: 998 with model DatepartRegression in generation 8 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 998 in generation 8: DatepartRegression
# Model Number: 999 with model ARIMA in generation 8 of 10
# Model Number: 1000 with model ARIMA in generation 8 of 10
# Model Number: 1001 with model Theta in generation 8 of 10
# Model Number: 1002 with model ETS in generation 8 of 10
# Model Number: 1003 with model SectionalMotif in generation 8 of 10
# Model Number: 1004 with model LastValueNaive in generation 8 of 10
# Model Number: 1005 with model ARDL in generation 8 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Model Number: 1006 with model UnobservedComponents in generation 8 of 10
# Model Number: 1007 with model ConstantNaive in generation 8 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 1007 in generation 8: ConstantNaive
# Model Number: 1008 with model Theta in generation 8 of 10
# Model Number: 1009 with model MetricMotif in generation 8 of 10
# Model Number: 1010 with model ConstantNaive in generation 8 of 10
# Model Number: 1011 with model LastValueNaive in generation 8 of 10
# Model Number: 1012 with model DatepartRegression in generation 8 of 10
# Model Number: 1013 with model UnobservedComponents in generation 8 of 10
# Model Number: 1014 with model FBProphet in generation 8 of 10
# Template Eval Error: ValueError('more than 1 year of data is required for holiday detection.') in model 1014 in generation 8: FBProphet
# Model Number: 1015 with model DatepartRegression in generation 8 of 10
# Model Number: 1016 with model Theta in generation 8 of 10
# Model Number: 1017 with model WindowRegression in generation 8 of 10
# Model Number: 1018 with model LastValueNaive in generation 8 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.230e+03, tolerance: 6.210e+02
#   model = cd_fast.enet_coordinate_descent(
# Model Number: 1019 with model GLM in generation 8 of 10
# Model Number: 1020 with model MetricMotif in generation 8 of 10
# Model Number: 1021 with model FBProphet in generation 8 of 10
# 19:12:58 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# Model Number: 1022 with model MultivariateMotif in generation 8 of 10
# Model Number: 1023 with model GLM in generation 8 of 10
# Model Number: 1024 with model SeasonalNaive in generation 8 of 10
# Model Number: 1025 with model MetricMotif in generation 8 of 10
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# Model Number: 1026 with model ConstantNaive in generation 8 of 10
# Model Number: 1027 with model AverageValueNaive in generation 8 of 10
# Model Number: 1028 with model GLM in generation 8 of 10
# Model Number: 1029 with model ETS in generation 8 of 10
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/links.py:198: RuntimeWarning: overflow encountered in exp
#   t = np.exp(-z)
# Model Number: 1030 with model SectionalMotif in generation 8 of 10
# Model Number: 1031 with model ARIMA in generation 8 of 10
# Model Number: 1032 with model UnivariateMotif in generation 8 of 10
# Model Number: 1033 with model ETS in generation 8 of 10
# Model Number: 1034 with model UnobservedComponents in generation 8 of 10
# Model Number: 1035 with model SeasonalNaive in generation 8 of 10
# Model Number: 1036 with model NVAR in generation 8 of 10
# Model Number: 1037 with model UnivariateMotif in generation 8 of 10
# Model Number: 1038 with model SectionalMotif in generation 8 of 10
# Model Number: 1039 with model ARIMA in generation 8 of 10
# Model Number: 1040 with model UnivariateMotif in generation 8 of 10
# Model Number: 1041 with model AverageValueNaive in generation 8 of 10
# Template Eval Error: Exception('Transformer HolidayTransformer failed on fit') in model 1041 in generation 8: AverageValueNaive
# Model Number: 1042 with model WindowRegression in generation 8 of 10
# Model Number: 1043 with model DatepartRegression in generation 8 of 10
# Model Number: 1044 with model MultivariateRegression in generation 8 of 10
# Model Number: 1045 with model LastValueNaive in generation 8 of 10
# Model Number: 1046 with model ConstantNaive in generation 8 of 10
# Model Number: 1047 with model FBProphet in generation 8 of 10
# 19:13:08 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# Model Number: 1048 with model GLM in generation 8 of 10
# Model Number: 1049 with model DatepartRegression in generation 8 of 10
# Template Eval Error: ValueError('Model DatepartRegression returned NaN for one or more series. fail_on_forecast_nan=True') in model 1049 in generation 8: DatepartRegression
# Model Number: 1050 with model UnivariateMotif in generation 8 of 10
# Model Number: 1051 with model UnivariateMotif in generation 8 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_regression.py:494: UserWarning: One or more samples have no neighbors within specified radius; predicting NaN.
#   warnings.warn(empty_warning_msg)
# Model Number: 1052 with model WindowRegression in generation 8 of 10
# Model Number: 1053 with model ARIMA in generation 8 of 10
# Model Number: 1054 with model ETS in generation 8 of 10
# Model Number: 1055 with model MultivariateRegression in generation 8 of 10
# Model Number: 1056 with model MetricMotif in generation 8 of 10
# Model Number: 1057 with model ETS in generation 8 of 10
# Model Number: 1058 with model ETS in generation 8 of 10
# Model Number: 1059 with model ARIMA in generation 8 of 10
# Model Number: 1060 with model SectionalMotif in generation 8 of 10
# Model Number: 1061 with model ARIMA in generation 8 of 10
# Template Eval Error: Exception('Transformer RegressionFilter failed on fit') in model 1061 in generation 8: ARIMA
# Model Number: 1062 with model MultivariateMotif in generation 8 of 10
# Model Number: 1063 with model ConstantNaive in generation 8 of 10
# Model Number: 1064 with model ConstantNaive in generation 8 of 10
# Model Number: 1065 with model WindowRegression in generation 8 of 10
# Model Number: 1066 with model LastValueNaive in generation 8 of 10
# Model Number: 1067 with model SectionalMotif in generation 8 of 10
# Model Number: 1068 with model GLS in generation 8 of 10
# Model Number: 1069 with model LastValueNaive in generation 8 of 10
# Model Number: 1070 with model GLM in generation 8 of 10
# Model Number: 1071 with model GLM in generation 8 of 10
# Model Number: 1072 with model Theta in generation 8 of 10
# Model Number: 1073 with model UnobservedComponents in generation 8 of 10
# Model Number: 1074 with model SectionalMotif in generation 8 of 10
# Model Number: 1075 with model ETS in generation 8 of 10
# Model Number: 1076 with model LastValueNaive in generation 8 of 10
# Model Number: 1077 with model WindowRegression in generation 8 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 1077 in generation 8: WindowRegression
# Model Number: 1078 with model LastValueNaive in generation 8 of 10
# Model Number: 1079 with model MetricMotif in generation 8 of 10
# Model Number: 1080 with model ConstantNaive in generation 8 of 10
# Model Number: 1081 with model MetricMotif in generation 8 of 10
# Model Number: 1082 with model UnivariateMotif in generation 8 of 10
# Model Number: 1083 with model WindowRegression in generation 8 of 10
# Model Number: 1084 with model DatepartRegression in generation 8 of 10
# Model Number: 1085 with model ARIMA in generation 8 of 10
# Template Eval Error: Exception('Transformer RobustScaler failed on fit') in model 1085 in generation 8: ARIMA
# Model Number: 1086 with model Theta in generation 8 of 10
# New Generation: 9 of 10
# Model Number: 1087 with model UnobservedComponents in generation 9 of 10
# 19:13:42 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# Model Number: 1088 with model GLM in generation 9 of 10
# Template Eval Error: Exception('Transformer Cointegration failed on fit') in model 1088 in generation 9: GLM
# Model Number: 1089 with model FBProphet in generation 9 of 10
# Model Number: 1090 with model ConstantNaive in generation 9 of 10
# Model Number: 1091 with model LastValueNaive in generation 9 of 10
# Template Eval Error: Exception('Transformer BTCD failed on fit') in model 1091 in generation 9: LastValueNaive
# Model Number: 1092 with model DatepartRegression in generation 9 of 10
# Template Eval Error: ValueError('Model DatepartRegression returned NaN for one or more series. fail_on_forecast_nan=True') in model 1092 in generation 9: DatepartRegression
# Model Number: 1093 with model Theta in generation 9 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_regression.py:494: UserWarning: One or more samples have no neighbors within specified radius; predicting NaN.
#   warnings.warn(empty_warning_msg)
# Model Number: 1094 with model SectionalMotif in generation 9 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 1094 in generation 9: SectionalMotif
# Model Number: 1095 with model MultivariateMotif in generation 9 of 10
# Model Number: 1096 with model Theta in generation 9 of 10
# Model Number: 1097 with model WindowRegression in generation 9 of 10
# Model Number: 1098 with model Theta in generation 9 of 10
# Model Number: 1099 with model ARIMA in generation 9 of 10
# Model Number: 1100 with model MultivariateRegression in generation 9 of 10
# Model Number: 1101 with model DatepartRegression in generation 9 of 10
# Model Number: 1102 with model MultivariateMotif in generation 9 of 10
# Model Number: 1103 with model ETS in generation 9 of 10
# Model Number: 1104 with model SeasonalNaive in generation 9 of 10
# Model Number: 1105 with model SeasonalNaive in generation 9 of 10
# Model Number: 1106 with model UnivariateMotif in generation 9 of 10
# Model Number: 1107 with model ConstantNaive in generation 9 of 10
# Model Number: 1108 with model DatepartRegression in generation 9 of 10
# Epoch 1/50
# 24/24 [==============================] - 7s 29ms/step - loss: 17.6572
# Epoch 2/50
# 24/24 [==============================] - 0s 20ms/step - loss: 10.2042
# Epoch 3/50
# 24/24 [==============================] - 0s 20ms/step - loss: 9.8830
# Epoch 4/50
# 24/24 [==============================] - 0s 20ms/step - loss: 8.8193
# Epoch 5/50
# 24/24 [==============================] - 0s 20ms/step - loss: 8.1324
# Epoch 6/50
# 24/24 [==============================] - 0s 19ms/step - loss: 10.2513
# Epoch 7/50
# 24/24 [==============================] - 0s 20ms/step - loss: 8.4859
# Epoch 8/50
# 24/24 [==============================] - 0s 19ms/step - loss: 9.4954
# Epoch 9/50
# 24/24 [==============================] - 1s 21ms/step - loss: 9.8132
# Epoch 10/50
# 24/24 [==============================] - 0s 19ms/step - loss: 8.6078
# Epoch 11/50
# 24/24 [==============================] - 0s 20ms/step - loss: 7.9400
# Epoch 12/50
# 24/24 [==============================] - 0s 19ms/step - loss: 8.3916
# Epoch 13/50
# 24/24 [==============================] - 1s 21ms/step - loss: 9.5324
# Epoch 14/50
# 24/24 [==============================] - 0s 20ms/step - loss: 8.1230
# Epoch 15/50
# 24/24 [==============================] - 1s 21ms/step - loss: 8.8585
# Epoch 16/50
# 24/24 [==============================] - 0s 20ms/step - loss: 8.1958
# Epoch 17/50
# 24/24 [==============================] - 1s 21ms/step - loss: 8.6125
# Epoch 18/50
# 24/24 [==============================] - 0s 20ms/step - loss: 8.7395
# Epoch 19/50
# 24/24 [==============================] - 1s 21ms/step - loss: 9.2250
# Epoch 20/50
# 24/24 [==============================] - 0s 20ms/step - loss: 7.8763
# Epoch 21/50
# 24/24 [==============================] - 1s 22ms/step - loss: 8.2534
# Epoch 22/50
# 24/24 [==============================] - 1s 30ms/step - loss: 7.9846
# Epoch 23/50
# 24/24 [==============================] - 1s 29ms/step - loss: 8.4098
# Epoch 24/50
# 24/24 [==============================] - 1s 29ms/step - loss: 8.6481
# Epoch 25/50
# 24/24 [==============================] - 1s 26ms/step - loss: 8.4071
# Epoch 26/50
# 24/24 [==============================] - 0s 21ms/step - loss: 8.1559
# Epoch 27/50
# 24/24 [==============================] - 0s 20ms/step - loss: 8.4260
# Epoch 28/50
# 24/24 [==============================] - 0s 20ms/step - loss: 8.8642
# Epoch 29/50
# 24/24 [==============================] - 0s 20ms/step - loss: 8.1002
# Epoch 30/50
# 24/24 [==============================] - 1s 21ms/step - loss: 8.4264
# Epoch 31/50
# 24/24 [==============================] - 0s 20ms/step - loss: 8.0205
# Epoch 32/50
# 24/24 [==============================] - 0s 21ms/step - loss: 7.9274
# Epoch 33/50
# 24/24 [==============================] - 0s 20ms/step - loss: 8.3667
# Epoch 34/50
# 24/24 [==============================] - 1s 21ms/step - loss: 8.2908
# Epoch 35/50
# 24/24 [==============================] - 0s 20ms/step - loss: 7.8889
# Epoch 36/50
# 24/24 [==============================] - 1s 21ms/step - loss: 8.3190
# Epoch 37/50
# 24/24 [==============================] - 0s 20ms/step - loss: 8.3350
# Epoch 38/50
# 24/24 [==============================] - 1s 21ms/step - loss: 8.5925
# Epoch 39/50
# 24/24 [==============================] - 1s 21ms/step - loss: 8.0474
# Epoch 40/50
# 24/24 [==============================] - 1s 21ms/step - loss: 8.4777
# Epoch 41/50
# 24/24 [==============================] - 0s 20ms/step - loss: 8.5528
# Epoch 42/50
# 24/24 [==============================] - 1s 21ms/step - loss: 8.5945
# Epoch 43/50
# 24/24 [==============================] - 0s 20ms/step - loss: 7.9385
# Epoch 44/50
# 24/24 [==============================] - 0s 21ms/step - loss: 8.1720
# Epoch 45/50
# 24/24 [==============================] - 1s 25ms/step - loss: 8.6468
# Epoch 46/50
# 24/24 [==============================] - 1s 31ms/step - loss: 8.9907
# Epoch 47/50
# 24/24 [==============================] - 1s 30ms/step - loss: 8.6712
# Epoch 48/50
# 24/24 [==============================] - 1s 30ms/step - loss: 7.9179
# Epoch 49/50
# 24/24 [==============================] - 1s 24ms/step - loss: 8.4244
# Epoch 50/50
# 24/24 [==============================] - 0s 20ms/step - loss: 8.2085
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7b372622c310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 1s/step
# Model Number: 1109 with model SectionalMotif in generation 9 of 10
# Model Number: 1110 with model ETS in generation 9 of 10
# Model Number: 1111 with model MetricMotif in generation 9 of 10
# Model Number: 1112 with model ETS in generation 9 of 10
# Model Number: 1113 with model SectionalMotif in generation 9 of 10
# Model Number: 1114 with model Theta in generation 9 of 10
# Template Eval Error: Exception('Transformer BTCD failed on fit') in model 1114 in generation 9: Theta
# Model Number: 1115 with model GLM in generation 9 of 10
# Model Number: 1116 with model ARIMA in generation 9 of 10
# Model Number: 1117 with model ARIMA in generation 9 of 10
# Model Number: 1118 with model LastValueNaive in generation 9 of 10
# Model Number: 1119 with model SectionalMotif in generation 9 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 1119 in generation 9: SectionalMotif
# Model Number: 1120 with model Theta in generation 9 of 10
# Model Number: 1121 with model WindowRegression in generation 9 of 10
# Model Number: 1122 with model AverageValueNaive in generation 9 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 1122 in generation 9: AverageValueNaive
# Model Number: 1123 with model ARIMA in generation 9 of 10
# Model Number: 1124 with model ARDL in generation 9 of 10
# Model Number: 1125 with model MetricMotif in generation 9 of 10
# Model Number: 1126 with model MultivariateMotif in generation 9 of 10
# Model Number: 1127 with model ConstantNaive in generation 9 of 10
# Model Number: 1128 with model FBProphet in generation 9 of 10
# Model Number: 1129 with model GLM in generation 9 of 10
# Model Number: 1130 with model FBProphet in generation 9 of 10
# 19:14:56 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# Model Number: 1131 with model Theta in generation 9 of 10
# Model Number: 1132 with model ETS in generation 9 of 10
# Model Number: 1133 with model MetricMotif in generation 9 of 10
# Model Number: 1134 with model MetricMotif in generation 9 of 10
# Model Number: 1135 with model SeasonalNaive in generation 9 of 10
# Model Number: 1136 with model Theta in generation 9 of 10
# Model Number: 1137 with model GLM in generation 9 of 10
# Model Number: 1138 with model UnivariateMotif in generation 9 of 10
# Model Number: 1139 with model MultivariateRegression in generation 9 of 10
# Template Eval Error: Exception('Transformer Cointegration failed on fit') in model 1139 in generation 9: MultivariateRegression
# Model Number: 1140 with model Theta in generation 9 of 10
# Model Number: 1141 with model SeasonalNaive in generation 9 of 10
# Model Number: 1142 with model MetricMotif in generation 9 of 10
# Model Number: 1143 with model LastValueNaive in generation 9 of 10
# Model Number: 1144 with model ConstantNaive in generation 9 of 10
# Model Number: 1145 with model ConstantNaive in generation 9 of 10
# Model Number: 1146 with model ETS in generation 9 of 10
# Model Number: 1147 with model SeasonalNaive in generation 9 of 10
# Model Number: 1148 with model UnivariateMotif in generation 9 of 10
# Model Number: 1149 with model SectionalMotif in generation 9 of 10
# Model Number: 1150 with model WindowRegression in generation 9 of 10
# Model Number: 1151 with model MultivariateMotif in generation 9 of 10
# Model Number: 1152 with model LastValueNaive in generation 9 of 10
# Model Number: 1153 with model MultivariateMotif in generation 9 of 10
# Model Number: 1154 with model ARIMA in generation 9 of 10
# Model Number: 1155 with model SeasonalNaive in generation 9 of 10
# Model Number: 1156 with model MetricMotif in generation 9 of 10
# Template Eval Error: Exception('Transformer RegressionFilter failed on fit') in model 1156 in generation 9: MetricMotif
# Model Number: 1157 with model WindowRegression in generation 9 of 10
# Model Number: 1158 with model ARIMA in generation 9 of 10
# Model Number: 1159 with model ARIMA in generation 9 of 10
# Model Number: 1160 with model GLM in generation 9 of 10
# Model Number: 1161 with model NVAR in generation 9 of 10
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 1161 in generation 9: NVAR
# Model Number: 1162 with model ConstantNaive in generation 9 of 10
# Model Number: 1163 with model ARIMA in generation 9 of 10
# Model Number: 1164 with model SeasonalNaive in generation 9 of 10
# Model Number: 1165 with model UnobservedComponents in generation 9 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 1165 in generation 9: UnobservedComponents
# Model Number: 1166 with model MetricMotif in generation 9 of 10
# Model Number: 1167 with model ARIMA in generation 9 of 10
# Model Number: 1168 with model DatepartRegression in generation 9 of 10
# Model Number: 1169 with model MetricMotif in generation 9 of 10
# Template Eval Error: Exception('Transformer RegressionFilter failed on fit') in model 1169 in generation 9: MetricMotif
# Model Number: 1170 with model ARIMA in generation 9 of 10
# Model Number: 1171 with model Theta in generation 9 of 10
# Model Number: 1172 with model ConstantNaive in generation 9 of 10
# Template Eval Error: Exception('Transformer HolidayTransformer failed on fit') in model 1172 in generation 9: ConstantNaive
# Model Number: 1173 with model MetricMotif in generation 9 of 10
# Template Eval Error: Exception('Transformer HolidayTransformer failed on fit') in model 1173 in generation 9: MetricMotif
# Model Number: 1174 with model Theta in generation 9 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 1174 in generation 9: Theta
# Model Number: 1175 with model Theta in generation 9 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Model Number: 1176 with model ARIMA in generation 9 of 10
# Model Number: 1177 with model SectionalMotif in generation 9 of 10
# Model Number: 1178 with model DatepartRegression in generation 9 of 10
# Model Number: 1179 with model UnivariateMotif in generation 9 of 10
# Model Number: 1180 with model UnivariateMotif in generation 9 of 10
# Model Number: 1181 with model UnivariateMotif in generation 9 of 10
# Model Number: 1182 with model SectionalMotif in generation 9 of 10
# Model Number: 1183 with model AverageValueNaive in generation 9 of 10
# Model Number: 1184 with model WindowRegression in generation 9 of 10
# Template Eval Error: Exception('Transformer HolidayTransformer failed on fit') in model 1184 in generation 9: WindowRegression
# Model Number: 1185 with model UnivariateMotif in generation 9 of 10
# Model Number: 1186 with model MetricMotif in generation 9 of 10
# New Generation: 10 of 10
# Model Number: 1187 with model SectionalMotif in generation 10 of 10
# Model Number: 1188 with model MetricMotif in generation 10 of 10
# Model Number: 1189 with model ARIMA in generation 10 of 10
# Model Number: 1190 with model ARIMA in generation 10 of 10
# Model Number: 1191 with model LastValueNaive in generation 10 of 10
# Template Eval Error: Exception('Transformer RobustScaler failed on fit') in model 1191 in generation 10: LastValueNaive
# Model Number: 1192 with model Theta in generation 10 of 10
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 1192 in generation 10: Theta
# Model Number: 1193 with model ARIMA in generation 10 of 10
# Model Number: 1194 with model ConstantNaive in generation 10 of 10
# Model Number: 1195 with model Theta in generation 10 of 10
# Model Number: 1196 with model DatepartRegression in generation 10 of 10
# Model Number: 1197 with model MetricMotif in generation 10 of 10
# Model Number: 1198 with model LastValueNaive in generation 10 of 10
# Model Number: 1199 with model MetricMotif in generation 10 of 10
# Model Number: 1200 with model MetricMotif in generation 10 of 10
# Model Number: 1201 with model ConstantNaive in generation 10 of 10
# Model Number: 1202 with model ConstantNaive in generation 10 of 10
# Model Number: 1203 with model ConstantNaive in generation 10 of 10
# Model Number: 1204 with model SeasonalNaive in generation 10 of 10
# Template Eval Error: Exception('Transformer HolidayTransformer failed on fit') in model 1204 in generation 10: SeasonalNaive
# Model Number: 1205 with model LastValueNaive in generation 10 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.5498e-25): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# Model Number: 1206 with model ARIMA in generation 10 of 10
# Model Number: 1207 with model ETS in generation 10 of 10
# Model Number: 1208 with model NVAR in generation 10 of 10
# Model Number: 1209 with model UnivariateMotif in generation 10 of 10
# Model Number: 1210 with model LastValueNaive in generation 10 of 10
# Model Number: 1211 with model ConstantNaive in generation 10 of 10
# Model Number: 1212 with model ConstantNaive in generation 10 of 10
# Model Number: 1213 with model ARIMA in generation 10 of 10
# Model Number: 1214 with model MetricMotif in generation 10 of 10
# Model Number: 1215 with model WindowRegression in generation 10 of 10
# Model Number: 1216 with model SectionalMotif in generation 10 of 10
# Model Number: 1217 with model MetricMotif in generation 10 of 10
# Model Number: 1218 with model Theta in generation 10 of 10
# Model Number: 1219 with model AverageValueNaive in generation 10 of 10
# Model Number: 1220 with model ARIMA in generation 10 of 10
# Model Number: 1221 with model NVAR in generation 10 of 10
# Model Number: 1222 with model GLM in generation 10 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 1222 in generation 10: GLM
# Model Number: 1223 with model DatepartRegression in generation 10 of 10
# Template Eval Error: Exception('Transformer QuantileTransformer failed on fit') in model 1223 in generation 10: DatepartRegression
# Model Number: 1224 with model UnobservedComponents in generation 10 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 1224 in generation 10: UnobservedComponents
# Model Number: 1225 with model SectionalMotif in generation 10 of 10
# Model Number: 1226 with model WindowRegression in generation 10 of 10
# Model Number: 1227 with model DatepartRegression in generation 10 of 10
# Model Number: 1228 with model ARIMA in generation 10 of 10
# Model Number: 1229 with model ARIMA in generation 10 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 1229 in generation 10: ARIMA
# Model Number: 1230 with model ConstantNaive in generation 10 of 10
# Model Number: 1231 with model UnivariateMotif in generation 10 of 10
# Model Number: 1232 with model GLM in generation 10 of 10
# Model Number: 1233 with model MultivariateMotif in generation 10 of 10
# Model Number: 1234 with model SeasonalNaive in generation 10 of 10
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# Model Number: 1235 with model ETS in generation 10 of 10
# Model Number: 1236 with model GLM in generation 10 of 10
# Model Number: 1237 with model ETS in generation 10 of 10
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /usr/local/lib/python3.10/dist-packages/autots/tools/fast_kalman.py:1306: RuntimeWarning: invalid value encountered in matmul
#   return np.matmul(A, np.swapaxes(B, -1, -2))
# /usr/local/lib/python3.10/dist-packages/autots/tools/fast_kalman.py:1293: RuntimeWarning: invalid value encountered in matmul
#   return np.matmul(A, B)
# Template Eval Error: ValueError('Model ETS returned NaN for one or more series. fail_on_forecast_nan=True') in model 1237 in generation 10: ETS
# Model Number: 1238 with model LastValueNaive in generation 10 of 10
# Model Number: 1239 with model MultivariateMotif in generation 10 of 10
# /usr/local/lib/python3.10/dist-packages/sklearn/decomposition/_fastica.py:708: FutureWarning: Starting in v1.3, whiten=True should be specified as whiten='arbitrary-variance' (its current behaviour). This behavior is deprecated in 1.1 and will raise ValueError in 1.3.
#   return self._fit_transform(X, compute_sources=True)
# Model Number: 1240 with model ETS in generation 10 of 10
# Model Number: 1241 with model UnobservedComponents in generation 10 of 10
# Model Number: 1242 with model AverageValueNaive in generation 10 of 10
# Model Number: 1243 with model Theta in generation 10 of 10
# Template Eval Error: Exception('Transformer HolidayTransformer failed on fit') in model 1243 in generation 10: Theta
# Model Number: 1244 with model ARDL in generation 10 of 10
# Model Number: 1245 with model ConstantNaive in generation 10 of 10
# Model Number: 1246 with model UnivariateMotif in generation 10 of 10
# Model Number: 1247 with model ARIMA in generation 10 of 10
# Model Number: 1248 with model UnivariateMotif in generation 10 of 10
# Model Number: 1249 with model DatepartRegression in generation 10 of 10
# Model Number: 1250 with model SeasonalNaive in generation 10 of 10
# Model Number: 1251 with model GLM in generation 10 of 10
# Model Number: 1252 with model GLM in generation 10 of 10
# Model Number: 1253 with model ARIMA in generation 10 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 1253 in generation 10: ARIMA
# Model Number: 1254 with model ETS in generation 10 of 10
# Model Number: 1255 with model MetricMotif in generation 10 of 10
# /usr/local/lib/python3.10/dist-packages/autots/tools/thresholding.py:204: RuntimeWarning: overflow encountered in double_scalars
#   (1 + mean_perc_decrease) ** self.mean_weight
# Model Number: 1256 with model UnivariateMotif in generation 10 of 10
# Model Number: 1257 with model SectionalMotif in generation 10 of 10
# Template Eval Error: Exception('Transformer Cointegration failed on fit') in model 1257 in generation 10: SectionalMotif
# Model Number: 1258 with model MetricMotif in generation 10 of 10
# Model Number: 1259 with model LastValueNaive in generation 10 of 10
# Model Number: 1260 with model Theta in generation 10 of 10
# Model Number: 1261 with model DatepartRegression in generation 10 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 1261 in generation 10: DatepartRegression
# Model Number: 1262 with model Ensemble in generation 11 of Ensembles
# Model Number: 1263 with model Ensemble in generation 11 of Ensembles
# Model Number: 1264 with model Ensemble in generation 11 of Ensembles
# Model Number: 1265 with model Ensemble in generation 11 of Ensembles
# Model Number: 1266 with model Ensemble in generation 11 of Ensembles
# Model Number: 1267 with model Ensemble in generation 11 of Ensembles
# Model Number: 1268 with model Ensemble in generation 11 of Ensembles
# Model Number: 1269 with model Ensemble in generation 11 of Ensembles
# Validation Round: 1
# Model Number: 1 of 187 with model MetricMotif for Validation 1
# 📈 1 - MetricMotif with avg smape 8.26:
# Model Number: 2 of 187 with model Ensemble for Validation 1
# 2 - Ensemble with avg smape 8.26:
# Model Number: 3 of 187 with model Ensemble for Validation 1
# 3 - Ensemble with avg smape 8.26:
# Model Number: 4 of 187 with model MetricMotif for Validation 1
# 4 - MetricMotif with avg smape 8.26:
# Model Number: 5 of 187 with model MetricMotif for Validation 1
# 5 - MetricMotif with avg smape 8.26:
# Model Number: 6 of 187 with model MetricMotif for Validation 1
# 6 - MetricMotif with avg smape 8.26:
# Model Number: 7 of 187 with model MetricMotif for Validation 1
# 7 - MetricMotif with avg smape 8.26:
# Model Number: 8 of 187 with model Ensemble for Validation 1
# 8 - Ensemble with avg smape 8.26:
# Model Number: 9 of 187 with model Ensemble for Validation 1
# 9 - Ensemble with avg smape 8.74:
# Model Number: 10 of 187 with model MetricMotif for Validation 1
# 10 - MetricMotif with avg smape 8.49:
# Model Number: 11 of 187 with model MetricMotif for Validation 1
# 11 - MetricMotif with avg smape 8.32:
# Model Number: 12 of 187 with model MetricMotif for Validation 1
# 📈 12 - MetricMotif with avg smape 8.16:
# Model Number: 13 of 187 with model MetricMotif for Validation 1
# 13 - MetricMotif with avg smape 8.29:
# Model Number: 14 of 187 with model Ensemble for Validation 1
# 14 - Ensemble with avg smape 9.0:
# Model Number: 15 of 187 with model Theta for Validation 1
# 15 - Theta with avg smape 9.25:
# Model Number: 16 of 187 with model Theta for Validation 1
# 16 - Theta with avg smape 9.25:
# Model Number: 17 of 187 with model Theta for Validation 1
# 17 - Theta with avg smape 9.25:
# Model Number: 18 of 187 with model Ensemble for Validation 1
# 18 - Ensemble with avg smape 9.14:
# Model Number: 19 of 187 with model Ensemble for Validation 1
# 19 - Ensemble with avg smape 9.18:
# Model Number: 20 of 187 with model Theta for Validation 1
# 20 - Theta with avg smape 9.25:
# Model Number: 21 of 187 with model Ensemble for Validation 1
# 21 - Ensemble with avg smape 9.46:
# Model Number: 22 of 187 with model Theta for Validation 1
# 22 - Theta with avg smape 9.26:
# Model Number: 23 of 187 with model Theta for Validation 1
# 23 - Theta with avg smape 9.24:
# Model Number: 24 of 187 with model Theta for Validation 1
# 24 - Theta with avg smape 9.24:
# Model Number: 25 of 187 with model Theta for Validation 1
# 25 - Theta with avg smape 9.24:
# Model Number: 26 of 187 with model Theta for Validation 1
# 26 - Theta with avg smape 9.24:
# Model Number: 27 of 187 with model ARIMA for Validation 1
# 27 - ARIMA with avg smape 9.5:
# Model Number: 28 of 187 with model ARIMA for Validation 1
# 28 - ARIMA with avg smape 9.78:
# Model Number: 29 of 187 with model ARIMA for Validation 1
# 29 - ARIMA with avg smape 9.78:
# Model Number: 30 of 187 with model ARIMA for Validation 1
# 30 - ARIMA with avg smape 8.69:
# Model Number: 31 of 187 with model ARIMA for Validation 1
# 31 - ARIMA with avg smape 9.55:
# Model Number: 32 of 187 with model UnivariateMotif for Validation 1
# 32 - UnivariateMotif with avg smape 9.79:
# Model Number: 33 of 187 with model UnivariateMotif for Validation 1
# 33 - UnivariateMotif with avg smape 9.79:
# Model Number: 34 of 187 with model UnivariateMotif for Validation 1
# 34 - UnivariateMotif with avg smape 9.78:
# Model Number: 35 of 187 with model UnivariateMotif for Validation 1
# 35 - UnivariateMotif with avg smape 9.78:
# Model Number: 36 of 187 with model ConstantNaive for Validation 1
# 36 - ConstantNaive with avg smape 9.98:
# Model Number: 37 of 187 with model ConstantNaive for Validation 1
# 37 - ConstantNaive with avg smape 9.98:
# Model Number: 38 of 187 with model ConstantNaive for Validation 1
# 38 - ConstantNaive with avg smape 9.98:
# Model Number: 39 of 187 with model ConstantNaive for Validation 1
# 39 - ConstantNaive with avg smape 9.82:
# Model Number: 40 of 187 with model ConstantNaive for Validation 1
# 40 - ConstantNaive with avg smape 10.02:
# Model Number: 41 of 187 with model ConstantNaive for Validation 1
# 41 - ConstantNaive with avg smape 9.38:
# Model Number: 42 of 187 with model ConstantNaive for Validation 1
# 42 - ConstantNaive with avg smape 9.25:
# Model Number: 43 of 187 with model ConstantNaive for Validation 1
# 43 - ConstantNaive with avg smape 9.25:
# Model Number: 44 of 187 with model ConstantNaive for Validation 1
# 44 - ConstantNaive with avg smape 9.25:
# Model Number: 45 of 187 with model ARIMA for Validation 1
# 45 - ARIMA with avg smape 9.25:
# Model Number: 46 of 187 with model ARIMA for Validation 1
# 46 - ARIMA with avg smape 9.25:
# Model Number: 47 of 187 with model ARIMA for Validation 1
# 47 - ARIMA with avg smape 9.2:
# Model Number: 48 of 187 with model ARDL for Validation 1
# 48 - ARDL with avg smape 10.79:
# Model Number: 49 of 187 with model ARIMA for Validation 1
# 📈 49 - ARIMA with avg smape 7.72:
# Model Number: 50 of 187 with model NVAR for Validation 1
# 50 - NVAR with avg smape 14.11:
# Model Number: 51 of 187 with model GLM for Validation 1
# 51 - GLM with avg smape 9.25:
# Model Number: 52 of 187 with model ETS for Validation 1
# 52 - ETS with avg smape 9.8:
# Model Number: 53 of 187 with model ETS for Validation 1
# 53 - ETS with avg smape 9.8:
# Model Number: 54 of 187 with model LastValueNaive for Validation 1
# 54 - LastValueNaive with avg smape 8.95:
# Model Number: 55 of 187 with model LastValueNaive for Validation 1
# 55 - LastValueNaive with avg smape 8.94:
# Model Number: 56 of 187 with model LastValueNaive for Validation 1
# 56 - LastValueNaive with avg smape 8.99:
# Model Number: 57 of 187 with model GLM for Validation 1
# 57 - GLM with avg smape 9.06:
# Model Number: 58 of 187 with model UnivariateMotif for Validation 1
# 58 - UnivariateMotif with avg smape 8.72:
# Model Number: 59 of 187 with model UnivariateMotif for Validation 1
# 59 - UnivariateMotif with avg smape 8.79:
# Model Number: 60 of 187 with model SectionalMotif for Validation 1
# 60 - SectionalMotif with avg smape 15.32:
# Model Number: 61 of 187 with model LastValueNaive for Validation 1
# 61 - LastValueNaive with avg smape 9.13:
# Model Number: 62 of 187 with model LastValueNaive for Validation 1
# 62 - LastValueNaive with avg smape 9.13:
# Model Number: 63 of 187 with model LastValueNaive for Validation 1
# 63 - LastValueNaive with avg smape 9.13:
# Model Number: 64 of 187 with model WindowRegression for Validation 1
# 64 - WindowRegression with avg smape 10.87:
# Model Number: 65 of 187 with model DatepartRegression for Validation 1
# 65 - DatepartRegression with avg smape 8.61:
# Model Number: 66 of 187 with model MultivariateMotif for Validation 1
# 66 - MultivariateMotif with avg smape 10.18:
# Model Number: 67 of 187 with model ETS for Validation 1
# 67 - ETS with avg smape 9.25:
# Model Number: 68 of 187 with model SectionalMotif for Validation 1
# 68 - SectionalMotif with avg smape 9.31:
# Model Number: 69 of 187 with model SectionalMotif for Validation 1
# 69 - SectionalMotif with avg smape 9.31:
# Model Number: 70 of 187 with model UnivariateMotif for Validation 1
# 70 - UnivariateMotif with avg smape 8.72:
# Model Number: 71 of 187 with model DatepartRegression for Validation 1
# 71 - DatepartRegression with avg smape 9.25:
# Model Number: 72 of 187 with model DatepartRegression for Validation 1
# 72 - DatepartRegression with avg smape 9.25:
# Model Number: 73 of 187 with model DatepartRegression for Validation 1
# 73 - DatepartRegression with avg smape 9.25:
# Model Number: 74 of 187 with model DatepartRegression for Validation 1
# 74 - DatepartRegression with avg smape 9.25:
# Model Number: 75 of 187 with model DatepartRegression for Validation 1
# 75 - DatepartRegression with avg smape 12.83:
# Model Number: 76 of 187 with model LastValueNaive for Validation 1
# 76 - LastValueNaive with avg smape 11.45:
# Model Number: 77 of 187 with model SectionalMotif for Validation 1
# 77 - SectionalMotif with avg smape 8.81:
# Model Number: 78 of 187 with model ETS for Validation 1
# 78 - ETS with avg smape 9.04:
# Model Number: 79 of 187 with model SeasonalNaive for Validation 1
# 79 - SeasonalNaive with avg smape 14.12:
# Model Number: 80 of 187 with model LastValueNaive for Validation 1
# 80 - LastValueNaive with avg smape 9.25:
# Model Number: 81 of 187 with model GLM for Validation 1
# 81 - GLM with avg smape 8.29:
# Model Number: 82 of 187 with model SectionalMotif for Validation 1
# 82 - SectionalMotif with avg smape 9.03:
# Model Number: 83 of 187 with model GLM for Validation 1
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# 83 - GLM with avg smape 8.29:
# Model Number: 84 of 187 with model GLM for Validation 1
# 84 - GLM with avg smape 8.28:
# Model Number: 85 of 187 with model SectionalMotif for Validation 1
# 85 - SectionalMotif with avg smape 8.21:
# Model Number: 86 of 187 with model WindowRegression for Validation 1
# 📈 86 - WindowRegression with avg smape 7.27:
# Model Number: 87 of 187 with model SectionalMotif for Validation 1
# 87 - SectionalMotif with avg smape 9.04:
# Model Number: 88 of 187 with model AverageValueNaive for Validation 1
# 88 - AverageValueNaive with avg smape 9.25:
# Model Number: 89 of 187 with model WindowRegression for Validation 1
# 89 - WindowRegression with avg smape 9.23:
# Model Number: 90 of 187 with model AverageValueNaive for Validation 1
# 90 - AverageValueNaive with avg smape 9.25:
# Model Number: 91 of 187 with model AverageValueNaive for Validation 1
# 91 - AverageValueNaive with avg smape 9.25:
# Model Number: 92 of 187 with model LastValueNaive for Validation 1
# 92 - LastValueNaive with avg smape 9.25:
# Model Number: 93 of 187 with model SeasonalNaive for Validation 1
# 📈 93 - SeasonalNaive with avg smape 6.56:
# Model Number: 94 of 187 with model GLM for Validation 1
# 94 - GLM with avg smape 8.06:
# Model Number: 95 of 187 with model MultivariateMotif for Validation 1
# 95 - MultivariateMotif with avg smape 9.24:
# Model Number: 96 of 187 with model WindowRegression for Validation 1
# 96 - WindowRegression with avg smape 11.64:
# Model Number: 97 of 187 with model WindowRegression for Validation 1
# 97 - WindowRegression with avg smape 11.64:
# Model Number: 98 of 187 with model SeasonalNaive for Validation 1
# 98 - SeasonalNaive with avg smape 9.61:
# Model Number: 99 of 187 with model SeasonalNaive for Validation 1
# 99 - SeasonalNaive with avg smape 9.61:
# Model Number: 100 of 187 with model ETS for Validation 1
# 100 - ETS with avg smape 9.25:
# Model Number: 101 of 187 with model SectionalMotif for Validation 1
# 101 - SectionalMotif with avg smape 9.24:
# Model Number: 102 of 187 with model SectionalMotif for Validation 1
# 102 - SectionalMotif with avg smape 9.26:
# Model Number: 103 of 187 with model ETS for Validation 1
# 103 - ETS with avg smape 10.31:
# Model Number: 104 of 187 with model GLM for Validation 1
# 104 - GLM with avg smape 8.27:
# Model Number: 105 of 187 with model GLM for Validation 1
# 105 - GLM with avg smape 8.27:
# Model Number: 106 of 187 with model WindowRegression for Validation 1
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# 106 - WindowRegression with avg smape 9.26:
# Model Number: 107 of 187 with model WindowRegression for Validation 1
# 107 - WindowRegression with avg smape 11.7:
# Model Number: 108 of 187 with model ETS for Validation 1
# 108 - ETS with avg smape 10.43:
# Model Number: 109 of 187 with model ETS for Validation 1
# 109 - ETS with avg smape 8.27:
# Model Number: 110 of 187 with model WindowRegression for Validation 1
# 110 - WindowRegression with avg smape 15.63:
# Model Number: 111 of 187 with model SeasonalNaive for Validation 1
# 111 - SeasonalNaive with avg smape 9.96:
# Model Number: 112 of 187 with model SeasonalNaive for Validation 1
# 112 - SeasonalNaive with avg smape 10.24:
# Model Number: 113 of 187 with model GLM for Validation 1
# 113 - GLM with avg smape 8.12:
# Model Number: 114 of 187 with model DatepartRegression for Validation 1
# 114 - DatepartRegression with avg smape 8.27:
# Model Number: 115 of 187 with model DatepartRegression for Validation 1
# 115 - DatepartRegression with avg smape 8.27:
# Model Number: 116 of 187 with model ETS for Validation 1
# 116 - ETS with avg smape 8.27:
# Model Number: 117 of 187 with model DatepartRegression for Validation 1
# 117 - DatepartRegression with avg smape 8.27:
# Model Number: 118 of 187 with model WindowRegression for Validation 1
# 118 - WindowRegression with avg smape 21.09:
# Model Number: 119 of 187 with model SeasonalNaive for Validation 1
# 119 - SeasonalNaive with avg smape 6.68:
# Model Number: 120 of 187 with model SeasonalNaive for Validation 1
# 120 - SeasonalNaive with avg smape 7.48:
# Model Number: 121 of 187 with model MultivariateMotif for Validation 1
# 121 - MultivariateMotif with avg smape 10.37:
# Model Number: 122 of 187 with model MultivariateMotif for Validation 1
# 122 - MultivariateMotif with avg smape 8.49:
# Model Number: 123 of 187 with model UnobservedComponents for Validation 1
# 123 - UnobservedComponents with avg smape 7.05:
# Model Number: 124 of 187 with model GLS for Validation 1
# 124 - GLS with avg smape 9.23:
# Model Number: 125 of 187 with model GLS for Validation 1
# 125 - GLS with avg smape 9.23:
# Model Number: 126 of 187 with model UnobservedComponents for Validation 1
# 126 - UnobservedComponents with avg smape 9.52:
# Model Number: 127 of 187 with model MultivariateMotif for Validation 1
# 127 - MultivariateMotif with avg smape 10.43:
# Model Number: 128 of 187 with model MultivariateMotif for Validation 1
# 128 - MultivariateMotif with avg smape 10.43:
# Model Number: 129 of 187 with model FBProphet for Validation 1
# 129 - FBProphet with avg smape 9.12:
# Model Number: 130 of 187 with model SeasonalNaive for Validation 1
# 130 - SeasonalNaive with avg smape 9.73:
# Model Number: 131 of 187 with model FBProphet for Validation 1
# 19:17:38 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# 131 - FBProphet with avg smape 9.04:
# Model Number: 132 of 187 with model FBProphet for Validation 1
# 132 - FBProphet with avg smape 17.03:
# Model Number: 133 of 187 with model UnobservedComponents for Validation 1
# 133 - UnobservedComponents with avg smape 8.09:
# Model Number: 134 of 187 with model GLS for Validation 1
# 134 - GLS with avg smape 11.29:
# Model Number: 135 of 187 with model FBProphet for Validation 1
# 135 - FBProphet with avg smape 17.41:
# Model Number: 136 of 187 with model MultivariateRegression for Validation 1
# 19:17:40 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# 136 - MultivariateRegression with avg smape 9.26:
# Model Number: 137 of 187 with model FBProphet for Validation 1
# 137 - FBProphet with avg smape 9.17:
# Model Number: 138 of 187 with model UnivariateMotif for Validation 1
# 19:17:41 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# 138 - UnivariateMotif with avg smape 8.78:
# Model Number: 139 of 187 with model FBProphet for Validation 1
# 139 - FBProphet with avg smape 9.17:
# Model Number: 140 of 187 with model FBProphet for Validation 1
# 19:17:42 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# 140 - FBProphet with avg smape 8.7:
# Model Number: 141 of 187 with model MultivariateRegression for Validation 1
# 19:17:44 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# 141 - MultivariateRegression with avg smape 12.69:
# Model Number: 142 of 187 with model FBProphet for Validation 1
# 142 - FBProphet with avg smape 8.73:
# Model Number: 143 of 187 with model MultivariateRegression for Validation 1
# 143 - MultivariateRegression with avg smape 10.04:
# Model Number: 144 of 187 with model UnivariateMotif for Validation 1
# 144 - UnivariateMotif with avg smape 11.56:
# Model Number: 145 of 187 with model FBProphet for Validation 1
# 145 - FBProphet with avg smape 8.29:
# Model Number: 146 of 187 with model UnobservedComponents for Validation 1
# 146 - UnobservedComponents with avg smape 9.03:
# Model Number: 147 of 187 with model UnobservedComponents for Validation 1
# 147 - UnobservedComponents with avg smape 9.0:
# Model Number: 148 of 187 with model UnobservedComponents for Validation 1
# 148 - UnobservedComponents with avg smape 9.0:
# Model Number: 149 of 187 with model UnobservedComponents for Validation 1
# 149 - UnobservedComponents with avg smape 9.0:
# Model Number: 150 of 187 with model MultivariateRegression for Validation 1
# 150 - MultivariateRegression with avg smape 8.27:
# Model Number: 151 of 187 with model AverageValueNaive for Validation 1
# 151 - AverageValueNaive with avg smape 9.15:
# Model Number: 152 of 187 with model GLS for Validation 1
# 152 - GLS with avg smape 10.82:
# Model Number: 153 of 187 with model MultivariateRegression for Validation 1
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_linear_loss.py:289: RuntimeWarning: invalid value encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# 153 - MultivariateRegression with avg smape 8.27:
# Model Number: 154 of 187 with model MultivariateRegression for Validation 1
# 154 - MultivariateRegression with avg smape 8.28:
# Model Number: 155 of 187 with model MultivariateRegression for Validation 1
# 155 - MultivariateRegression with avg smape 10.14:
# Model Number: 156 of 187 with model UnobservedComponents for Validation 1
# 156 - UnobservedComponents with avg smape 8.86:
# Model Number: 157 of 187 with model NVAR for Validation 1
# 157 - NVAR with avg smape 10.41:
# Model Number: 158 of 187 with model MultivariateRegression for Validation 1
# 158 - MultivariateRegression with avg smape 10.2:
# Model Number: 159 of 187 with model GLS for Validation 1
# 159 - GLS with avg smape 10.42:
# Model Number: 160 of 187 with model MultivariateMotif for Validation 1
# 160 - MultivariateMotif with avg smape 11.18:
# Model Number: 161 of 187 with model UnobservedComponents for Validation 1
# 161 - UnobservedComponents with avg smape 8.67:
# Model Number: 162 of 187 with model MultivariateMotif for Validation 1
# 162 - MultivariateMotif with avg smape 10.09:
# Model Number: 163 of 187 with model MultivariateMotif for Validation 1
# 163 - MultivariateMotif with avg smape 10.09:
# Model Number: 164 of 187 with model ARDL for Validation 1
# 164 - ARDL with avg smape 9.0:
# Model Number: 165 of 187 with model MultivariateRegression for Validation 1
# 165 - MultivariateRegression with avg smape 10.77:
# Model Number: 166 of 187 with model GLS for Validation 1
# 166 - GLS with avg smape 9.64:
# Model Number: 167 of 187 with model GLS for Validation 1
# 167 - GLS with avg smape 9.9:
# Model Number: 168 of 187 with model GLS for Validation 1
# 168 - GLS with avg smape 9.9:
# Model Number: 169 of 187 with model GLS for Validation 1
# 169 - GLS with avg smape 9.49:
# Model Number: 170 of 187 with model NVAR for Validation 1
# 170 - NVAR with avg smape 11.72:
# Model Number: 171 of 187 with model AverageValueNaive for Validation 1
# 171 - AverageValueNaive with avg smape 10.98:
# Model Number: 172 of 187 with model ARDL for Validation 1
# 172 - ARDL with avg smape 11.91:
# Model Number: 173 of 187 with model NVAR for Validation 1
# 173 - NVAR with avg smape 10.17:
# Model Number: 174 of 187 with model NVAR for Validation 1
# 174 - NVAR with avg smape 14.05:
# Model Number: 175 of 187 with model AverageValueNaive for Validation 1
# 175 - AverageValueNaive with avg smape 10.72:
# Model Number: 176 of 187 with model AverageValueNaive for Validation 1
# 176 - AverageValueNaive with avg smape 10.72:
# Model Number: 177 of 187 with model AverageValueNaive for Validation 1
# 177 - AverageValueNaive with avg smape 9.65:
# Model Number: 178 of 187 with model AverageValueNaive for Validation 1
# 178 - AverageValueNaive with avg smape 9.65:
# Model Number: 179 of 187 with model ARDL for Validation 1
# 179 - ARDL with avg smape 18.84:
# Model Number: 180 of 187 with model NVAR for Validation 1
# 180 - NVAR with avg smape 8.38:
# Model Number: 181 of 187 with model ARDL for Validation 1
# 181 - ARDL with avg smape 180.17:
# Model Number: 182 of 187 with model NVAR for Validation 1
# 182 - NVAR with avg smape 11.09:
# Model Number: 183 of 187 with model NVAR for Validation 1
# 183 - NVAR with avg smape 8.8:
# Model Number: 184 of 187 with model NVAR for Validation 1
# 184 - NVAR with avg smape 9.88:
# Model Number: 185 of 187 with model ARDL for Validation 1
# 185 - ARDL with avg smape 10.8:
# Model Number: 186 of 187 with model ARDL for Validation 1
# 186 - ARDL with avg smape 18.28:
# Model Number: 187 of 187 with model ARDL for Validation 1
# 187 - ARDL with avg smape 18.48:
# Validation Round: 2
# Model Number: 1 of 187 with model MetricMotif for Validation 2
# 📈 1 - MetricMotif with avg smape 1.67:
# Model Number: 2 of 187 with model Ensemble for Validation 2
# 2 - Ensemble with avg smape 1.67:
# Model Number: 3 of 187 with model Ensemble for Validation 2
# 3 - Ensemble with avg smape 1.67:
# Model Number: 4 of 187 with model MetricMotif for Validation 2
# 4 - MetricMotif with avg smape 1.67:
# Model Number: 5 of 187 with model MetricMotif for Validation 2
# 5 - MetricMotif with avg smape 1.67:
# Model Number: 6 of 187 with model MetricMotif for Validation 2
# 6 - MetricMotif with avg smape 1.67:
# Model Number: 7 of 187 with model MetricMotif for Validation 2
# 7 - MetricMotif with avg smape 1.67:
# Model Number: 8 of 187 with model Ensemble for Validation 2
# 📈 8 - Ensemble with avg smape 1.66:
# Model Number: 9 of 187 with model Ensemble for Validation 2
# 📈 9 - Ensemble with avg smape 1.65:
# Model Number: 10 of 187 with model MetricMotif for Validation 2
# 10 - MetricMotif with avg smape 1.67:
# Model Number: 11 of 187 with model MetricMotif for Validation 2
# 📈 11 - MetricMotif with avg smape 1.62:
# Model Number: 12 of 187 with model MetricMotif for Validation 2
# 12 - MetricMotif with avg smape 1.68:
# Model Number: 13 of 187 with model MetricMotif for Validation 2
# 13 - MetricMotif with avg smape 1.68:
# Model Number: 14 of 187 with model Ensemble for Validation 2
# 14 - Ensemble with avg smape 1.72:
# Model Number: 15 of 187 with model Theta for Validation 2
# 15 - Theta with avg smape 2.0:
# Model Number: 16 of 187 with model Theta for Validation 2
# 16 - Theta with avg smape 2.0:
# Model Number: 17 of 187 with model Theta for Validation 2
# 17 - Theta with avg smape 2.0:
# Model Number: 18 of 187 with model Ensemble for Validation 2
# 18 - Ensemble with avg smape 1.73:
# Model Number: 19 of 187 with model Ensemble for Validation 2
# 19 - Ensemble with avg smape 1.74:
# Model Number: 20 of 187 with model Theta for Validation 2
# 20 - Theta with avg smape 2.01:
# Model Number: 21 of 187 with model Ensemble for Validation 2
# 21 - Ensemble with avg smape 2.01:
# Model Number: 22 of 187 with model Theta for Validation 2
# 22 - Theta with avg smape 2.02:
# Model Number: 23 of 187 with model Theta for Validation 2
# 23 - Theta with avg smape 2.0:
# Model Number: 24 of 187 with model Theta for Validation 2
# 24 - Theta with avg smape 2.0:
# Model Number: 25 of 187 with model Theta for Validation 2
# 25 - Theta with avg smape 2.0:
# Model Number: 26 of 187 with model Theta for Validation 2
# 26 - Theta with avg smape 2.0:
# Model Number: 27 of 187 with model ARIMA for Validation 2
# 27 - ARIMA with avg smape 1.86:
# Model Number: 28 of 187 with model ARIMA for Validation 2
# 28 - ARIMA with avg smape 2.07:
# Model Number: 29 of 187 with model ARIMA for Validation 2
# 29 - ARIMA with avg smape 2.07:
# Model Number: 30 of 187 with model ARIMA for Validation 2
# 📈 30 - ARIMA with avg smape 1.33:
# Model Number: 31 of 187 with model ARIMA for Validation 2
# 31 - ARIMA with avg smape 2.31:
# Model Number: 32 of 187 with model UnivariateMotif for Validation 2
# 32 - UnivariateMotif with avg smape 2.19:
# Model Number: 33 of 187 with model UnivariateMotif for Validation 2
# 33 - UnivariateMotif with avg smape 2.19:
# Model Number: 34 of 187 with model UnivariateMotif for Validation 2
# 34 - UnivariateMotif with avg smape 2.19:
# Model Number: 35 of 187 with model UnivariateMotif for Validation 2
# 35 - UnivariateMotif with avg smape 2.19:
# Model Number: 36 of 187 with model ConstantNaive for Validation 2
# 36 - ConstantNaive with avg smape 2.2:
# Model Number: 37 of 187 with model ConstantNaive for Validation 2
# 37 - ConstantNaive with avg smape 2.2:
# Model Number: 38 of 187 with model ConstantNaive for Validation 2
# 38 - ConstantNaive with avg smape 2.2:
# Model Number: 39 of 187 with model ConstantNaive for Validation 2
# 39 - ConstantNaive with avg smape 2.0:
# Model Number: 40 of 187 with model ConstantNaive for Validation 2
# 40 - ConstantNaive with avg smape 2.22:
# Model Number: 41 of 187 with model ConstantNaive for Validation 2
# 41 - ConstantNaive with avg smape 1.9:
# Model Number: 42 of 187 with model ConstantNaive for Validation 2
# 42 - ConstantNaive with avg smape 1.96:
# Model Number: 43 of 187 with model ConstantNaive for Validation 2
# 43 - ConstantNaive with avg smape 1.96:
# Model Number: 44 of 187 with model ConstantNaive for Validation 2
# 44 - ConstantNaive with avg smape 1.96:
# Model Number: 45 of 187 with model ARIMA for Validation 2
# 45 - ARIMA with avg smape 1.35:
# Model Number: 46 of 187 with model ARIMA for Validation 2
# 46 - ARIMA with avg smape 1.35:
# Model Number: 47 of 187 with model ARIMA for Validation 2
# 47 - ARIMA with avg smape 1.34:
# Model Number: 48 of 187 with model ARDL for Validation 2
# 48 - ARDL with avg smape 3.18:
# Model Number: 49 of 187 with model ARIMA for Validation 2
# 49 - ARIMA with avg smape 3.31:
# Model Number: 50 of 187 with model NVAR for Validation 2
# 50 - NVAR with avg smape 6.63:
# Model Number: 51 of 187 with model GLM for Validation 2
# 51 - GLM with avg smape 1.96:
# Model Number: 52 of 187 with model ETS for Validation 2
# 52 - ETS with avg smape 2.5:
# Model Number: 53 of 187 with model ETS for Validation 2
# 53 - ETS with avg smape 2.5:
# Model Number: 54 of 187 with model LastValueNaive for Validation 2
# 54 - LastValueNaive with avg smape 2.41:
# Model Number: 55 of 187 with model LastValueNaive for Validation 2
# 55 - LastValueNaive with avg smape 2.53:
# Model Number: 56 of 187 with model LastValueNaive for Validation 2
# 56 - LastValueNaive with avg smape 2.43:
# Model Number: 57 of 187 with model GLM for Validation 2
# 57 - GLM with avg smape 2.12:
# Model Number: 58 of 187 with model UnivariateMotif for Validation 2
# 58 - UnivariateMotif with avg smape 4.06:
# Model Number: 59 of 187 with model UnivariateMotif for Validation 2
# 59 - UnivariateMotif with avg smape 3.94:
# Model Number: 60 of 187 with model SectionalMotif for Validation 2
# 📈 60 - SectionalMotif with avg smape 1.22:
# Model Number: 61 of 187 with model LastValueNaive for Validation 2
# 61 - LastValueNaive with avg smape 1.96:
# Model Number: 62 of 187 with model LastValueNaive for Validation 2
# 62 - LastValueNaive with avg smape 1.96:
# Model Number: 63 of 187 with model LastValueNaive for Validation 2
# 63 - LastValueNaive with avg smape 1.96:
# Model Number: 64 of 187 with model WindowRegression for Validation 2
# 64 - WindowRegression with avg smape 1.97:
# Model Number: 65 of 187 with model DatepartRegression for Validation 2
# 65 - DatepartRegression with avg smape 4.1:
# Model Number: 66 of 187 with model MultivariateMotif for Validation 2
# 66 - MultivariateMotif with avg smape 1.53:
# Model Number: 67 of 187 with model ETS for Validation 2
# 67 - ETS with avg smape 1.96:
# Model Number: 68 of 187 with model SectionalMotif for Validation 2
# 68 - SectionalMotif with avg smape 1.91:
# Model Number: 69 of 187 with model SectionalMotif for Validation 2
# 69 - SectionalMotif with avg smape 1.91:
# Model Number: 70 of 187 with model UnivariateMotif for Validation 2
# 70 - UnivariateMotif with avg smape 4.19:
# Model Number: 71 of 187 with model DatepartRegression for Validation 2
# 71 - DatepartRegression with avg smape 1.96:
# Model Number: 72 of 187 with model DatepartRegression for Validation 2
# 72 - DatepartRegression with avg smape 1.96:
# Model Number: 73 of 187 with model DatepartRegression for Validation 2
# 73 - DatepartRegression with avg smape 1.96:
# Model Number: 74 of 187 with model DatepartRegression for Validation 2
# 74 - DatepartRegression with avg smape 1.96:
# Model Number: 75 of 187 with model DatepartRegression for Validation 2
# 75 - DatepartRegression with avg smape 1.96:
# Model Number: 76 of 187 with model LastValueNaive for Validation 2
# 76 - LastValueNaive with avg smape 1.94:
# Model Number: 77 of 187 with model SectionalMotif for Validation 2
# 77 - SectionalMotif with avg smape 4.14:
# Model Number: 78 of 187 with model ETS for Validation 2
# 78 - ETS with avg smape 1.87:
# Model Number: 79 of 187 with model SeasonalNaive for Validation 2
# 79 - SeasonalNaive with avg smape 3.59:
# Model Number: 80 of 187 with model LastValueNaive for Validation 2
# 80 - LastValueNaive with avg smape 1.96:
# Model Number: 81 of 187 with model GLM for Validation 2
# 81 - GLM with avg smape 3.58:
# Model Number: 82 of 187 with model SectionalMotif for Validation 2
# 82 - SectionalMotif with avg smape 2.56:
# Model Number: 83 of 187 with model GLM for Validation 2
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# 83 - GLM with avg smape 3.58:
# Model Number: 84 of 187 with model GLM for Validation 2
# 84 - GLM with avg smape 3.57:
# Model Number: 85 of 187 with model SectionalMotif for Validation 2
# 85 - SectionalMotif with avg smape 4.21:
# Model Number: 86 of 187 with model WindowRegression for Validation 2
# 86 - WindowRegression with avg smape 4.34:
# Model Number: 87 of 187 with model SectionalMotif for Validation 2
# 87 - SectionalMotif with avg smape 2.56:
# Model Number: 88 of 187 with model AverageValueNaive for Validation 2
# 88 - AverageValueNaive with avg smape 1.96:
# Model Number: 89 of 187 with model WindowRegression for Validation 2
# 89 - WindowRegression with avg smape 1.87:
# Model Number: 90 of 187 with model AverageValueNaive for Validation 2
# 90 - AverageValueNaive with avg smape 1.96:
# Model Number: 91 of 187 with model AverageValueNaive for Validation 2
# 91 - AverageValueNaive with avg smape 1.96:
# Model Number: 92 of 187 with model LastValueNaive for Validation 2
# 92 - LastValueNaive with avg smape 1.96:
# Model Number: 93 of 187 with model SeasonalNaive for Validation 2
# 93 - SeasonalNaive with avg smape 1.46:
# Model Number: 94 of 187 with model GLM for Validation 2
# 94 - GLM with avg smape 3.9:
# Model Number: 95 of 187 with model MultivariateMotif for Validation 2
# 95 - MultivariateMotif with avg smape 1.75:
# Model Number: 96 of 187 with model WindowRegression for Validation 2
# 96 - WindowRegression with avg smape 2.58:
# Model Number: 97 of 187 with model WindowRegression for Validation 2
# 97 - WindowRegression with avg smape 2.58:
# Model Number: 98 of 187 with model SeasonalNaive for Validation 2
# 98 - SeasonalNaive with avg smape 3.23:
# Model Number: 99 of 187 with model SeasonalNaive for Validation 2
# 99 - SeasonalNaive with avg smape 3.23:
# Model Number: 100 of 187 with model ETS for Validation 2
# 100 - ETS with avg smape 1.96:
# Model Number: 101 of 187 with model SectionalMotif for Validation 2
# 101 - SectionalMotif with avg smape 1.79:
# Model Number: 102 of 187 with model SectionalMotif for Validation 2
# 102 - SectionalMotif with avg smape 2.82:
# Model Number: 103 of 187 with model ETS for Validation 2
# 103 - ETS with avg smape 3.5:
# Model Number: 104 of 187 with model GLM for Validation 2
# 104 - GLM with avg smape 3.7:
# Model Number: 105 of 187 with model GLM for Validation 2
# 105 - GLM with avg smape 3.7:
# Model Number: 106 of 187 with model WindowRegression for Validation 2
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# 106 - WindowRegression with avg smape 1.89:
# Model Number: 107 of 187 with model WindowRegression for Validation 2
# 107 - WindowRegression with avg smape 3.57:
# Model Number: 108 of 187 with model ETS for Validation 2
# 108 - ETS with avg smape 3.42:
# Model Number: 109 of 187 with model ETS for Validation 2
# 109 - ETS with avg smape 3.7:
# Model Number: 110 of 187 with model WindowRegression for Validation 2
# 110 - WindowRegression with avg smape 6.8:
# Model Number: 111 of 187 with model SeasonalNaive for Validation 2
# 111 - SeasonalNaive with avg smape 3.61:
# Model Number: 112 of 187 with model SeasonalNaive for Validation 2
# 112 - SeasonalNaive with avg smape 3.61:
# Model Number: 113 of 187 with model GLM for Validation 2
# 113 - GLM with avg smape 3.54:
# Model Number: 114 of 187 with model DatepartRegression for Validation 2
# 114 - DatepartRegression with avg smape 3.7:
# Model Number: 115 of 187 with model DatepartRegression for Validation 2
# 115 - DatepartRegression with avg smape 3.7:
# Model Number: 116 of 187 with model ETS for Validation 2
# 116 - ETS with avg smape 3.7:
# Model Number: 117 of 187 with model DatepartRegression for Validation 2
# 117 - DatepartRegression with avg smape 3.7:
# Model Number: 118 of 187 with model WindowRegression for Validation 2
# 118 - WindowRegression with avg smape 13.41:
# Model Number: 119 of 187 with model SeasonalNaive for Validation 2
# 119 - SeasonalNaive with avg smape 1.46:
# Model Number: 120 of 187 with model SeasonalNaive for Validation 2
# 120 - SeasonalNaive with avg smape 3.04:
# Model Number: 121 of 187 with model MultivariateMotif for Validation 2
# 121 - MultivariateMotif with avg smape 1.69:
# Model Number: 122 of 187 with model MultivariateMotif for Validation 2
# 122 - MultivariateMotif with avg smape 1.65:
# Model Number: 123 of 187 with model UnobservedComponents for Validation 2
# 123 - UnobservedComponents with avg smape 3.87:
# Model Number: 124 of 187 with model GLS for Validation 2
# 124 - GLS with avg smape 1.94:
# Model Number: 125 of 187 with model GLS for Validation 2
# 125 - GLS with avg smape 1.94:
# Model Number: 126 of 187 with model UnobservedComponents for Validation 2
# 126 - UnobservedComponents with avg smape 8.23:
# Model Number: 127 of 187 with model MultivariateMotif for Validation 2
# 127 - MultivariateMotif with avg smape 1.98:
# Model Number: 128 of 187 with model MultivariateMotif for Validation 2
# 128 - MultivariateMotif with avg smape 1.98:
# Model Number: 129 of 187 with model FBProphet for Validation 2
# 129 - FBProphet with avg smape 1.86:
# Model Number: 130 of 187 with model SeasonalNaive for Validation 2
# 130 - SeasonalNaive with avg smape 4.8:
# Model Number: 131 of 187 with model FBProphet for Validation 2
# 19:18:52 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# 131 - FBProphet with avg smape 1.93:
# Model Number: 132 of 187 with model FBProphet for Validation 2
# 132 - FBProphet with avg smape 16.14:
# Model Number: 133 of 187 with model UnobservedComponents for Validation 2
# 133 - UnobservedComponents with avg smape 3.56:
# Model Number: 134 of 187 with model GLS for Validation 2
# 134 - GLS with avg smape 2.83:
# Model Number: 135 of 187 with model FBProphet for Validation 2
# 135 - FBProphet with avg smape 16.16:
# Model Number: 136 of 187 with model MultivariateRegression for Validation 2
# 19:18:54 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# 136 - MultivariateRegression with avg smape 1.99:
# Model Number: 137 of 187 with model FBProphet for Validation 2
# 137 - FBProphet with avg smape 1.66:
# Model Number: 138 of 187 with model UnivariateMotif for Validation 2
# 19:18:54 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# 138 - UnivariateMotif with avg smape 3.92:
# Model Number: 139 of 187 with model FBProphet for Validation 2
# 19:18:55 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# 139 - FBProphet with avg smape 1.66:
# Model Number: 140 of 187 with model FBProphet for Validation 2
# 140 - FBProphet with avg smape 1.66:
# Model Number: 141 of 187 with model MultivariateRegression for Validation 2
# 19:18:56 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# 141 - MultivariateRegression with avg smape 5.88:
# Model Number: 142 of 187 with model FBProphet for Validation 2
# 142 - FBProphet with avg smape 1.66:
# Model Number: 143 of 187 with model MultivariateRegression for Validation 2
# 143 - MultivariateRegression with avg smape 3.38:
# Model Number: 144 of 187 with model UnivariateMotif for Validation 2
# 144 - UnivariateMotif with avg smape 3.07:
# Model Number: 145 of 187 with model FBProphet for Validation 2
# 145 - FBProphet with avg smape 1.84:
# Model Number: 146 of 187 with model UnobservedComponents for Validation 2
# 146 - UnobservedComponents with avg smape 1.67:
# Model Number: 147 of 187 with model UnobservedComponents for Validation 2
# 147 - UnobservedComponents with avg smape 1.68:
# Model Number: 148 of 187 with model UnobservedComponents for Validation 2
# 148 - UnobservedComponents with avg smape 1.65:
# Model Number: 149 of 187 with model UnobservedComponents for Validation 2
# 149 - UnobservedComponents with avg smape 1.65:
# Model Number: 150 of 187 with model MultivariateRegression for Validation 2
# 150 - MultivariateRegression with avg smape 3.7:
# Model Number: 151 of 187 with model AverageValueNaive for Validation 2
# 151 - AverageValueNaive with avg smape 3.11:
# Model Number: 152 of 187 with model GLS for Validation 2
# 152 - GLS with avg smape 3.97:
# Model Number: 153 of 187 with model MultivariateRegression for Validation 2
# 153 - MultivariateRegression with avg smape 4.04:
# Model Number: 154 of 187 with model MultivariateRegression for Validation 2
# 154 - MultivariateRegression with avg smape 5.31:
# Model Number: 155 of 187 with model MultivariateRegression for Validation 2
# 155 - MultivariateRegression with avg smape 4.39:
# Model Number: 156 of 187 with model UnobservedComponents for Validation 2
# 156 - UnobservedComponents with avg smape 1.54:
# Model Number: 157 of 187 with model NVAR for Validation 2
# 157 - NVAR with avg smape 6.04:
# Model Number: 158 of 187 with model MultivariateRegression for Validation 2
# 158 - MultivariateRegression with avg smape 2.96:
# Model Number: 159 of 187 with model GLS for Validation 2
# 159 - GLS with avg smape 3.63:
# Model Number: 160 of 187 with model MultivariateMotif for Validation 2
# 160 - MultivariateMotif with avg smape 2.23:
# Model Number: 161 of 187 with model UnobservedComponents for Validation 2
# 161 - UnobservedComponents with avg smape 2.36:
# Model Number: 162 of 187 with model MultivariateMotif for Validation 2
# 162 - MultivariateMotif with avg smape 2.21:
# Model Number: 163 of 187 with model MultivariateMotif for Validation 2
# 163 - MultivariateMotif with avg smape 2.21:
# Model Number: 164 of 187 with model ARDL for Validation 2
# 164 - ARDL with avg smape 1.67:
# Model Number: 165 of 187 with model MultivariateRegression for Validation 2
# Template Eval Error: Exception('Transformer LocalLinearTrend failed on fit') in model 165 in generation 0: MultivariateRegression
# Model Number: 166 of 187 with model GLS for Validation 2
# 166 - GLS with avg smape 3.17:
# Model Number: 167 of 187 with model GLS for Validation 2
# 167 - GLS with avg smape 1.53:
# Model Number: 168 of 187 with model GLS for Validation 2
# 168 - GLS with avg smape 1.53:
# Model Number: 169 of 187 with model GLS for Validation 2
# 169 - GLS with avg smape 3.06:
# Model Number: 170 of 187 with model NVAR for Validation 2
# 170 - NVAR with avg smape 4.77:
# Model Number: 171 of 187 with model AverageValueNaive for Validation 2
# 171 - AverageValueNaive with avg smape 5.55:
# Model Number: 172 of 187 with model ARDL for Validation 2
# 172 - ARDL with avg smape 4.17:
# Model Number: 173 of 187 with model NVAR for Validation 2
# 173 - NVAR with avg smape 2.73:
# Model Number: 174 of 187 with model NVAR for Validation 2
# 174 - NVAR with avg smape 4.81:
# Model Number: 175 of 187 with model AverageValueNaive for Validation 2
# 175 - AverageValueNaive with avg smape 2.36:
# Model Number: 176 of 187 with model AverageValueNaive for Validation 2
# 176 - AverageValueNaive with avg smape 2.36:
# Model Number: 177 of 187 with model AverageValueNaive for Validation 2
# 177 - AverageValueNaive with avg smape 1.97:
# Model Number: 178 of 187 with model AverageValueNaive for Validation 2
# 178 - AverageValueNaive with avg smape 1.97:
# Model Number: 179 of 187 with model ARDL for Validation 2
# 179 - ARDL with avg smape 3.21:
# Model Number: 180 of 187 with model NVAR for Validation 2
# 180 - NVAR with avg smape 1.54:
# Model Number: 181 of 187 with model ARDL for Validation 2
# 181 - ARDL with avg smape 2.5:
# Model Number: 182 of 187 with model NVAR for Validation 2
# 182 - NVAR with avg smape 4.66:
# Model Number: 183 of 187 with model NVAR for Validation 2
# 183 - NVAR with avg smape 1.72:
# Model Number: 184 of 187 with model NVAR for Validation 2
# 184 - NVAR with avg smape 2.05:
# Model Number: 185 of 187 with model ARDL for Validation 2
# 185 - ARDL with avg smape 4.45:
# Model Number: 186 of 187 with model ARDL for Validation 2
# 186 - ARDL with avg smape 1.71:
# Model Number: 187 of 187 with model ARDL for Validation 2
# 187 - ARDL with avg smape 8.62:
# Validation Round: 3
# Model Number: 1 of 187 with model MetricMotif for Validation 3
# 📈 1 - MetricMotif with avg smape 7.13:
# Model Number: 2 of 187 with model Ensemble for Validation 3
# 2 - Ensemble with avg smape 7.13:
# Model Number: 3 of 187 with model Ensemble for Validation 3
# 3 - Ensemble with avg smape 7.13:
# Model Number: 4 of 187 with model MetricMotif for Validation 3
# 4 - MetricMotif with avg smape 7.13:
# Model Number: 5 of 187 with model MetricMotif for Validation 3
# 5 - MetricMotif with avg smape 7.13:
# Model Number: 6 of 187 with model MetricMotif for Validation 3
# 6 - MetricMotif with avg smape 7.13:
# Model Number: 7 of 187 with model MetricMotif for Validation 3
# 7 - MetricMotif with avg smape 7.13:
# Model Number: 8 of 187 with model Ensemble for Validation 3
# 8 - Ensemble with avg smape 7.2:
# Model Number: 9 of 187 with model Ensemble for Validation 3
# 9 - Ensemble with avg smape 7.24:
# Model Number: 10 of 187 with model MetricMotif for Validation 3
# 10 - MetricMotif with avg smape 7.25:
# Model Number: 11 of 187 with model MetricMotif for Validation 3
# 11 - MetricMotif with avg smape 7.13:
# Model Number: 12 of 187 with model MetricMotif for Validation 3
# 12 - MetricMotif with avg smape 7.23:
# Model Number: 13 of 187 with model MetricMotif for Validation 3
# 13 - MetricMotif with avg smape 7.23:
# Model Number: 14 of 187 with model Ensemble for Validation 3
# 14 - Ensemble with avg smape 7.58:
# Model Number: 15 of 187 with model Theta for Validation 3
# 15 - Theta with avg smape 8.24:
# Model Number: 16 of 187 with model Theta for Validation 3
# 16 - Theta with avg smape 8.24:
# Model Number: 17 of 187 with model Theta for Validation 3
# 17 - Theta with avg smape 8.24:
# Model Number: 18 of 187 with model Ensemble for Validation 3
# 18 - Ensemble with avg smape 7.37:
# Model Number: 19 of 187 with model Ensemble for Validation 3
# 19 - Ensemble with avg smape 7.38:
# Model Number: 20 of 187 with model Theta for Validation 3
# 20 - Theta with avg smape 8.28:
# Model Number: 21 of 187 with model Ensemble for Validation 3
# 21 - Ensemble with avg smape 7.73:
# Model Number: 22 of 187 with model Theta for Validation 3
# 22 - Theta with avg smape 8.28:
# Model Number: 23 of 187 with model Theta for Validation 3
# 23 - Theta with avg smape 8.25:
# Model Number: 24 of 187 with model Theta for Validation 3
# 24 - Theta with avg smape 8.25:
# Model Number: 25 of 187 with model Theta for Validation 3
# 25 - Theta with avg smape 8.25:
# Model Number: 26 of 187 with model Theta for Validation 3
# 26 - Theta with avg smape 8.25:
# Model Number: 27 of 187 with model ARIMA for Validation 3
# 27 - ARIMA with avg smape 7.37:
# Model Number: 28 of 187 with model ARIMA for Validation 3
# 28 - ARIMA with avg smape 8.7:
# Model Number: 29 of 187 with model ARIMA for Validation 3
# 29 - ARIMA with avg smape 8.7:
# Model Number: 30 of 187 with model ARIMA for Validation 3
# 30 - ARIMA with avg smape 7.2:
# Model Number: 31 of 187 with model ARIMA for Validation 3
# 31 - ARIMA with avg smape 8.14:
# Model Number: 32 of 187 with model UnivariateMotif for Validation 3
# 32 - UnivariateMotif with avg smape 7.65:
# Model Number: 33 of 187 with model UnivariateMotif for Validation 3
# 33 - UnivariateMotif with avg smape 7.65:
# Model Number: 34 of 187 with model UnivariateMotif for Validation 3
# 34 - UnivariateMotif with avg smape 7.65:
# Model Number: 35 of 187 with model UnivariateMotif for Validation 3
# 35 - UnivariateMotif with avg smape 7.65:
# Model Number: 36 of 187 with model ConstantNaive for Validation 3
# 36 - ConstantNaive with avg smape 7.8:
# Model Number: 37 of 187 with model ConstantNaive for Validation 3
# 37 - ConstantNaive with avg smape 7.8:
# Model Number: 38 of 187 with model ConstantNaive for Validation 3
# 38 - ConstantNaive with avg smape 7.8:
# Model Number: 39 of 187 with model ConstantNaive for Validation 3
# 39 - ConstantNaive with avg smape 7.74:
# Model Number: 40 of 187 with model ConstantNaive for Validation 3
# 40 - ConstantNaive with avg smape 7.81:
# Model Number: 41 of 187 with model ConstantNaive for Validation 3
# 41 - ConstantNaive with avg smape 7.8:
# Model Number: 42 of 187 with model ConstantNaive for Validation 3
# 42 - ConstantNaive with avg smape 8.14:
# Model Number: 43 of 187 with model ConstantNaive for Validation 3
# 43 - ConstantNaive with avg smape 8.14:
# Model Number: 44 of 187 with model ConstantNaive for Validation 3
# 44 - ConstantNaive with avg smape 8.14:
# Model Number: 45 of 187 with model ARIMA for Validation 3
# 📈 45 - ARIMA with avg smape 6.18:
# Model Number: 46 of 187 with model ARIMA for Validation 3
# 46 - ARIMA with avg smape 6.18:
# Model Number: 47 of 187 with model ARIMA for Validation 3
# 47 - ARIMA with avg smape 7.13:
# Model Number: 48 of 187 with model ARDL for Validation 3
# 📈 48 - ARDL with avg smape 4.64:
# Model Number: 49 of 187 with model ARIMA for Validation 3
# 49 - ARIMA with avg smape 7.87:
# Model Number: 50 of 187 with model NVAR for Validation 3
# 50 - NVAR with avg smape 7.13:
# Model Number: 51 of 187 with model GLM for Validation 3
# 51 - GLM with avg smape 8.14:
# Model Number: 52 of 187 with model ETS for Validation 3
# 52 - ETS with avg smape 6.41:
# Model Number: 53 of 187 with model ETS for Validation 3
# 53 - ETS with avg smape 6.41:
# Model Number: 54 of 187 with model LastValueNaive for Validation 3
# 📈 54 - LastValueNaive with avg smape 4.52:
# Model Number: 55 of 187 with model LastValueNaive for Validation 3
# 📈 55 - LastValueNaive with avg smape 2.32:
# Model Number: 56 of 187 with model LastValueNaive for Validation 3
# 56 - LastValueNaive with avg smape 4.52:
# Model Number: 57 of 187 with model GLM for Validation 3
# 57 - GLM with avg smape 8.39:
# Model Number: 58 of 187 with model UnivariateMotif for Validation 3
# 58 - UnivariateMotif with avg smape 7.45:
# Model Number: 59 of 187 with model UnivariateMotif for Validation 3
# 59 - UnivariateMotif with avg smape 7.44:
# Model Number: 60 of 187 with model SectionalMotif for Validation 3
# 60 - SectionalMotif with avg smape 4.74:
# Model Number: 61 of 187 with model LastValueNaive for Validation 3
# 61 - LastValueNaive with avg smape 8.44:
# Model Number: 62 of 187 with model LastValueNaive for Validation 3
# 62 - LastValueNaive with avg smape 8.44:
# Model Number: 63 of 187 with model LastValueNaive for Validation 3
# 63 - LastValueNaive with avg smape 8.44:
# Model Number: 64 of 187 with model WindowRegression for Validation 3
# 64 - WindowRegression with avg smape 7.94:
# Model Number: 65 of 187 with model DatepartRegression for Validation 3
# 65 - DatepartRegression with avg smape 8.57:
# Model Number: 66 of 187 with model MultivariateMotif for Validation 3
# 66 - MultivariateMotif with avg smape 8.25:
# Model Number: 67 of 187 with model ETS for Validation 3
# 67 - ETS with avg smape 8.14:
# Model Number: 68 of 187 with model SectionalMotif for Validation 3
# 68 - SectionalMotif with avg smape 7.99:
# Model Number: 69 of 187 with model SectionalMotif for Validation 3
# 69 - SectionalMotif with avg smape 7.99:
# Model Number: 70 of 187 with model UnivariateMotif for Validation 3
# 70 - UnivariateMotif with avg smape 8.17:
# Model Number: 71 of 187 with model DatepartRegression for Validation 3
# 71 - DatepartRegression with avg smape 8.14:
# Model Number: 72 of 187 with model DatepartRegression for Validation 3
# 72 - DatepartRegression with avg smape 8.14:
# Model Number: 73 of 187 with model DatepartRegression for Validation 3
# 73 - DatepartRegression with avg smape 8.14:
# Model Number: 74 of 187 with model DatepartRegression for Validation 3
# 74 - DatepartRegression with avg smape 8.14:
# Model Number: 75 of 187 with model DatepartRegression for Validation 3
# 75 - DatepartRegression with avg smape 8.14:
# Model Number: 76 of 187 with model LastValueNaive for Validation 3
# 📈 76 - LastValueNaive with avg smape 2.15:
# Model Number: 77 of 187 with model SectionalMotif for Validation 3
# 77 - SectionalMotif with avg smape 7.27:
# Model Number: 78 of 187 with model ETS for Validation 3
# 78 - ETS with avg smape 8.17:
# Model Number: 79 of 187 with model SeasonalNaive for Validation 3
# 79 - SeasonalNaive with avg smape 4.22:
# Model Number: 80 of 187 with model LastValueNaive for Validation 3
# 80 - LastValueNaive with avg smape 8.14:
# Model Number: 81 of 187 with model GLM for Validation 3
# 81 - GLM with avg smape 7.91:
# Model Number: 82 of 187 with model SectionalMotif for Validation 3
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# 82 - SectionalMotif with avg smape 8.12:
# Model Number: 83 of 187 with model GLM for Validation 3
# 83 - GLM with avg smape 7.91:
# Model Number: 84 of 187 with model GLM for Validation 3
# 84 - GLM with avg smape 7.91:
# Model Number: 85 of 187 with model SectionalMotif for Validation 3
# 85 - SectionalMotif with avg smape 9.8:
# Model Number: 86 of 187 with model WindowRegression for Validation 3
# 86 - WindowRegression with avg smape 9.36:
# Model Number: 87 of 187 with model SectionalMotif for Validation 3
# 87 - SectionalMotif with avg smape 8.12:
# Model Number: 88 of 187 with model AverageValueNaive for Validation 3
# 88 - AverageValueNaive with avg smape 8.14:
# Model Number: 89 of 187 with model WindowRegression for Validation 3
# 89 - WindowRegression with avg smape 8.14:
# Model Number: 90 of 187 with model AverageValueNaive for Validation 3
# 90 - AverageValueNaive with avg smape 8.14:
# Model Number: 91 of 187 with model AverageValueNaive for Validation 3
# 91 - AverageValueNaive with avg smape 8.14:
# Model Number: 92 of 187 with model LastValueNaive for Validation 3
# 92 - LastValueNaive with avg smape 8.14:
# Model Number: 93 of 187 with model SeasonalNaive for Validation 3
# 93 - SeasonalNaive with avg smape 6.71:
# Model Number: 94 of 187 with model GLM for Validation 3
# 94 - GLM with avg smape 8.22:
# Model Number: 95 of 187 with model MultivariateMotif for Validation 3
# 95 - MultivariateMotif with avg smape 8.31:
# Model Number: 96 of 187 with model WindowRegression for Validation 3
# 96 - WindowRegression with avg smape 9.8:
# Model Number: 97 of 187 with model WindowRegression for Validation 3
# 97 - WindowRegression with avg smape 9.8:
# Model Number: 98 of 187 with model SeasonalNaive for Validation 3
# 98 - SeasonalNaive with avg smape 6.63:
# Model Number: 99 of 187 with model SeasonalNaive for Validation 3
# 99 - SeasonalNaive with avg smape 6.63:
# Model Number: 100 of 187 with model ETS for Validation 3
# 100 - ETS with avg smape 8.14:
# Model Number: 101 of 187 with model SectionalMotif for Validation 3
# 101 - SectionalMotif with avg smape 8.32:
# Model Number: 102 of 187 with model SectionalMotif for Validation 3
# 102 - SectionalMotif with avg smape 9.86:
# Model Number: 103 of 187 with model ETS for Validation 3
# 103 - ETS with avg smape 5.41:
# Model Number: 104 of 187 with model GLM for Validation 3
# 104 - GLM with avg smape 7.92:
# Model Number: 105 of 187 with model GLM for Validation 3
# 105 - GLM with avg smape 7.92:
# Model Number: 106 of 187 with model WindowRegression for Validation 3
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# 106 - WindowRegression with avg smape 8.13:
# Model Number: 107 of 187 with model WindowRegression for Validation 3
# 107 - WindowRegression with avg smape 4.81:
# Model Number: 108 of 187 with model ETS for Validation 3
# 108 - ETS with avg smape 5.38:
# Model Number: 109 of 187 with model ETS for Validation 3
# 109 - ETS with avg smape 7.92:
# Model Number: 110 of 187 with model WindowRegression for Validation 3
# 110 - WindowRegression with avg smape 10.62:
# Model Number: 111 of 187 with model SeasonalNaive for Validation 3
# 111 - SeasonalNaive with avg smape 7.33:
# Model Number: 112 of 187 with model SeasonalNaive for Validation 3
# 112 - SeasonalNaive with avg smape 7.33:
# Model Number: 113 of 187 with model GLM for Validation 3
# 113 - GLM with avg smape 10.06:
# Model Number: 114 of 187 with model DatepartRegression for Validation 3
# 114 - DatepartRegression with avg smape 7.92:
# Model Number: 115 of 187 with model DatepartRegression for Validation 3
# 115 - DatepartRegression with avg smape 7.92:
# Model Number: 116 of 187 with model ETS for Validation 3
# 116 - ETS with avg smape 7.92:
# Model Number: 117 of 187 with model DatepartRegression for Validation 3
# 117 - DatepartRegression with avg smape 7.92:
# Model Number: 118 of 187 with model WindowRegression for Validation 3
# 118 - WindowRegression with avg smape 16.36:
# Model Number: 119 of 187 with model SeasonalNaive for Validation 3
# 119 - SeasonalNaive with avg smape 5.16:
# Model Number: 120 of 187 with model SeasonalNaive for Validation 3
# 120 - SeasonalNaive with avg smape 6.48:
# Model Number: 121 of 187 with model MultivariateMotif for Validation 3
# 121 - MultivariateMotif with avg smape 8.67:
# Model Number: 122 of 187 with model MultivariateMotif for Validation 3
# 122 - MultivariateMotif with avg smape 7.0:
# Model Number: 123 of 187 with model UnobservedComponents for Validation 3
# 123 - UnobservedComponents with avg smape 4.96:
# Model Number: 124 of 187 with model GLS for Validation 3
# 124 - GLS with avg smape 8.12:
# Model Number: 125 of 187 with model GLS for Validation 3
# 125 - GLS with avg smape 8.12:
# Model Number: 126 of 187 with model UnobservedComponents for Validation 3
# 126 - UnobservedComponents with avg smape 163.25:
# Model Number: 127 of 187 with model MultivariateMotif for Validation 3
# 127 - MultivariateMotif with avg smape 8.95:
# Model Number: 128 of 187 with model MultivariateMotif for Validation 3
# 128 - MultivariateMotif with avg smape 8.95:
# Model Number: 129 of 187 with model FBProphet for Validation 3
# 129 - FBProphet with avg smape 8.24:
# Model Number: 130 of 187 with model SeasonalNaive for Validation 3
# 130 - SeasonalNaive with avg smape 8.55:
# Model Number: 131 of 187 with model FBProphet for Validation 3
# 19:20:23 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# 131 - FBProphet with avg smape 8.1:
# Model Number: 132 of 187 with model FBProphet for Validation 3
# 132 - FBProphet with avg smape 19.06:
# Model Number: 133 of 187 with model UnobservedComponents for Validation 3
# 133 - UnobservedComponents with avg smape 7.19:
# Model Number: 134 of 187 with model GLS for Validation 3
# 134 - GLS with avg smape 2.26:
# Model Number: 135 of 187 with model FBProphet for Validation 3
# 135 - FBProphet with avg smape 19.0:
# Model Number: 136 of 187 with model MultivariateRegression for Validation 3
# 19:20:25 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# 136 - MultivariateRegression with avg smape 9.12:
# Model Number: 137 of 187 with model FBProphet for Validation 3
# 137 - FBProphet with avg smape 7.96:
# Model Number: 138 of 187 with model UnivariateMotif for Validation 3
# 19:20:26 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# 138 - UnivariateMotif with avg smape 7.52:
# Model Number: 139 of 187 with model FBProphet for Validation 3
# 19:20:27 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# 139 - FBProphet with avg smape 7.96:
# Model Number: 140 of 187 with model FBProphet for Validation 3
# 140 - FBProphet with avg smape 7.43:
# Model Number: 141 of 187 with model MultivariateRegression for Validation 3
# 19:20:29 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# 141 - MultivariateRegression with avg smape 2.37:
# Model Number: 142 of 187 with model FBProphet for Validation 3
# 142 - FBProphet with avg smape 7.29:
# Model Number: 143 of 187 with model MultivariateRegression for Validation 3
# 143 - MultivariateRegression with avg smape 2.6:
# Model Number: 144 of 187 with model UnivariateMotif for Validation 3
# 144 - UnivariateMotif with avg smape 5.0:
# Model Number: 145 of 187 with model FBProphet for Validation 3
# 145 - FBProphet with avg smape 8.03:
# Model Number: 146 of 187 with model UnobservedComponents for Validation 3
# 146 - UnobservedComponents with avg smape 7.72:
# Model Number: 147 of 187 with model UnobservedComponents for Validation 3
# 147 - UnobservedComponents with avg smape 9.64:
# Model Number: 148 of 187 with model UnobservedComponents for Validation 3
# 148 - UnobservedComponents with avg smape 7.72:
# Model Number: 149 of 187 with model UnobservedComponents for Validation 3
# 149 - UnobservedComponents with avg smape 7.72:
# Model Number: 150 of 187 with model MultivariateRegression for Validation 3
# 150 - MultivariateRegression with avg smape 9.28:
# Model Number: 151 of 187 with model AverageValueNaive for Validation 3
# 151 - AverageValueNaive with avg smape 5.65:
# Model Number: 152 of 187 with model GLS for Validation 3
# 152 - GLS with avg smape 4.22:
# Model Number: 153 of 187 with model MultivariateRegression for Validation 3
# 153 - MultivariateRegression with avg smape 7.92:
# Model Number: 154 of 187 with model MultivariateRegression for Validation 3
# 154 - MultivariateRegression with avg smape 8.85:
# Model Number: 155 of 187 with model MultivariateRegression for Validation 3
# 155 - MultivariateRegression with avg smape 4.79:
# Model Number: 156 of 187 with model UnobservedComponents for Validation 3
# 156 - UnobservedComponents with avg smape 7.62:
# Model Number: 157 of 187 with model NVAR for Validation 3
# 157 - NVAR with avg smape 11.63:
# Model Number: 158 of 187 with model MultivariateRegression for Validation 3
# 📈 158 - MultivariateRegression with avg smape 2.05:
# Model Number: 159 of 187 with model GLS for Validation 3
# 159 - GLS with avg smape 3.92:
# Model Number: 160 of 187 with model MultivariateMotif for Validation 3
# 160 - MultivariateMotif with avg smape 2.16:
# Model Number: 161 of 187 with model UnobservedComponents for Validation 3
# 161 - UnobservedComponents with avg smape 9.27:
# Model Number: 162 of 187 with model MultivariateMotif for Validation 3
# 162 - MultivariateMotif with avg smape 2.4:
# Model Number: 163 of 187 with model MultivariateMotif for Validation 3
# 163 - MultivariateMotif with avg smape 2.4:
# Model Number: 164 of 187 with model ARDL for Validation 3
# 164 - ARDL with avg smape 6.98:
# Model Number: 165 of 187 with model MultivariateRegression for Validation 3
# Template Eval Error: Exception('Transformer LocalLinearTrend failed on fit') in model 165 in generation 0: MultivariateRegression
# Model Number: 166 of 187 with model GLS for Validation 3
# 166 - GLS with avg smape 3.34:
# Model Number: 167 of 187 with model GLS for Validation 3
# 📈 167 - GLS with avg smape 1.83:
# Model Number: 168 of 187 with model GLS for Validation 3
# 168 - GLS with avg smape 1.83:
# Model Number: 169 of 187 with model GLS for Validation 3
# 169 - GLS with avg smape 3.22:
# Model Number: 170 of 187 with model NVAR for Validation 3
# 170 - NVAR with avg smape 2.03:
# Model Number: 171 of 187 with model AverageValueNaive for Validation 3
# 171 - AverageValueNaive with avg smape 11.18:
# Model Number: 172 of 187 with model ARDL for Validation 3
# 172 - ARDL with avg smape 1.91:
# Model Number: 173 of 187 with model NVAR for Validation 3
# 173 - NVAR with avg smape 5.19:
# Model Number: 174 of 187 with model NVAR for Validation 3
# 174 - NVAR with avg smape 1.94:
# Model Number: 175 of 187 with model AverageValueNaive for Validation 3
# 175 - AverageValueNaive with avg smape 5.06:
# Model Number: 176 of 187 with model AverageValueNaive for Validation 3
# 176 - AverageValueNaive with avg smape 5.06:
# Model Number: 177 of 187 with model AverageValueNaive for Validation 3
# 177 - AverageValueNaive with avg smape 3.29:
# Model Number: 178 of 187 with model AverageValueNaive for Validation 3
# 178 - AverageValueNaive with avg smape 3.29:
# Model Number: 179 of 187 with model ARDL for Validation 3
# 179 - ARDL with avg smape 5.3:
# Model Number: 180 of 187 with model NVAR for Validation 3
# 180 - NVAR with avg smape 2.43:
# Model Number: 181 of 187 with model ARDL for Validation 3
# 181 - ARDL with avg smape 7.92:
# Model Number: 182 of 187 with model NVAR for Validation 3
# 182 - NVAR with avg smape 1.94:
# Model Number: 183 of 187 with model NVAR for Validation 3
# 183 - NVAR with avg smape 5.71:
# Model Number: 184 of 187 with model NVAR for Validation 3
# 184 - NVAR with avg smape 2.91:
# Model Number: 185 of 187 with model ARDL for Validation 3
# 185 - ARDL with avg smape 2.27:
# Model Number: 186 of 187 with model ARDL for Validation 3
# 186 - ARDL with avg smape 5.42:
# Model Number: 187 of 187 with model ARDL for Validation 3
# 187 - ARDL with avg smape 4.34:
# Model Number: 1831 with model Ensemble in generation 12 of Ensembles
# Model Number: 1832 with model Ensemble in generation 12 of Ensembles
# Model Number: 1833 with model Ensemble in generation 12 of Ensembles
# Model Number: 1834 with model Ensemble in generation 12 of Ensembles
# Model Number: 1835 with model Ensemble in generation 12 of Ensembles
# Model Number: 1836 with model Ensemble in generation 12 of Ensembles
# Model Number: 1837 with model Ensemble in generation 12 of Ensembles
# 19:20:39 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# Model Number: 1838 with model Ensemble in generation 12 of Ensembles
# 19:20:40 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# Validation Round: 1
# Model Number: 1 of 8 with model Ensemble for Validation 1
# 📈 1 - Ensemble with avg smape 7.38:
# Model Number: 2 of 8 with model Ensemble for Validation 1
# 2 - Ensemble with avg smape 9.08:
# Model Number: 3 of 8 with model Ensemble for Validation 1
# 3 - Ensemble with avg smape 8.28:
# Model Number: 4 of 8 with model Ensemble for Validation 1
# 4 - Ensemble with avg smape 9.06:
# Model Number: 5 of 8 with model Ensemble for Validation 1
# 5 - Ensemble with avg smape 8.49:
# Model Number: 6 of 8 with model Ensemble for Validation 1
# 6 - Ensemble with avg smape 8.58:
# Model Number: 7 of 8 with model Ensemble for Validation 1
# 19:20:44 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# 7 - Ensemble with avg smape 8.06:
# Model Number: 8 of 8 with model Ensemble for Validation 1
# 19:20:45 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# 8 - Ensemble with avg smape 8.11:
# Validation Round: 2
# Model Number: 1 of 8 with model Ensemble for Validation 2
# 📈 1 - Ensemble with avg smape 1.6:
# Model Number: 2 of 8 with model Ensemble for Validation 2
# 📈 2 - Ensemble with avg smape 1.48:
# Model Number: 3 of 8 with model Ensemble for Validation 2
# 3 - Ensemble with avg smape 1.77:
# Model Number: 4 of 8 with model Ensemble for Validation 2
# 4 - Ensemble with avg smape 1.96:
# Model Number: 5 of 8 with model Ensemble for Validation 2
# 5 - Ensemble with avg smape 1.65:
# Model Number: 6 of 8 with model Ensemble for Validation 2
# 6 - Ensemble with avg smape 1.73:
# Model Number: 7 of 8 with model Ensemble for Validation 2
# 19:20:48 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# 7 - Ensemble with avg smape 1.67:
# Model Number: 8 of 8 with model Ensemble for Validation 2
# 19:20:49 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# 8 - Ensemble with avg smape 1.68:
# Validation Round: 3
# Model Number: 1 of 8 with model Ensemble for Validation 3
# 📈 1 - Ensemble with avg smape 3.67:
# Model Number: 2 of 8 with model Ensemble for Validation 3
# 📈 2 - Ensemble with avg smape 2.01:
# Model Number: 3 of 8 with model Ensemble for Validation 3
# 3 - Ensemble with avg smape 4.04:
# Model Number: 4 of 8 with model Ensemble for Validation 3
# 4 - Ensemble with avg smape 5.16:
# Model Number: 5 of 8 with model Ensemble for Validation 3
# 5 - Ensemble with avg smape 2.39:
# Model Number: 6 of 8 with model Ensemble for Validation 3
# 6 - Ensemble with avg smape 2.53:
# Model Number: 7 of 8 with model Ensemble for Validation 3
# 19:20:52 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# 7 - Ensemble with avg smape 3.71:
# Model Number: 8 of 8 with model Ensemble for Validation 3
# 19:20:53 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# 8 - Ensemble with avg smape 3.77:
# DogeCoin Price Prediction
#                   Close
# 2023-12-21  2297.951349
# 2023-12-22  2303.789018
# 2023-12-23  2307.244615
# 2023-12-24  2309.328832
# 2023-12-25  2312.942697
# 2023-12-26  2315.857191
# 2023-12-27  2321.350325
# 2023-12-28  2331.799402
# 2023-12-29  2348.139651
# 2023-12-30  2364.605887
